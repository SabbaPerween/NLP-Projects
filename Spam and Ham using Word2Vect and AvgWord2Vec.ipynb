# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\acer\anaconda3\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\users\acer\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\users\acer\anaconda3\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\acer\anaconda3\lib\site-packages (from gensim) (5.2.1)

# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king=wv['king']

# %%
import pandas as pd
messages=pd.read_csv('SMSSpamCollection.txt',
                    sep='\t',names=["label","message"])

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
corpus=[]
for i in range(0,len(messages)):
    review=re.sub('[^a-zA-z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[lemmatizer.lemmatize(word) for word in review ]
    review=' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
#  'had your mobile month or more u r entitled to update to the latest colour mobile with camera for free call the mobile update co free on',
#  'i m gonna be home soon and i don t want to talk about this stuff anymore tonight k i ve cried enough today',
#  'six chance to win cash from to pound txt csh and send to cost p day day tsandcs apply reply hl info',
#  'urgent you have won a week free membership in our prize jackpot txt the word claim to no t c www dbuk net lccltd pobox ldnw a rw',
#  'i ve been searching for the right word to thank you for this breather i promise i wont take your help for granted and will fulfil my promise you have been wonderful and a blessing at all time',
#  'i have a date on sunday with will',
#  'xxxmobilemovieclub to use your credit click the wap link in the next txt message or click here http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'oh k i m watching here',
#  'eh u remember how spell his name yes i did he v naughty make until i v wet',
#  'fine if that s the way u feel that s the way it gota b',
#  'england v macedonia dont miss the goal team news txt ur national team to eg england to try wale scotland txt poboxox w wq',
#  'is that seriously how you spell his name',
#  'i m going to try for month ha ha only joking',
#  'so pay first lar then when is da stock comin',
#  'aft i finish my lunch then i go str down lor ard smth lor u finish ur lunch already',
#  'ffffffffff alright no way i can meet up with you sooner',
#  'just forced myself to eat a slice i m really not hungry tho this suck mark is getting worried he know i m sick when i turn down pizza lol',
#  'lol your always so convincing',
#  'did you catch the bus are you frying an egg did you make a tea are you eating your mom s left over dinner do you feel my love',
#  'i m back amp we re packing the car now i ll let you know if there s room',
#  'ahhh work i vaguely remember that what doe it feel like lol',
#  'wait that s still not all that clear were you not sure about me being sarcastic or that that s why x doesn t want to live with u',
#  'yeah he got in at and wa v apologetic n had fallen out and she wa actin like spoilt child and he got caught up in that till but we won t go there not doing too badly cheer you',
#  'k tell me anything about you',
#  'for fear of fainting with the of all that housework you just did quick have a cuppa',
#  'thanks for your subscription to ringtone uk your mobile will be charged month please confirm by replying yes or no if you reply no you will not be charged',
#  'yup ok i go home look at the timing then i msg again xuhui going to learn on nd may too but her lesson is at am',
#  'oops i ll let you know when my roommate s done',
#  'i see the letter b on my car',
#  'anything lor u decide',
#  'hello how s you and how did saturday go i wa just texting to see if you d decided to do anything tomo not that i m trying to invite myself or anything',
#  'pls go ahead with watt i just wanted to be sure do have a great weekend abiola',
#  'did i forget to tell you i want you i need you i crave you but most of all i love you my sweet arabian steed mmmmmm yummy',
#  'rodger burn msg we tried to call you re your reply to our sm for a free nokia mobile free camcorder please call now for delivery tomorrow',
#  'who are you seeing',
#  'great i hope you like your man well endowed i am lt gt inch',
#  'no call message missed call',
#  'didn t you get hep b immunisation in nigeria',
#  'fair enough anything going on',
#  'yeah hopefully if tyler can t do it i could maybe ask around a bit',
#  'u don t know how stubborn i am i didn t even want to go to the hospital i kept telling mark i m not a weak sucker hospital are for weak sucker',
#  'what you thinked about me first time you saw me in class',
#  'a gram usually run like lt gt a half eighth is smarter though and get you almost a whole second gram for lt gt',
#  'k fyi x ha a ride early tomorrow morning but he s crashing at our place tonight',
#  'wow i never realized that you were so embarassed by your accomodations i thought you liked it since i wa doing the best i could and you always seemed so happy about the cave i m sorry i didn t and don t have more to give i m sorry i offered i m sorry your room wa so embarassing',
#  'sm ac sptv the new jersey devil and the detroit red wing play ice hockey correct or incorrect end reply end sptv',
#  'do you know what mallika sherawat did yesterday find out now lt url gt',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry i ll call later in meeting',
#  'tell where you reached',
#  'yes gauti and sehwag out of odi series',
#  'your gonna have to pick up a burger for yourself on your way home i can t even move pain is killing me',
#  'ha ha ha good joke girl are situation seeker',
#  'it a part of checking iq',
#  'sorry my roommate took forever it ok if i come by now',
#  'ok lar i double check wif da hair dresser already he said wun cut v short he said will cut until i look nice',
#  'a a valued customer i am pleased to advise you that following recent review of your mob no you are awarded with a bonus prize call',
#  'today is song dedicated day which song will u dedicate for me send this to all ur valuable frnds but first rply me',
#  'urgent ur awarded a complimentary trip to eurodisinc trav aco entry or to claim txt dis to morefrmmob shracomorsglsuplt l aj',
#  'did you hear about the new divorce barbie it come with all of ken s stuff',
#  'i plane to give on this month end',
#  'wah lucky man then can save money hee',
#  'finished class where are you',
#  'hi babe im at home now wanna do something xx',
#  'k k where are you how did you performed',
#  'u can call me now',
#  'i am waiting machan call me once you free',
#  'thats cool i am a gentleman and will treat you with dignity and respect',
#  'i like you people very much but am very shy pa',
#  'doe not operate after lt gt or what',
#  'it not the same here still looking for a job how much do ta s earn there',
#  'sorry i ll call later',
#  'k did you call me just now ah',
#  'ok i am on the way to home hi hi',
#  'you will be in the place of that man',
#  'yup next stop',
#  'i call you later don t have network if urgnt sm me',
#  'for real when u getting on yo i only need more ticket and one more jacket and i m done i already used all my multis',
#  'yes i started to send request to make it but pain came back so i m back in bed double coin at the factory too i gotta cash in all my nitros',
#  'i m really not up to it still tonight babe',
#  'ela kano il download come wen ur free',
#  'yeah do don t stand to close tho you ll catch something',
#  'sorry to be a pain is it ok if we meet another night i spent late afternoon in casualty and that mean i haven t done any of y stuff moro and that includes all my time sheet and that sorry',
#  'smile in pleasure smile in pain smile when trouble pours like rain smile when sum hurt u smile becoz someone still love to see u smiling',
#  'please call our customer service representative on between am pm a you have won a guaranteed cash or prize',
#  'havent planning to buy later i check already lido only got show in e afternoon u finish work already',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'watching telugu movie wat abt u',
#  'i see when we finish we have load of loan to pay',
#  'hi wk been ok on hols now yes on for a bit of a run forgot that i have hairdresser appointment at four so need to get home n shower beforehand doe that cause prob for u',
#  'i see a cup of coffee animation',
#  'please don t text me anymore i have nothing else to say',
#  'okay name ur price a long a it legal wen can i pick them up y u ave x am xx',
#  'i m still looking for a car to buy and have not gone the driving test yet',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'wow you re right i didn t mean to do that i guess once i gave up on boston men and changed my search location to nyc something changed cuz on my signin page it still say boston',
#  'umma my life and vava umma love you lot dear',
#  'thanks a lot for your wish on my birthday thanks you for making my birthday truly memorable',
#  'aight i ll hit you up when i get some cash',
#  'how would my ip address test that considering my computer isn t a minecraft server',
#  'i know grumpy old people my mom wa like you better not be lying then again i am always the one to play joke',
#  'dont worry i guess he s busy',
#  'what is the plural of the noun research',
#  'going for dinner msg you after',
#  'i m ok wif it co i like try new thing but i scared u dun like mah co u said not too loud',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'wa ur openin sentence very formal anyway i m fine too juz tt i m eatin too much n puttin on weight haha so anythin special happened',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'you are a winner u have been specially selected receive or a holiday flight inc speak to a live operator claim p min',
#  'goodo yes we must speak friday egg potato ratio for tortilla needed',
#  'hmm my uncle just informed me that he s paying the school directly so pls buy food',
#  'private your account statement for show unredeemed bonus point to claim call identifier code expires',
#  'urgent your mobile no wa awarded bonus caller prize on this is our final try to contact u call from landline box wr c ppm',
#  'here is my new address apple pair all that malarky',
#  'today voda number ending are selected to receive a award if you have a match please call quoting claim code standard rate app',
#  'i am going to sao mu today will be done only at',
#  'predict wat time ll finish buying',
#  'good stuff will do',
#  'just so that you know yetunde hasn t sent money yet i just sent her a text not to bother sending so it over you dont have to involve yourself in anything i shouldn t have imposed anything on you in the first place so for that i apologise',
#  'are you there in room',
#  'hey girl how r u hope u r well me an del r bak again long time no c give me a call sum time from lucyxx',
#  'k k how much doe it cost',
#  'i m home',
#  'dear will call tmorrow pls accomodate',
#  'first answer my question',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country the algarve is in txt ansr to sp tyrone',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network bt txting gravel to nt ec a p msg p',
#  'i only haf msn it s yijue hotmail com',
#  'he is there you call and meet him',
#  'no no i will check all room befor activity',
#  'you ll not rcv any more msg from the chat svc for free hardcore service text go to if u get nothing u must age verify with yr network try again',
#  'got c i lazy to type i forgot in lect i saw a pouch but like not v nice',
#  'k text me when you re on the way',
#  'sir waiting for your mail',
#  'a swt thought nver get tired of doing little thing lovable person coz somtimes those little thing occupy d biggest part in their heart gud ni',
#  'i know you are can you pls open the back',
#  'yes see ya not on the dot',
#  'whats the staff name who is taking class for u',
#  'freemsg why haven t you replied to my text i m randy sexy female and live local luv to hear from u netcollex ltd p per msg reply stop to end',
#  'ummma will call after check in our life will begin from qatar so pls pray very hard',
#  'k i deleted my contact that why',
#  'sindu got job in birla soft',
#  'the wine is flowing and i m i have nevering',
#  'yup i thk cine is better co no need go down plaza mah',
#  'ok ur typical reply',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'you are everywhere dirt on the floor the window even on my shirt and sometimes when i open my mouth you are all that come flowing out i dream of my world without you then half my chore are out too a time of joy for me lot of tv show i ll see but i guess like all thing you just must exist like rain hail and mist and when my time here is done you and i become one',
#  'aaooooright are you at work',
#  'i m leaving my house now',
#  'hello my love what are you doing did you get to that interview today are you you happy are you being a good boy do you think of me are you missing me',
#  'customer service annoncement you have a new year delivery waiting for you please call now to arrange delivery',
#  'you are a winner u have been specially selected receive cash or a holiday flight inc speak to a live operator claim',
#  'keep yourself safe for me because i need you and i miss you already and i envy everyone that see s you in real life',
#  'new car and house for my parent i have only new job in hand',
#  'i m so in love with you i m excited each day i spend with you you make me so happy',
#  'pls stop bootydelious f is inviting you to be her friend reply yes or no see her www sm ac u bootydelious stop send stop frnd to',
#  'bangbabes ur order is on the way u should receive a service msg download ur content if u do not goto wap bangb tv on ur mobile internet service menu',
#  'i place all ur point on e culture module already',
#  'urgent we are trying to contact you last weekend draw show that you have won a prize guaranteed call claim code s valid hr only',
#  'hi frnd which is best way to avoid missunderstding wit our beloved one s',
#  'great escape i fancy the bridge but need her lager see you tomo',
#  'yes it completely in out of form clark also utter waste',
#  'sir i need axis bank account no and bank address',
#  'hmmm thk sure got time to hop ard ya can go free abt muz call u to discus liao',
#  'what time you coming down later',
#  'bloody hell cant believe you forgot my surname mr ill give u a clue it spanish and begin with m',
#  'well i m gonna finish my bath now have a good fine night',
#  'let me know when you ve got the money so carlos can make the call',
#  'u still going to the mall',
#  'turn out my friend are staying for the whole show and won t be back til lt gt so feel free to go ahead and smoke that lt gt worth',
#  'text her if she doesnt reply let me know so i can have her log in',
#  'hi you just spoke to maneesha v we d like to know if you were satisfied with the experience reply toll free with yes or no',
#  'you lifted my hope with the offer of money i am in need especially when the end of the month approach and it hurt my studying anyways have a gr weekend',
#  'lol no u can trust me',
#  'ok i am a gentleman and will treat you with dignity and respect',
#  'he will you guy close',
#  'going on nothing great bye',
#  'hello handsome are you finding that job not being lazy working towards getting back that net for mummy where s my boytoy now doe he miss me',
#  'haha awesome be there in a minute',
#  'please call our customer service representative on freephone between am pm a you have won a guaranteed cash or prize',
#  'have you got xmas radio time if not i will get it now',
#  'i jus reached home i go bathe first but my si using net tell u when she finish k',
#  'are you unique enough find out from th august www areyouunique co uk',
#  'i m sorry i ve joined the league of people that dont keep in touch you mean a great deal to me you have been a friend at all time even at great personal cost do have a great week',
#  'hi finally i completed the course',
#  'it will stop on itself i however suggest she stay with someone that will be able to give or for every stool',
#  'how are you doing hope you ve settled in for the new school year just wishin you a gr day',
#  'gud mrng dear hav a nice day',
#  'did u got that person story',
#  'is your hamster dead hey so tmr i meet you at pm orchard mrt',
#  'hi it kate how is your evening i hope i can see you tomorrow for a bit but i have to bloody babyjontet txt back if u can xxx',
#  'found it enc lt gt where you at',
#  'i sent you lt gt buck',
#  'hello darlin ive finished college now so txt me when u finish if u can love kate xxx',
#  'your account ha been refilled successfully by inr lt decimal gt your keralacircle prepaid account balance is r lt decimal gt your transaction id is kr lt gt',
#  'goodmorning sleeping ga',
#  'u call me alter at ok',
#  'say until like dat i dun buy ericsson oso cannot oredi lar',
#  'a i entered my cabin my pa said happy b day bos i felt special she askd me lunch after lunch she invited me to her apartment we went there',
#  'aight yo dat straight dogg',
#  'you please give u connection today itself before lt decimal gt or refund the bill',
#  'both i shoot big load so get ready',
#  'what s up bruv hope you had a great break do have a rewarding semester',
#  'home so we can always chat',
#  'k k good study well',
#  'yup how noe leh',
#  'sound great are you home now',
#  'finally the match heading towards draw a your prediction',
#  'tired i haven t slept well the past few night',
#  'easy ah sen got selected mean it good',
#  'i have to take exam with march',
#  'yeah you should i think you can use your gt atm now to register not sure but if there s anyway i can help let me know but when you do be sure you are ready',
#  'ok no prob take ur time',
#  'there is o called ubandu which will run without installing in hard disk you can use that o to copy the important file in system and give it to repair shop',
#  'sorry i ll call later',
#  'u say leh of course nothing happen lar not say v romantic jus a bit only lor i thk e nite scenery not so nice leh',
#  'new mobile from must go txt nokia to no collect yours today from only www tc biz optout gbp mtmsg',
#  'would really appreciate if you call me just need someone to talk to',
#  'will u meet ur dream partner soon is ur career off a flyng start find out free txt horo followed by ur star sign e g horo aries',
#  'hey company elama po mudyadhu',
#  'life is more strict than teacher bcoz teacher teach lesson amp then conduct exam but life first conduct exam amp then teach lesson happy morning',
#  'dear good morning now only i am up',
#  'get down in gandhipuram and walk to cross cut road right side lt gt street road and turn at first right',
#  'dear we are going to our rubber place',
#  'sorry battery died yeah i m here',
#  'yes here tv is always available in work place',
#  'text meet someone sexy today u can find a date or even flirt it up to u join just p reply with name age eg sam msg recd thirtyeight penny',
#  'i have printed it oh so lt gt come upstairs',
#  'or ill be a little closer like at the bus stop on the same street',
#  'where are you when wil you reach here',
#  'new theory argument win d situation but loses the person so dont argue with ur friend just kick them amp say i m always correct',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'tomarrow final hearing on my laptop case so i cant',
#  'pleassssssseeeeee tel me v avent done sportsx',
#  'okay no no just shining on that wa meant to be signing but that sound better',
#  'although i told u dat i m into baig face watch now but i really like e watch u gave co it s fr u thanx everything dat u ve done today i m touched',
#  'u don t remember that old commercial',
#  'too late i said i have the website i didn t i have or dont have the slipper',
#  'i asked you to call him now ok',
#  'kallis wont bat in nd inning',
#  'it didnt work again oh ok goodnight then i ll fix and have it ready by the time you wake up you are very dearly missed have a good night sleep',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ranjith cal drpd deeraj and deepak min hold',
#  'wen ur lovable bcums angry wid u dnt take it seriously coz being angry is d most childish n true way of showing deep affection care n luv kettoda manda have nice day da',
#  'what you doing how are you',
#  'ups which is day also and the shipping company that take wks the other way is usps which take a week but when it get to lag you may have to bribe nipost to get your stuff',
#  'i m back lemme know when you re ready',
#  'don t necessarily expect it to be done before you get back though because i m just now headin out',
#  'mmm so yummy babe nice jolt to the suzy',
#  'where are you lover i need you',
#  'we tried to contact you re your reply to our offer of a video handset anytime network min unlimited text camcorder reply or call now',
#  'i m parked next to a mini when are you coming in today do you think',
#  'yup',
#  'anyway i m going shopping on my own now co my si not done yet dun disturb u liao',
#  'my no in luton ring me if ur around h',
#  'hey i am really horny want to chat or see me naked text hot to text charged at pm to unsubscribe text stop',
#  'why you dint come with u',
#  'same wana plan a trip sometme then',
#  'not sure yet still trying to get a hold of him',
#  'ur ringtone service ha changed free credit go to club mobile com to choose content now stop txt club stop to p wk club po box mk wt',
#  'the evo i just had to download flash jealous',
#  'ringtone club get the uk single chart on your mobile each week and choose any top quality ringtone this message is free of charge',
#  'come to mu we re sorting out our narcotic situation',
#  'night ha ended for another day morning ha come in a special way may you smile like the sunny ray and leaf your worry at the blue blue bay',
#  'hmv bonus special pound of genuine hmv voucher to be won just answer easy question play now send hmv to more info www percent real com',
#  'usf i guess might a well take car',
#  'no objection my bf not coming',
#  'thanx',
#  'tell rob to mack his gf in the theater',
#  'awesome i ll see you in a bit',
#  'just sent it so what type of food do you like',
#  'all done all handed in celebration in full swing yet',
#  'you got called a tool',
#  'wen u miss someone the person is definitely special for u but if the person is so special why to miss them just keep in touch gdeve',
#  'ok i asked for money how far',
#  'okie',
#  'yeah i think my usual guy s still passed out from last night if you get ahold of anybody let me know and i ll throw down',
#  'k i might come by tonight then if my class let out early',
#  'ok',
#  'hi baby im cruisin with my girl friend what r u up give me a call in and hour at home if thats alright or fone me on this fone now love jenny xxx',
#  'my life mean a lot to me not because i love my life but because i love the people in my life the world call them friend i call them my world ge',
#  'dear shall mail tonite busy in the street shall update you tonite thing are looking ok varunnathu edukkukayee raksha ollu but a good one in real sense',
#  'hey you told your name to gautham ah',
#  'haf u found him i feel so stupid da v cam wa working',
#  'oops got that bit',
#  'are you this much buzy',
#  'i accidentally deleted the message resend please',
#  't mobile customer you may now claim your free camera phone upgrade a pay go sim card for your loyalty call on offer end thfeb t c s apply',
#  'unless it s a situation where you go gurl would be more appropriate',
#  'hurt me tease me make me cry but in the end of my life when i die plz keep one rose on my grave and say stupid i miss u have a nice day bslvyl',
#  'i cant pick the phone right now pls send a message',
#  'need a coffee run tomo can t believe it s that time of week already',
#  'awesome i remember the last time we got somebody high for the first time with diesel v',
#  'shit that is really shocking and scary cant imagine for a second def up for night out do u think there is somewhere i could crash for night save on taxi',
#  'oh and by the way you do have more food in your fridge want to go out for a meal tonight',
#  'he is a womdarfull actor',
#  'sm ac blind date u rodds is m from aberdeen united kingdom check him out http img sm ac w icmb cktz r no blind date send hide',
#  'yup from what i remb i think should be can book',
#  'jos ask if u wana meet up',
#  'lol yes our friendship is hanging on a thread cause u won t buy stuff',
#  'themob check out our newest selection of content game tone gossip babe and sport keep your mobile fit and funky text wap to',
#  'where are the garage key they aren t on the bookshelf',
#  'today is accept day u accept me a brother sister lover dear best clos lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rply mean enemy',
#  'think ur smart win this week in our weekly quiz text play to now t c winnersclub po box m uz gbp week',
#  'he say he ll give me a call when his friend s got the money but that he s definitely buying before the end of the week',
#  'hi the way i wa with u day is the normal way this is the real me ur unique i hope i know u the rest of mylife hope u find wot wa lost',
#  'you made my day do have a great day too',
#  'k k advance happy pongal',
#  'hmmm guess we can go kb n power yoga haha dunno we can tahan power yoga anot thk got lo oso forgot liao',
#  'not really dude have no friend i m afraid',
#  'december only had your mobile mths you are entitled to update to the latest colour camera mobile for free call the mobile update co free on',
#  'coffee cake i guess',
#  'merry christmas to you too babe i love ya kiss',
#  'hey why dont we just go watch x men and have lunch haha',
#  'cud u tell ppl im gona b a bit l co bus hav gon past co they were full im still waitin pete x',
#  'that would be great we ll be at the guild could meet on bristol road or somewhere will get in touch over weekend our plan take flight have a good week',
#  'no problem how are you doing',
#  'no call message missed call',
#  'hi da how is the today class',
#  'i d say that s a good sign but well you know my track record at reading woman',
#  'cool text me when you re parked',
#  'i m reading the text i just sent you it meant to be a joke so read it in that light',
#  'k k apo k good movie',
#  'maybe i could get book out tomo then return it immediately or something',
#  'call germany for only penny per minute call from a fixed line via access number no prepayment direct access',
#  'any chance you might have had with me evaporated a soon a you violated my privacy by stealing my phone number from your employer s paperwork not cool at all please do not contact me again or i will report you to your supervisor',
#  'valentine day special win over in our quiz and take your partner on the trip of a lifetime send go to now p msg rcvd custcare',
#  'ta daaaaa i am home babe are you still up',
#  'cool so how come you havent been wined and dined before',
#  'just sleeping and surfing',
#  'sorry i ll call later',
#  'u calling me right call my hand phone',
#  'ok that s great thanx a lot',
#  'i take it the post ha come then you must have s of text now happy reading my one from wiv hello caroline at the end is my favourite bless him',
#  'where u been hiding stranger',
#  'am not interested to do like that',
#  'my sister cleared two round in birla soft yesterday',
#  'gudnite tc practice going on',
#  'dis is yijue i jus saw ur mail in case huiming havent sent u my num dis is my num',
#  'one small prestige problem now',
#  'fancy a shag i do interested sextextuk com txt xxuk suzy to txts cost per msg tncs on website x',
#  'just checking in on you really do miss seeing jeremiah do have a great month',
#  'nah can t help you there i ve never had an iphone',
#  'if you re not in my car in an hour and a half i m going apeshit',
#  'today is sorry day if ever i wa angry with you if ever i misbehaved or hurt you plz plz just slap urself bcoz it ur fault i m basically good',
#  'yo you guy ever figure out how much we need for alcohol jay and i are trying to figure out how much we can safely spend on weed',
#  'lt gt ish minute wa minute ago wtf',
#  'thank you for calling forgot to say happy onam to you sirji i am fine here and remembered you when i met an insurance person meet you in qatar insha allah rakhesh ex tata aig who joined tissco tayseer',
#  'congratulation ur awarded of cd voucher or gift guaranteed free entry wkly draw txt music to tncs www ldew com win ppmx age',
#  'ur cash balance is currently pound to maximize ur cash in now send cash to only p msg cc hg suite land row w j hl',
#  'i m an actor when i work i work in the evening and sleep late since i m unemployed at the moment i always sleep late when you re unemployed every day is saturday',
#  'hello just got here st andrew boy it a long way it cold i will keep you posted',
#  'ha ha cool cool chikku chikku db',
#  'oh ok no prob',
#  'check audrey s status right now',
#  'busy here trying to finish for new year i am looking forward to finally meeting you',
#  'good afternoon sunshine how dawn that day are we refreshed and happy to be alive do we breathe in the air and smile i think of you my love a always',
#  'well i know z will take care of me so no worry',
#  'update_now xmas offer latest motorola sonyericsson nokia free bluetooth double min txt on orange call mobileupd on or call optout f q',
#  'here is your discount code rp to stop further message reply stop www regalportfolio co uk customer service',
#  'wat uniform in where get',
#  'cool text me when you re ready',
#  'hello my boytoy geeee i miss you already and i just woke up i wish you were here in bed with me cuddling me i love you',
#  'i will spoil you in bed a well',
#  'i m going for bath will msg you next lt gt min',
#  'i cant keep talking to people if am not sure i can pay them if they agree to price so pls tell me what you want to really buy and how much you are willing to pay',
#  'thanks for your ringtone order reference t you will be charged gbp per week you can unsubscribe at anytime by calling customer service on',
#  'can you say what happen',
#  'you could have seen me i did t recognise you face',
#  'well there s not a lot of thing happening in lindsay on new year sigh some bar in ptbo and the blue heron ha something going',
#  'keep my payasam there if rinu brings',
#  'i taught that ranjith sir called me so only i sm like that becaus he verifying about project prabu told today so only pa dont mistake me',
#  'i guess that s why you re worried you must know that there s a way the body repair itself and i m quite sure you shouldn t worry we ll take it slow first the test they will guide when your ovulation is then just relax nothing you ve said is a reason to worry but i ll keep on followin you up',
#  'yeah sure give me a couple minute to track down my wallet',
#  'hey leave it not a big deal take care',
#  'hey i will be late ah meet you at',
#  'double min and txts month free bluetooth on orange available on sony nokia motorola phone call mobileupd on or call optout n dx',
#  'it took mr owl lick',
#  'customer place i will call you',
#  'mm that time you dont like fun',
#  'mths half price orange line rental latest camera phone free had your phone mths call mobilesdirect free on to update now or stoptxt',
#  'yup having my lunch buffet now u eat already',
#  'huh so late fr dinner',
#  'hey so this sat are we going for the intro pilate only or the kickboxing too',
#  'morning only i can ok',
#  'yes i think so i am in office but my lap is in room i think thats on for the last few day i didnt shut that down',
#  'pick you up bout ish what time are and that going',
#  'from here after the performance award is calculated every two month not for current one month period',
#  'wa actually sleeping and still might when u call back so a text is gr you rock si will send u a text wen i wake',
#  'you are always putting your business out there you put picture of your as on facebook you are one of the most open people i ve ever met why would i think a picture of your room would hurt you make you feel violated',
#  'good evening sir al salam wahleykkum sharing a happy news by the grace of god i got an offer from tayseer tissco and i joined hope you are fine inshah allah meet you sometime rakhesh visitor from india',
#  'hmmm k but i want to change the field quickly da i wanna get system administrator or network administrator',
#  'free ringtone text first to for a poly or text get to for a true tone help after st free tone are x pw to e nd txt stop',
#  'dear how is chechi did you talk to her',
#  'the hair cream ha not been shipped',
#  'none of that s happening til you get here though',
#  'yep the great loxahatchee xmas tree burning of lt gt start in an hour',
#  'haha get used to driving to usf man i know a lot of stoner',
#  'all wa well until slightly disastrous class this pm with my fav darling hope day off ok coffee wld be good a can t stay late tomorrow same time place a always',
#  'hello good week fancy a drink or something later',
#  'headin towards busetop',
#  'message some text missing sender name missing number missing sent date missing missing u a lot thats y everything is missing sent via fullonsms com',
#  'come by our room at some point so we can iron out the plan for this weekend',
#  'co i want it to be your thing',
#  'okies i ll go yan jiu too we can skip ard oso go cine den go mrt one blah blah blah',
#  'bring home some wendy d',
#  'dating service cal l box sk ch',
#  'whatsup there dont u want to sleep',
#  'alright i have a new goal now',
#  'free entry into our weekly competition just text the word win to now t c www txttowin co uk',
#  'alright i ll head out in a few minute text me where to meet you',
#  'send a logo ur lover name joined by a heart txt love name name mobno eg love adam eve to yahoo pobox w wq txtno no ad p',
#  'yes from last week itself i m taking live call',
#  'someone ha contacted our dating service and entered your phone because they fancy you to find out who it is call from a landline pobox n tf p',
#  'siva is in hostel aha',
#  'urgent your mobile number ha been awarded with a prize guaranteed call from land line claim valid hr only',
#  'send this to ur friend and receive something about ur voice how is my speaking expression childish naughty sentiment rowdy ful of attitude romantic shy attractive funny lt gt irritating lt gt lovable reply me',
#  'ok she ll be ok i guess',
#  'aathi where are you dear',
#  'any pain on urination any thing else',
#  'at esplanade do mind giving me a lift co i got no car today',
#  'i wnt to buy a bmw car urgently it vry urgent but hv a shortage of lt gt lac there is no source to arng dis amt lt gt lac thats my prob',
#  'at home watching tv lor',
#  'doe she usually take fifteen fucking minute to respond to a yes or no question',
#  'congrats nokia video camera phone is your call call cost ppm ave call min vary from mobile close post bcm ldn wc n xx',
#  'booked ticket for pongal',
#  'you available now i m like right around hillsborough amp lt gt th',
#  'the message sent is askin for lt gt dollar shoul i pay lt gt or lt gt',
#  'ask g or iouri i ve told the story like ten time already',
#  'how long doe applebees fucking take',
#  'hi hope u get this txt journey hasnt been gd now about min late i think',
#  'but i have to i like to have love and arrange',
#  'yes he is really great bhaji told kallis best cricketer after sachin in world very tough to get out',
#  'you were supposed to wake me up gt',
#  'oic i saw him too but i tot he din c me i found a group liao',
#  'sorry i ll call later',
#  'hey hey werethe monkeespeople say we monkeyaround howdy gorgeous howu doin foundurself a jobyet sausage love jen xxx',
#  'sorry my battery died i can come by but i m only getting a gram for now where s your place',
#  'well done blimey exercise yeah i kinda remember wot that is hmm',
#  'i wont get concentration dear you know you are my mind and everything',
#  'lol have you made plan for new year',
#  'min later k',
#  'hank lotsly',
#  'thanks for this hope you had a good day today',
#  'k k what are detail you want to transfer acc no enough',
#  'ok i will tell her to stay out yeah it been tough but we are optimistic thing will improve this month',
#  'loan for any purpose homeowner tenant welcome have you been previously refused we can still help call free or text back help',
#  'si si i think ill go make those oreo truffle',
#  'look at amy ure a beautiful intelligent woman and i like u a lot i know u don t like me like that so don t worry',
#  'i hope you that s the result of being consistently intelligent and kind start asking him about practicum link and keep your ear open and all the best ttyl',
#  'that call cost which i guess isnt bad miss ya need ya want ya love ya',
#  'going thru a very different feeling wavering decision and coping up with the same is the same individual time will heal everything i believe',
#  'where did u go my phone is gonna die you have to stay in here',
#  'great never been better each day give even more reason to thank god',
#  'upgrdcentre orange customer you may now claim your free camera phone upgrade for your loyalty call now on offer end th july t c s apply opt out available',
#  'sorry i ll call later ok bye',
#  'ok i am on the way to railway',
#  'great princess i love giving and receiving oral doggy style is my fave position how about you i enjoy making love lt gt time per night',
#  'they don t put that stuff on the road to keep it from getting slippery over there',
#  'when are you going to ride your bike',
#  'yup no need i ll jus wait e rain stop',
#  'there are many company tell me the language',
#  'okmail dear dave this is your final notice to collect your tenerife holiday or cash award call from landline tc sae box cw wx ppm',
#  'how long ha it been since you screamed princess',
#  'nothing i meant that once the money enters your account here the bank will remove it flat rate someone transfered lt gt to my account and lt gt dollar got removed so the bank differ and charge also differ be sure you trust the ja person you are sending account detail to co',
#  'want get laid tonight want real dogging location sent direct ur mob join the uk s largest dogging network by txting moan to nyt ec a p msg p',
#  'nice line said by a broken heart plz don t cum more time infront of me other wise once again i ll trust u good t',
#  'ok i m gonna head up to usf in like fifteen minute',
#  'love you aathi love u lot',
#  'tension ah what machi any problem',
#  'k can i pick up another th when you re done',
#  'when re you guy getting back g said you were thinking about not staying for mcr',
#  'almost there see u in a sec',
#  'yo carlos a few friend are already asking me about you you working at all this weekend',
#  'watching tv lor',
#  'thank you baby i cant wait to taste the real thing',
#  'you should change your fb to jaykwon thuglyfe falconerf',
#  'if we win it really no side for long time',
#  'free message activate your free text message by replying to this message with the word free for term condition visit www com',
#  'dear reached railway what happen to you',
#  'depends on quality if you want the type i sent boye faded glory then about if you want ralphs maybe',
#  'i think i ve fixed it can you send a test message',
#  'sorry man my account s dry or i would if you want we could trade back half or i could buy some shit with my credit card',
#  'congrats year special cinema pas for is yours call now c suprman v matrix starwars etc all free bx ip we pm dont miss out',
#  'sorry in meeting i ll call later',
#  'what class of lt gt reunion',
#  'are you free now can i call now',
#  'got meh when',
#  'nope think i will go for it on monday sorry i replied so late',
#  'some of them told accenture is not confirm is it true',
#  'kate jackson rec center before ish right',
#  'dear i have reache room',
#  'fighting with the world is easy u either win or lose bt fightng with some who is close to u is dificult if u lose u lose if u win u still lose',
#  'when can come out',
#  'check with nuerologist',
#  'lolnice i went from a fish to water',
#  'congratulation in this week s competition draw u have won the prize to claim just call b t c stop sm over only ppm',
#  'no it s waiting in e car dat s bored wat co wait outside got nothing do at home can do my stuff or watch tv wat',
#  'maybe westshore or hyde park village the place near my house',
#  'you should know now so how s anthony are you bringing money i ve school fee to pay and rent and stuff like that thats why i need your help a friend in need',
#  'what s the significance',
#  'your opinion about me over jada kusruthi lovable silent spl character not matured stylish simple pls reply',
#  'at the latest g s still there if you can scrounge up some ammo and want to give the new ak a try',
#  'prabha i m soryda realy frm heart i m sory',
#  'lol ok your forgiven',
#  'no jst change tat only',
#  'you are guaranteed the latest nokia phone a gb ipod mp player or a prize txt word collect to no ibhltd ldnw h p mtmsgrcvd',
#  's no competition for him',
#  'boltblue tone for p reply poly or mono eg poly cha cha slide yeah slow jamz toxic come with me or stop more tone txt more',
#  'your credit have been topped up for http www bubbletext com your renewal pin is tgxxrz',
#  'that way transport is less problematic than on sat night by the way if u want to ask n to join my bday feel free but need to know definite no a booking on fri',
#  'usually the person is unconscious that s in child but in adult they may just behave abnormally i ll call you now',
#  'but that s on ebay it might be less elsewhere',
#  'shall i come to get pickle',
#  'were gonna go get some taco',
#  'that s very rude you on campus',
#  'urgent your mobile no wa awarded a bonus caller prize on this is our nd attempt to contact you call box qu',
#  'hi i won t b ard christmas but do enjoy n merry x ma',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'yes how is a pretty lady like you single',
#  'you will recieve your tone within the next hr for term and condition please see channel u teletext pg',
#  'jay say that you re a double faggot',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'what today sunday sunday is holiday so no work',
#  'gudnite tc practice going on',
#  'i ll be late',
#  'i ve not called you in a while this is hoping it wa l r malaria and that you know that we miss you guy i miss ban big so pls give her my love especially have a great day',
#  'good afternoon my love how go that day i hope maybe you got some lead on a job i think of you boytoy and send you a passionate kiss from across the sea',
#  'probably gonna be here for a while see you later tonight lt',
#  'or maybe my fat finger just press all these button and it doesn t know what to do',
#  'ummmmmaah many many happy return of d day my dear sweet heart happy birthday dear',
#  'i am in tirupur da once you started from office call me',
#  'from www applausestore com monthlysubscription p msg max month t csc web age stop txt stop',
#  'a famous quote when you develop the ability to listen to anything unconditionally without losing your temper or self confidence it mean you are married',
#  'but am going to college pa what to do are else ill come there it self pa',
#  'oclock at mine just to bash out a flat plan',
#  'this girl doe not stay in bed this girl doesn t need recovery time id rather pas out while having fun then be cooped up in bed',
#  'then any special there',
#  'i know but you need to get hotel now i just got my invitation but i had to apologise cali is to sweet for me to come to some english bloke s weddin',
#  'sorry that took so long omw now',
#  'wait lt gt min',
#  'ok give me minute i think i see her btw you re my alibi you were cutting my hair the whole time',
#  'imagine you finally get to sink into that bath after i have put you through your pace maybe even having you eat me for a while before i left but also imagine the feel of that cage on your cock surrounded by the bath water reminding you always who owns you enjoy my cuck',
#  'hurry up i ve been weed deficient for like three day',
#  'sure if i get an acknowledgement from you that it s astoundingly tactless and generally faggy to demand a blood oath fo',
#  'ok every night take a warm bath drink a cup of milk and you ll see a work of magic you still need to loose weight just so that you know',
#  'i ll have a look at the frying pan in case it s cheap or a book perhaps no that s silly a frying pan isn t likely to be a book',
#  'o well uv cause mutation sunscreen is like essential thesedays',
#  'having lunch you are not in online why',
#  'i know that my friend already told that',
#  'hi princess thank you for the pic you are very pretty how are you',
#  'aiyo u always c our ex one i dunno abt mei she haven reply first time u reply so fast y so lucky not workin huh got bao by ur sugardad ah gee',
#  'hi msg me i m in office',
#  'thanx e brownie it s v nice',
#  'geeeee i love you so much i can barely stand it',
#  'gent we are trying to contact you last weekend draw show that you won a prize guaranteed call claim code k valid hr only ppm',
#  'fuck babe i miss you already you know can t you let me send you some money towards your net i need you i want you i crave you',
#  'ill call u mrw at ninish with my address that icky american freek wont stop callin me bad jen k eh',
#  'oooh bed ridden ey what are you thinking of',
#  'so anyways you can just go to your gym or whatever my love smile i hope your ok and having a good day babe i miss you so much already',
#  'love it daddy will make you scream with pleasure i am going to slap your as with my dick',
#  'wot u wanna do then missy',
#  'yar lor wait my mum finish sch then have lunch lor i whole morning stay at home clean my room now my room quite clean hee',
#  'do you know where my lab goggles went',
#  'can you open the door',
#  'waiting for your call',
#  'nope i waiting in sch daddy',
#  'you have won cash or a prize to claim call',
#  'i m tired of arguing with you about this week after week do what you want and from now on i ll do the same',
#  'wait me in sch i finish ard',
#  'our mobile number ha won to claim call u back or ring the claim hot line on',
#  'arngd marriage is while u r walkin unfortuntly a snake bite u bt love marriage is dancing in frnt of d snake amp sayin bite me bite me',
#  'huh so early then having dinner outside izzit',
#  'ok anyway no need to change with what you said',
#  'we tried to contact you re your reply to our offer of min textand a new video phone call now or reply for free delivery tomorrow',
#  'my ex wife wa not able to have kid do you want kid one day',
#  'so how s scotland hope you are not over showing your jjc tendency take care live the dream',
#  'tell them u have a headache and just want to use hour of sick time',
#  'i dun thk i ll quit yet hmmm can go jazz yogasana oso can we can go meet em after our lesson den',
#  'pete can you please ring meive hardly gotany credit',
#  'ya srsly better than yi tho',
#  'i m in a meeting call me later at',
#  'for ur chance to win a wkly shopping spree txt shop to t s c s www txt shop com custcare x p wk',
#  'you have been specially selected to receive a pound award call before the line close cost ppm t c apply ag promo',
#  'private your account statement for show un redeemed s i m point call identifier code expires',
#  'you still at grand prix',
#  'i met you a a stranger and choose you a my friend a long a the world stand our friendship never end let be friend forever gud nitz',
#  'i am great how are you',
#  'gud mrng dear have a nice day',
#  'you have an important customer service announcement call freephone now',
# ...
#  'i borrow ur bag ok',
#  'u were outbid by simonwatson on the shinco dvd plyr bid again visit sm ac smsrewards end bid notification reply end out',
#  'where s my boytoy i miss you what happened',
#  'he ha lot of used one babe but the model doesn t help youi have to bring it over and he ll match it up',
#  'also are you bringing galileo or dobby',
#  'then why you not responding',
#  'boo babe u enjoyin yourjob u seemed b gettin on well hunny hope ure ok take care i llspeak u soonlots of loveme xxxx',
#  'good afternoon starshine how s my boytoy doe he crave me yet ache to fuck me sip cappuccino i miss you babe teasing kiss',
#  'on the road so cant txt',
#  'smsservices for yourinclusive text credit pls goto www comuk net login qxj unsubscribe with stop no extra charge help comuk cm ae',
#  'p alfie moon s child in need song on ur mob tell ur m s txt tone charity to for nokias or poly charity for polys zed profit charity',
#  'have a good evening ttyl',
#  'hmm bit and piece lol sigh',
#  'hahaha use your brain dear',
#  'hey you got any mail',
#  'sorry light turned green i meant another friend wanted lt gt worth but he may not be around',
#  'thanks for yesterday sir you have been wonderful hope you enjoyed the burial mojibiola',
#  'u have a secret admirer reveal who think u r so special call to opt out reply reveal stop per msg recd cust care',
#  'hi mate it rv did u hav a nice hol just a message say hello coz haven t sent u in age started driving so stay off road rvx',
#  'dear voucher holder to claim this week offer at you pc please go to http www e tlp co uk expressoffer t c apply to stop text txt stop to',
#  'thank you so much when we skyped wit kz and sura we didnt get the pleasure of your company hope you are good we ve given you ultimatum oh we are countin down to aburo enjoy this is the message i sent day ago',
#  'surely result will offer',
#  'good morning my dear have a great amp successful day',
#  'do you want anytime any network min text and a new video phone for only five pound per week call or reply for delivery tomorrow',
#  'sir i have been late in paying rent for the past few month and had to pay a lt gt charge i felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that s why i didnt speak up i however am in a recession and wont be able to pay the charge this month hence my askin well ahead of month s end can you please help thanks',
#  'we tried to contact you re our offer of new video phone anytime any network min half price rental camcorder call or reply for delivery wed',
#  'last chance claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub remove txt x or stop',
#  'i luv u soo much u don t understand how special u r me ring u morrow luv u xxx',
#  'pls send me a comprehensive mail about who i m paying when and how much',
#  'our prashanthettan s mother passed away last night pray for her and family',
#  'urgent call from your landline your complimentary ibiza holiday or cash await collection sae t c po box sk wp ppm',
#  'k k when are you going',
#  'meanwhile in the shit suite xavier decided to give u lt gt second of warning that samantha wa coming over and is playing jay s guitar to impress her or some shit also i don t think doug realizes i don t live here anymore',
#  'my stomach ha been thru so much trauma i swear i just can t eat i better lose weight',
#  'i am in office whats the matter msg me now i will call you at break',
#  'yeah there s barely enough room for the two of u x ha too many fucking shoe sorry man see you later',
#  'today s offer claim ur worth of discount voucher text yes to now savamob member offer mobile t c sub unsub reply x',
#  'u reach orchard already u wan go buy ticket first',
#  'i am real baby i want to bring out your inner tigress',
#  'no da if you run that it activate the full version da',
#  'ah poor baby hope urfeeling bettersn luv probthat overdose of work hey go careful spk u sn lot of lovejen xxx',
#  'stop the story i ve told him i ve returned it and he s saying i should not re order it',
#  'talk sexy make new friend or fall in love in the world most discreet text dating service just text vip to and see who you could meet',
#  'going to take your babe out',
#  'hai ana tomarrow am coming on morning lt decimal gt ill be there in sathy then we ll go to rto office reply me after came to home',
#  'spoon it is then okay',
#  'did he just say somebody is named tampa',
#  'in work now going have in few min',
#  'your brother is a genius',
#  'sorry i guess whenever i can get a hold of my connection maybe an hour or two i ll text you',
#  'did u find out what time the bus is at coz i need to sort some stuff out',
#  'dude ive been seeing a lotta corvette lately',
#  'congratulation ur awarded either a yr supply of cd from virgin record or a mystery gift guaranteed call t c www smsco net pm approx min',
#  'same here but i consider wall and bunker and shit important just because i never play on peaceful but i guess your place is high enough that it don t matter',
#  'private your account statement for xxxxxx show un redeemed s i m point call identifier code expires',
#  'hello we need some posh bird and chap to user trial prod for champneys can i put you down i need your address and dob asap ta r',
#  'what do u want for xmas how about free text message a new video phone with half price line rental call free now on to find out more',
#  'well am officially in a philosophical hole so if u wanna call am at home ready to be saved',
#  'it going good no problem but still need little experience to understand american customer voice',
#  'i ll text you when i drop x off',
#  'ugh it been a long day i m exhausted just want to cuddle up and take a nap',
#  'talk with yourself atleast once in a day otherwise you will miss your best friend in this world shakespeare shesil lt gt',
#  'shop till u drop is it you either k k cash or travel voucher call now ntt po box cr bt fixedline cost ppm mobile vary',
#  'are you in castor you need to see something',
#  'sunshine quiz wkly q win a top sony dvd player if u know which country liverpool played in mid week txt ansr to sp tyrone',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on',
#  'u have a secret admirer who is looking make contact with u find out who they r reveal who think ur so special call on stopsms',
#  'reminder you have not downloaded the content you have already paid for goto http doit mymoby tv to collect your content',
#  'see i knew giving you a break a few time woul lead to you always wanting to miss curfew i wa gonna gibe you til one but a midnight movie is not gonna get out til after you need to come home you need to getsleep and if anything you need to b studdying ear training',
#  'i love to give massage i use lot of baby oil what is your fave position',
#  'dude we should go sup again',
#  'yoyyooo u know how to change permission for a drive in mac my usb flash drive',
#  'gibbs unsold mike hussey',
#  'i like to talk pa but am not able to i dont know y',
#  'y dun cut too short leh u dun like ah she failed she s quite sad',
#  'you unbelievable faglord',
#  'wife how she knew the time of murder exactly',
#  'why do you ask princess',
#  'i am great princess what are you thinking about me',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie you',
#  'it s ok i noe u re busy but i m really too bored so i msg u i oso dunno wat colour she choose me one',
#  'doesn t g have class early tomorrow and thus shouldn t be trying to smoke at lt gt',
#  'superb thought be grateful that u dont have everything u want that mean u still have an opportunity to be happier tomorrow than u are today',
#  'hope you are having a good week just checking in',
#  'i m used to it i just hope my agent don t drop me since i ve only booked a few thing this year this whole me in boston them in nyc wa an experiment',
#  'thursday night yeah sure thing we ll work it out then',
#  'your free ringtone is waiting to be collected simply text the password mix to to verify get usher and britney fml po box mk h ppw',
#  'probably money worry thing are coming due and i have several outstanding invoice for work i did two and three month ago',
#  'how is it possible to teach you and where',
#  'i wonder if your phone battery went dead i had to tell you i love you babe',
#  'lovely smell on this bus and it ain t tobacco',
#  'we re all getting worried over here derek and taylor have already assumed the worst',
#  'hey what s up charles sorry about the late reply',
#  'all the lastest from stereophonics marley dizzee racal libertine and the stroke win nookii game with flirt click themob wap bookmark or text wap to',
#  'i ll give her once i have it plus she said grinule greet you whenever we speak',
#  'white fudge oreo are in store',
#  'january male sale hot gay chat now cheaper call national rate from p min cheap to p min peak to stop text call p min',
#  'my love how come it took you so long to leave for zaher s i got your word on ym and wa happy to see them but wa sad you had left i miss you',
#  'i am sorry it hurt you',
#  'can t i feel nauseous i m so pissed i didn t eat any sweet all week cause today i wa planning to pig out i wa dieting all week and now i m not hungry',
#  'ok lor but not too early me still having project meeting now',
#  'call me da i am waiting for your call',
#  'i could ask carlos if we could get more if anybody else can chip in',
#  'wa actually about to send you a reminder today have a wonderful weekend',
#  'when people see my msg they think iam addicted to msging they are wrong bcoz they don\\ t know that iam addicted to my sweet friend bslvyl',
#  'hey you gave them your photo when you registered for driving ah tmr wanna meet at yck',
#  'dont talk to him ever ok it my word',
#  'when u wana see it then',
#  'on ma way to school can you pls send me ashley s number',
#  'it shall be fine i have avalarr now will hollalater',
#  'she went to attend another two round today but still did t reach home',
#  'actually i deleted my old website now i m blogging at magicalsongs blogspot com',
#  'k wait chikku il send aftr lt gt min',
#  'but i m on a diet and i ate too many slice of pizza yesterday ugh i m always on a diet',
#  'k i will give my kvb acc detail',
#  'oh all have to come ah',
#  'money you r a lucky winner claim your prize text money over million to give away ppt x normal text rate box w t jy',
#  'i m really sorry i won t b able do this friday hope u can find an alternative hope yr term s going ok',
#  'congratulation ore mo owo re wa enjoy it and i wish you many happy moment to and fro wherever you go',
#  'so do you have samus shoulder yet',
#  'what time you think you ll have it need to know when i should be near campus',
#  'dear matthew please call from a landline your complimentary lux tenerife holiday or cash await collection ppm sae t c box sk xh',
#  'then dun wear jean lor',
#  'since when which side any fever any vomitin',
#  'k k are you in college',
#  'urgent call from landline your complimentary tenerife holiday or cash await collection sae t c box hp yf ppm',
#  'better made up for friday and stuffed myself like a pig yesterday now i feel bleh but at least it not writhing pain kind of bleh',
#  'no we sell it all so we ll have ton if coin then sell our coin to someone thru paypal voila money back in life pocket',
#  'theyre doing it to lot of place only hospital and medical place are safe',
#  'how about getting in touch with folk waiting for company just txt back your name and age to opt in enjoy the community p sm',
#  'and also i ve sorta blown him off a couple time recently so id rather not text him out of the blue looking for weed',
#  'i sent my score to sophas and i had to do secondary application for a few school i think if you are thinking of applying do a research on cost also contact joke ogunrinde her school is one me the less expensive one',
#  'i cant wait to see you how were the photo were useful',
#  'ur cash balance is currently pound to maximize ur cash in now send go to only p msg cc po box tcr w',
#  'hey i booked the kb on sat already what other lesson are we going for ah keep your sat night free we need to meet and confirm our lodging',
#  'chk in ur belovd m dict',
#  'is that what time you want me to come',
#  'awesome lemme know whenever you re around',
#  'shb b ok lor thanx',
#  'beautiful truth against gravity read carefully our heart feel light when someone is in it but it feel very heavy when someone leaf it good night',
#  'also remember to get dobby s bowl from your car',
#  'filthy story and girl waiting for your',
#  'sorry i now then c ur msg yar lor so poor thing but only one night tmr u ll have a brand new room sleep in',
#  'love isn t a decision it s a feeling if we could decide who to love then life would be much simpler but then less magical',
#  'welp apparently he retired',
#  'my sort code is and acc no is the bank is natwest can you reply to confirm i ve sent this to the right person',
#  'where',
#  'u sure u can t take any sick time',
#  'urgent we are trying to contact u today draw show that you have won a prize guaranteed call from land line claim m valid hr only',
#  'watching cartoon listening music amp at eve had to go temple amp church what about u',
#  'yo chad which gymnastics class do you wanna take the site say christian class is full',
#  'are you this much buzy',
#  'or better still can you catch her and let ask her if she can sell lt gt for me',
#  'i am not sure about night menu i know only about noon menu',
#  'what do u want when i come back a beautiful necklace a a token of my heart for you thats what i will give but only to my wife of my liking be that and see no one can give you that dont call me i will wait till i come',
#  'are you willing to go for aptitude class',
#  'it wont b until a trying sort house out is that ok',
#  'yar lor he wan go c horse racing today mah so eat earlier lor i ate chicken rice u',
#  'haha awesome omw back now then',
#  'yup i thk so until e shop close lor',
#  'what is your account number',
#  'eh u send wrongly lar',
#  'hey no i ad a crap nite wa borin without ya boggy with me u boring biatch thanx but u wait til nxt time il ave ya',
#  'ok i shall talk to him',
#  'dont hesitate you know this is the second time she ha had weakness like that so keep i notebook of what she eat and did the day before or if anything changed the day before so that we can be sure it nothing',
#  'hey you can pay with salary de only lt gt',
#  'another month i need chocolate weed and alcohol',
#  'if he started searching he will get job in few day he have great potential and talent',
#  'reckon need to be in town by eightish to walk from carpark',
#  'congrats mobile g videophones r yours call now videochat wid your mate play java game dload polyph music noline rentl',
#  'look at the fuckin time what the fuck you think is up',
#  'yo guess what i just dropped',
#  'carlos say he ll be at mu in lt gt minute',
#  'i m in office now i will call you lt gt min',
#  'geeee i miss you already you know your all i can think about fuck i can t wait till next year when we will be together loving kiss',
#  'yun ah the ubi one say if wan call by tomorrow call look for irene ere only got bus ubi cres ubi tech park ph for st wkg day n',
#  'ugh gotta drive back to sd from la my butt is sore',
#  'th of july',
#  'hi im having the most relaxing time ever we have to get up at am every day wa the party good the other night i get home tomorrow at ish',
#  'up to wan come then come lor but i din c any stripe skirt',
#  'the xmas story is peace the xmas msg is love the xmas miracle is jesus hav a blessed month ahead amp wish u merry xmas',
#  'i can t i don t have her number',
#  'change again it s e one next to escalator',
#  'yetunde i m in class can you not run water on it to make it ok pls now',
#  'not a lot ha happened here feel very quiet beth is at her aunt and charlie is working lot just me and helen in at the mo how have you been',
#  'then wait me at bus stop aft ur lect lar if i dun c then i go get my car then come back n pick',
#  ...]

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
words=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words.append(simple_preprocess(sent))

# %%
words
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'question',
#   'std',
#   'txt',
#   'rate',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'don',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'to',
#   'send',
#   'to',
#   'rcv'],
#  ['even',
#   'my',
#   'brother',
#   'is',
#   'not',
#   'like',
#   'to',
#   'speak',
#   'with',
#   'me',
#   'they',
#   'treat',
#   'me',
#   'like',
#   'aid',
#   'patent'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['winner',
#   'valued',
#   'network',
#   'customer',
#   'you',
#   'have',
#   'been',
#   'selected',
#   'to',
#   'receivea',
#   'prize',
#   'reward',
#   'to',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour',
#   'only'],
#  ['had',
#   'your',
#   'mobile',
#   'month',
#   'or',
#   'more',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'mobile',
#   'with',
#   'camera',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['gonna',
#   'be',
#   'home',
#   'soon',
#   'and',
#   'don',
#   'want',
#   'to',
#   'talk',
#   'about',
#   'this',
#   'stuff',
#   'anymore',
#   'tonight',
#   've',
#   'cried',
#   'enough',
#   'today'],
#  ['six',
#   'chance',
#   'to',
#   'win',
#   'cash',
#   'from',
#   'to',
#   'pound',
#   'txt',
#   'csh',
#   'and',
#   'send',
#   'to',
#   'cost',
#   'day',
#   'day',
#   'tsandcs',
#   'apply',
#   'reply',
#   'hl',
#   'info'],
#  ['urgent',
#   'you',
#   'have',
#   'won',
#   'week',
#   'free',
#   'membership',
#   'in',
#   'our',
#   'prize',
#   'jackpot',
#   'txt',
#   'the',
#   'word',
#   'claim',
#   'to',
#   'no',
#   'www',
#   'dbuk',
#   'net',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ve',
#   'been',
#   'searching',
#   'for',
#   'the',
#   'right',
#   'word',
#   'to',
#   'thank',
#   'you',
#   'for',
#   'this',
#   'breather',
#   'promise',
#   'wont',
#   'take',
#   'your',
#   'help',
#   'for',
#   'granted',
#   'and',
#   'will',
#   'fulfil',
#   'my',
#   'promise',
#   'you',
#   'have',
#   'been',
#   'wonderful',
#   'and',
#   'blessing',
#   'at',
#   'all',
#   'time'],
#  ['have', 'date', 'on', 'sunday', 'with', 'will'],
#  ['to',
#   'use',
#   'your',
#   'credit',
#   'click',
#   'the',
#   'wap',
#   'link',
#   'in',
#   'the',
#   'next',
#   'txt',
#   'message',
#   'or',
#   'click',
#   'here',
#   'http',
#   'wap',
#   'com',
#   'qjkgighjjgcbl'],
#  ['oh', 'watching', 'here'],
#  ['eh',
#   'remember',
#   'how',
#   'spell',
#   'his',
#   'name',
#   'yes',
#   'did',
#   'he',
#   'naughty',
#   'make',
#   'until',
#   'wet'],
#  ['fine',
#   'if',
#   'that',
#   'the',
#   'way',
#   'feel',
#   'that',
#   'the',
#   'way',
#   'it',
#   'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'the',
#   'goal',
#   'team',
#   'news',
#   'txt',
#   'ur',
#   'national',
#   'team',
#   'to',
#   'eg',
#   'england',
#   'to',
#   'try',
#   'wale',
#   'scotland',
#   'txt',
#   'poboxox',
#   'wq'],
#  ['is', 'that', 'seriously', 'how', 'you', 'spell', 'his', 'name'],
#  ['going', 'to', 'try', 'for', 'month', 'ha', 'ha', 'only', 'joking'],
#  ['so', 'pay', 'first', 'lar', 'then', 'when', 'is', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'my',
#   'lunch',
#   'then',
#   'go',
#   'str',
#   'down',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'already'],
#  ['ffffffffff',
#   'alright',
#   'no',
#   'way',
#   'can',
#   'meet',
#   'up',
#   'with',
#   'you',
#   'sooner'],
#  ['just',
#   'forced',
#   'myself',
#   'to',
#   'eat',
#   'slice',
#   'really',
#   'not',
#   'hungry',
#   'tho',
#   'this',
#   'suck',
#   'mark',
#   'is',
#   'getting',
#   'worried',
#   'he',
#   'know',
#   'sick',
#   'when',
#   'turn',
#   'down',
#   'pizza',
#   'lol'],
#  ['lol', 'your', 'always', 'so', 'convincing'],
#  ['did',
#   'you',
#   'catch',
#   'the',
#   'bus',
#   'are',
#   'you',
#   'frying',
#   'an',
#   'egg',
#   'did',
#   'you',
#   'make',
#   'tea',
#   'are',
#   'you',
#   'eating',
#   'your',
#   'mom',
#   'left',
#   'over',
#   'dinner',
#   'do',
#   'you',
#   'feel',
#   'my',
#   'love'],
#  ['back',
#   'amp',
#   'we',
#   're',
#   'packing',
#   'the',
#   'car',
#   'now',
#   'll',
#   'let',
#   'you',
#   'know',
#   'if',
#   'there',
#   'room'],
#  ['ahhh',
#   'work',
#   'vaguely',
#   'remember',
#   'that',
#   'what',
#   'doe',
#   'it',
#   'feel',
#   'like',
#   'lol'],
#  ['wait',
#   'that',
#   'still',
#   'not',
#   'all',
#   'that',
#   'clear',
#   'were',
#   'you',
#   'not',
#   'sure',
#   'about',
#   'me',
#   'being',
#   'sarcastic',
#   'or',
#   'that',
#   'that',
#   'why',
#   'doesn',
#   'want',
#   'to',
#   'live',
#   'with'],
#  ['yeah',
#   'he',
#   'got',
#   'in',
#   'at',
#   'and',
#   'wa',
#   'apologetic',
#   'had',
#   'fallen',
#   'out',
#   'and',
#   'she',
#   'wa',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'and',
#   'he',
#   'got',
#   'caught',
#   'up',
#   'in',
#   'that',
#   'till',
#   'but',
#   'we',
#   'won',
#   'go',
#   'there',
#   'not',
#   'doing',
#   'too',
#   'badly',
#   'cheer',
#   'you'],
#  ['tell', 'me', 'anything', 'about', 'you'],
#  ['for',
#   'fear',
#   'of',
#   'fainting',
#   'with',
#   'the',
#   'of',
#   'all',
#   'that',
#   'housework',
#   'you',
#   'just',
#   'did',
#   'quick',
#   'have',
#   'cuppa'],
#  ['thanks',
#   'for',
#   'your',
#   'subscription',
#   'to',
#   'ringtone',
#   'uk',
#   'your',
#   'mobile',
#   'will',
#   'be',
#   'charged',
#   'month',
#   'please',
#   'confirm',
#   'by',
#   'replying',
#   'yes',
#   'or',
#   'no',
#   'if',
#   'you',
#   'reply',
#   'no',
#   'you',
#   'will',
#   'not',
#   'be',
#   'charged'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'at',
#   'the',
#   'timing',
#   'then',
#   'msg',
#   'again',
#   'xuhui',
#   'going',
#   'to',
#   'learn',
#   'on',
#   'nd',
#   'may',
#   'too',
#   'but',
#   'her',
#   'lesson',
#   'is',
#   'at',
#   'am'],
#  ['oops', 'll', 'let', 'you', 'know', 'when', 'my', 'roommate', 'done'],
#  ['see', 'the', 'letter', 'on', 'my', 'car'],
#  ['anything', 'lor', 'decide'],
#  ['hello',
#   'how',
#   'you',
#   'and',
#   'how',
#   'did',
#   'saturday',
#   'go',
#   'wa',
#   'just',
#   'texting',
#   'to',
#   'see',
#   'if',
#   'you',
#   'decided',
#   'to',
#   'do',
#   'anything',
#   'tomo',
#   'not',
#   'that',
#   'trying',
#   'to',
#   'invite',
#   'myself',
#   'or',
#   'anything'],
#  ['pls',
#   'go',
#   'ahead',
#   'with',
#   'watt',
#   'just',
#   'wanted',
#   'to',
#   'be',
#   'sure',
#   'do',
#   'have',
#   'great',
#   'weekend',
#   'abiola'],
#  ['did',
#   'forget',
#   'to',
#   'tell',
#   'you',
#   'want',
#   'you',
#   'need',
#   'you',
#   'crave',
#   'you',
#   'but',
#   'most',
#   'of',
#   'all',
#   'love',
#   'you',
#   'my',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummy'],
#  ['rodger',
#   'burn',
#   'msg',
#   'we',
#   'tried',
#   'to',
#   'call',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'sm',
#   'for',
#   'free',
#   'nokia',
#   'mobile',
#   'free',
#   'camcorder',
#   'please',
#   'call',
#   'now',
#   'for',
#   'delivery',
#   'tomorrow'],
#  ['who', 'are', 'you', 'seeing'],
#  ['great',
#   'hope',
#   'you',
#   'like',
#   'your',
#   'man',
#   'well',
#   'endowed',
#   'am',
#   'lt',
#   'gt',
#   'inch'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['didn', 'you', 'get', 'hep', 'immunisation', 'in', 'nigeria'],
#  ['fair', 'enough', 'anything', 'going', 'on'],
#  ['yeah',
#   'hopefully',
#   'if',
#   'tyler',
#   'can',
#   'do',
#   'it',
#   'could',
#   'maybe',
#   'ask',
#   'around',
#   'bit'],
#  ['don',
#   'know',
#   'how',
#   'stubborn',
#   'am',
#   'didn',
#   'even',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'hospital',
#   'kept',
#   'telling',
#   'mark',
#   'not',
#   'weak',
#   'sucker',
#   'hospital',
#   'are',
#   'for',
#   'weak',
#   'sucker'],
#  ['what',
#   'you',
#   'thinked',
#   'about',
#   'me',
#   'first',
#   'time',
#   'you',
#   'saw',
#   'me',
#   'in',
#   'class'],
#  ['gram',
#   'usually',
#   'run',
#   'like',
#   'lt',
#   'gt',
#   'half',
#   'eighth',
#   'is',
#   'smarter',
#   'though',
#   'and',
#   'get',
#   'you',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'for',
#   'lt',
#   'gt'],
#  ['fyi',
#   'ha',
#   'ride',
#   'early',
#   'tomorrow',
#   'morning',
#   'but',
#   'he',
#   'crashing',
#   'at',
#   'our',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realized',
#   'that',
#   'you',
#   'were',
#   'so',
#   'embarassed',
#   'by',
#   'your',
#   'accomodations',
#   'thought',
#   'you',
#   'liked',
#   'it',
#   'since',
#   'wa',
#   'doing',
#   'the',
#   'best',
#   'could',
#   'and',
#   'you',
#   'always',
#   'seemed',
#   'so',
#   'happy',
#   'about',
#   'the',
#   'cave',
#   'sorry',
#   'didn',
#   'and',
#   'don',
#   'have',
#   'more',
#   'to',
#   'give',
#   'sorry',
#   'offered',
#   'sorry',
#   'your',
#   'room',
#   'wa',
#   'so',
#   'embarassing'],
#  ['sm',
#   'ac',
#   'sptv',
#   'the',
#   'new',
#   'jersey',
#   'devil',
#   'and',
#   'the',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'or',
#   'incorrect',
#   'end',
#   'reply',
#   'end',
#   'sptv'],
#  ['do',
#   'you',
#   'know',
#   'what',
#   'mallika',
#   'sherawat',
#   'did',
#   'yesterday',
#   'find',
#   'out',
#   'now',
#   'lt',
#   'url',
#   'gt'],
#  ['congrats',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'for',
#   'is',
#   'yours',
#   'call',
#   'now',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'all',
#   'free',
#   'bx',
#   'ip',
#   'we',
#   'pm',
#   'dont',
#   'miss',
#   'out'],
#  ['sorry', 'll', 'call', 'later', 'in', 'meeting'],
#  ['tell', 'where', 'you', 'reached'],
#  ['yes', 'gauti', 'and', 'sehwag', 'out', 'of', 'odi', 'series'],
#  ['your',
#   'gonna',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'burger',
#   'for',
#   'yourself',
#   'on',
#   'your',
#   'way',
#   'home',
#   'can',
#   'even',
#   'move',
#   'pain',
#   'is',
#   'killing',
#   'me'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'are', 'situation', 'seeker'],
#  ['it', 'part', 'of', 'checking', 'iq'],
#  ['sorry',
#   'my',
#   'roommate',
#   'took',
#   'forever',
#   'it',
#   'ok',
#   'if',
#   'come',
#   'by',
#   'now'],
#  ['ok',
#   'lar',
#   'double',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'already',
#   'he',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'he',
#   'said',
#   'will',
#   'cut',
#   'until',
#   'look',
#   'nice'],
#  ['valued',
#   'customer',
#   'am',
#   'pleased',
#   'to',
#   'advise',
#   'you',
#   'that',
#   'following',
#   'recent',
#   'review',
#   'of',
#   'your',
#   'mob',
#   'no',
#   'you',
#   'are',
#   'awarded',
#   'with',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'is',
#   'song',
#   'dedicated',
#   'day',
#   'which',
#   'song',
#   'will',
#   'dedicate',
#   'for',
#   'me',
#   'send',
#   'this',
#   'to',
#   'all',
#   'ur',
#   'valuable',
#   'frnds',
#   'but',
#   'first',
#   'rply',
#   'me'],
#  ['urgent',
#   'ur',
#   'awarded',
#   'complimentary',
#   'trip',
#   'to',
#   'eurodisinc',
#   'trav',
#   'aco',
#   'entry',
#   'or',
#   'to',
#   'claim',
#   'txt',
#   'dis',
#   'to',
#   'morefrmmob',
#   'aj'],
#  ['did',
#   'you',
#   'hear',
#   'about',
#   'the',
#   'new',
#   'divorce',
#   'barbie',
#   'it',
#   'come',
#   'with',
#   'all',
#   'of',
#   'ken',
#   'stuff'],
#  ['plane', 'to', 'give', 'on', 'this', 'month', 'end'],
#  ['wah', 'lucky', 'man', 'then', 'can', 'save', 'money', 'hee'],
#  ['finished', 'class', 'where', 'are', 'you'],
#  ['hi', 'babe', 'im', 'at', 'home', 'now', 'wanna', 'do', 'something', 'xx'],
#  ['where', 'are', 'you', 'how', 'did', 'you', 'performed'],
#  ['can', 'call', 'me', 'now'],
#  ['am', 'waiting', 'machan', 'call', 'me', 'once', 'you', 'free'],
#  ['thats',
#   'cool',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['like', 'you', 'people', 'very', 'much', 'but', 'am', 'very', 'shy', 'pa'],
#  ['doe', 'not', 'operate', 'after', 'lt', 'gt', 'or', 'what'],
#  ['it',
#   'not',
#   'the',
#   'same',
#   'here',
#   'still',
#   'looking',
#   'for',
#   'job',
#   'how',
#   'much',
#   'do',
#   'ta',
#   'earn',
#   'there'],
#  ['sorry', 'll', 'call', 'later'],
#  ['did', 'you', 'call', 'me', 'just', 'now', 'ah'],
#  ['ok', 'am', 'on', 'the', 'way', 'to', 'home', 'hi', 'hi'],
#  ['you', 'will', 'be', 'in', 'the', 'place', 'of', 'that', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'you', 'later', 'don', 'have', 'network', 'if', 'urgnt', 'sm', 'me'],
#  ['for',
#   'real',
#   'when',
#   'getting',
#   'on',
#   'yo',
#   'only',
#   'need',
#   'more',
#   'ticket',
#   'and',
#   'one',
#   'more',
#   'jacket',
#   'and',
#   'done',
#   'already',
#   'used',
#   'all',
#   'my',
#   'multis'],
#  ['yes',
#   'started',
#   'to',
#   'send',
#   'request',
#   'to',
#   'make',
#   'it',
#   'but',
#   'pain',
#   'came',
#   'back',
#   'so',
#   'back',
#   'in',
#   'bed',
#   'double',
#   'coin',
#   'at',
#   'the',
#   'factory',
#   'too',
#   'gotta',
#   'cash',
#   'in',
#   'all',
#   'my',
#   'nitros'],
#  ['really', 'not', 'up', 'to', 'it', 'still', 'tonight', 'babe'],
#  ['ela', 'kano', 'il', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah',
#   'do',
#   'don',
#   'stand',
#   'to',
#   'close',
#   'tho',
#   'you',
#   'll',
#   'catch',
#   'something'],
#  ['sorry',
#   'to',
#   'be',
#   'pain',
#   'is',
#   'it',
#   'ok',
#   'if',
#   'we',
#   'meet',
#   'another',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'in',
#   'casualty',
#   'and',
#   'that',
#   'mean',
#   'haven',
#   'done',
#   'any',
#   'of',
#   'stuff',
#   'moro',
#   'and',
#   'that',
#   'includes',
#   'all',
#   'my',
#   'time',
#   'sheet',
#   'and',
#   'that',
#   'sorry'],
#  ['smile',
#   'in',
#   'pleasure',
#   'smile',
#   'in',
#   'pain',
#   'smile',
#   'when',
#   'trouble',
#   'pours',
#   'like',
#   'rain',
#   'smile',
#   'when',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someone',
#   'still',
#   'love',
#   'to',
#   'see',
#   'smiling'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['havent',
#   'planning',
#   'to',
#   'buy',
#   'later',
#   'check',
#   'already',
#   'lido',
#   'only',
#   'got',
#   'show',
#   'in',
#   'afternoon',
#   'finish',
#   'work',
#   'already'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watching', 'telugu', 'movie', 'wat', 'abt'],
#  ['see',
#   'when',
#   'we',
#   'finish',
#   'we',
#   'have',
#   'load',
#   'of',
#   'loan',
#   'to',
#   'pay'],
#  ['hi',
#   'wk',
#   'been',
#   'ok',
#   'on',
#   'hols',
#   'now',
#   'yes',
#   'on',
#   'for',
#   'bit',
#   'of',
#   'run',
#   'forgot',
#   'that',
#   'have',
#   'hairdresser',
#   'appointment',
#   'at',
#   'four',
#   'so',
#   'need',
#   'to',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'doe',
#   'that',
#   'cause',
#   'prob',
#   'for'],
#  ['see', 'cup', 'of', 'coffee', 'animation'],
#  ['please',
#   'don',
#   'text',
#   'me',
#   'anymore',
#   'have',
#   'nothing',
#   'else',
#   'to',
#   'say'],
#  ['okay',
#   'name',
#   'ur',
#   'price',
#   'long',
#   'it',
#   'legal',
#   'wen',
#   'can',
#   'pick',
#   'them',
#   'up',
#   'ave',
#   'am',
#   'xx'],
#  ['still',
#   'looking',
#   'for',
#   'car',
#   'to',
#   'buy',
#   'and',
#   'have',
#   'not',
#   'gone',
#   'the',
#   'driving',
#   'test',
#   'yet'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['wow',
#   'you',
#   're',
#   'right',
#   'didn',
#   'mean',
#   'to',
#   'do',
#   'that',
#   'guess',
#   'once',
#   'gave',
#   'up',
#   'on',
#   'boston',
#   'men',
#   'and',
#   'changed',
#   'my',
#   'search',
#   'location',
#   'to',
#   'nyc',
#   'something',
#   'changed',
#   'cuz',
#   'on',
#   'my',
#   'signin',
#   'page',
#   'it',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'my', 'life', 'and', 'vava', 'umma', 'love', 'you', 'lot', 'dear'],
#  ['thanks',
#   'lot',
#   'for',
#   'your',
#   'wish',
#   'on',
#   'my',
#   'birthday',
#   'thanks',
#   'you',
#   'for',
#   'making',
#   'my',
#   'birthday',
#   'truly',
#   'memorable'],
#  ['aight', 'll', 'hit', 'you', 'up', 'when', 'get', 'some', 'cash'],
#  ['how',
#   'would',
#   'my',
#   'ip',
#   'address',
#   'test',
#   'that',
#   'considering',
#   'my',
#   'computer',
#   'isn',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpy',
#   'old',
#   'people',
#   'my',
#   'mom',
#   'wa',
#   'like',
#   'you',
#   'better',
#   'not',
#   'be',
#   'lying',
#   'then',
#   'again',
#   'am',
#   'always',
#   'the',
#   'one',
#   'to',
#   'play',
#   'joke'],
#  ['dont', 'worry', 'guess', 'he', 'busy'],
#  ['what', 'is', 'the', 'plural', 'of', 'the', 'noun', 'research'],
#  ['going', 'for', 'dinner', 'msg', 'you', 'after'],
#  ['ok',
#   'wif',
#   'it',
#   'co',
#   'like',
#   'try',
#   'new',
#   'thing',
#   'but',
#   'scared',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'not',
#   'too',
#   'loud'],
#  ['gent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentence',
#   'very',
#   'formal',
#   'anyway',
#   'fine',
#   'too',
#   'juz',
#   'tt',
#   'eatin',
#   'too',
#   'much',
#   'puttin',
#   'on',
#   'weight',
#   'haha',
#   'so',
#   'anythin',
#   'special',
#   'happened'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim',
#   'min'],
#  ['goodo',
#   'yes',
#   'we',
#   'must',
#   'speak',
#   'friday',
#   'egg',
#   'potato',
#   'ratio',
#   'for',
#   'tortilla',
#   'needed'],
#  ['hmm',
#   'my',
#   'uncle',
#   'just',
#   'informed',
#   'me',
#   'that',
#   'he',
#   'paying',
#   'the',
#   'school',
#   'directly',
#   'so',
#   'pls',
#   'buy',
#   'food'],
#  ['private',
#   'your',
#   'account',
#   'statement',
#   'for',
#   'show',
#   'unredeemed',
#   'bonus',
#   'point',
#   'to',
#   'claim',
#   'call',
#   'identifier',
#   'code',
#   'expires'],
#  ['urgent',
#   'your',
#   'mobile',
#   'no',
#   'wa',
#   'awarded',
#   'bonus',
#   'caller',
#   'prize',
#   'on',
#   'this',
#   'is',
#   'our',
#   'final',
#   'try',
#   'to',
#   'contact',
#   'call',
#   'from',
#   'landline',
#   'box',
#   'wr',
#   'ppm'],
#  ['here',
#   'is',
#   'my',
#   'new',
#   'address',
#   'apple',
#   'pair',
#   'all',
#   'that',
#   'malarky'],
#  ['today',
#   'voda',
#   'number',
#   'ending',
#   'are',
#   'selected',
#   'to',
#   'receive',
#   'award',
#   'if',
#   'you',
#   'have',
#   'match',
#   'please',
#   'call',
#   'quoting',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['am',
#   'going',
#   'to',
#   'sao',
#   'mu',
#   'today',
#   'will',
#   'be',
#   'done',
#   'only',
#   'at'],
#  ['predict', 'wat', 'time', 'll', 'finish', 'buying'],
#  ['good', 'stuff', 'will', 'do'],
#  ['just',
#   'so',
#   'that',
#   'you',
#   'know',
#   'yetunde',
#   'hasn',
#   'sent',
#   'money',
#   'yet',
#   'just',
#   'sent',
#   'her',
#   'text',
#   'not',
#   'to',
#   'bother',
#   'sending',
#   'so',
#   'it',
#   'over',
#   'you',
#   'dont',
#   'have',
#   'to',
#   'involve',
#   'yourself',
#   'in',
#   'anything',
#   'shouldn',
#   'have',
#   'imposed',
#   'anything',
#   'on',
#   'you',
#   'in',
#   'the',
#   'first',
#   'place',
#   'so',
#   'for',
#   'that',
#   'apologise'],
#  ['are', 'you', 'there', 'in', 'room'],
#  ['hey',
#   'girl',
#   'how',
#   'hope',
#   'well',
#   'me',
#   'an',
#   'del',
#   'bak',
#   'again',
#   'long',
#   'time',
#   'no',
#   'give',
#   'me',
#   'call',
#   'sum',
#   'time',
#   'from',
#   'lucyxx'],
#  ['how', 'much', 'doe', 'it', 'cost'],
#  ['home'],
#  ['dear', 'will', 'call', 'tmorrow', 'pls', 'accomodate'],
#  ['first', 'answer', 'my', 'question'],
#  ['sunshine',
#   'quiz',
#   'wkly',
#   'win',
#   'top',
#   'sony',
#   'dvd',
#   'player',
#   'if',
#   'know',
#   'which',
#   'country',
#   'the',
#   'algarve',
#   'is',
#   'in',
#   'txt',
#   'ansr',
#   'to',
#   'sp',
#   'tyrone'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dogging',
#   'location',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'the',
#   'uk',
#   'largest',
#   'dogging',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'to',
#   'nt',
#   'ec',
#   'msg'],
#  ['only', 'haf', 'msn', 'it', 'yijue', 'hotmail', 'com'],
#  ['he', 'is', 'there', 'you', 'call', 'and', 'meet', 'him'],
#  ['no', 'no', 'will', 'check', 'all', 'room', 'befor', 'activity'],
#  ['you',
#   'll',
#   'not',
#   'rcv',
#   'any',
#   'more',
#   'msg',
#   'from',
#   'the',
#   'chat',
#   'svc',
#   'for',
#   'free',
#   'hardcore',
#   'service',
#   'text',
#   'go',
#   'to',
#   'if',
#   'get',
#   'nothing',
#   'must',
#   'age',
#   'verify',
#   'with',
#   'yr',
#   'network',
#   'try',
#   'again'],
#  ['got',
#   'lazy',
#   'to',
#   'type',
#   'forgot',
#   'in',
#   'lect',
#   'saw',
#   'pouch',
#   'but',
#   'like',
#   'not',
#   'nice'],
#  ['text', 'me', 'when', 'you', 're', 'on', 'the', 'way'],
#  ['sir', 'waiting', 'for', 'your', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tired',
#   'of',
#   'doing',
#   'little',
#   'thing',
#   'lovable',
#   'person',
#   'coz',
#   'somtimes',
#   'those',
#   'little',
#   'thing',
#   'occupy',
#   'biggest',
#   'part',
#   'in',
#   'their',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'you', 'are', 'can', 'you', 'pls', 'open', 'the', 'back'],
#  ['yes', 'see', 'ya', 'not', 'on', 'the', 'dot'],
#  ['whats', 'the', 'staff', 'name', 'who', 'is', 'taking', 'class', 'for'],
#  ['freemsg',
#   'why',
#   'haven',
#   'you',
#   'replied',
#   'to',
#   'my',
#   'text',
#   'randy',
#   'sexy',
#   'female',
#   'and',
#   'live',
#   'local',
#   'luv',
#   'to',
#   'hear',
#   'from',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'reply',
#   'stop',
#   'to',
#   'end'],
#  ['ummma',
#   'will',
#   'call',
#   'after',
#   'check',
#   'in',
#   'our',
#   'life',
#   'will',
#   'begin',
#   'from',
#   'qatar',
#   'so',
#   'pls',
#   'pray',
#   'very',
#   'hard'],
#  ['deleted', 'my', 'contact', 'that', 'why'],
#  ['sindu', 'got', 'job', 'in', 'birla', 'soft'],
#  ['the', 'wine', 'is', 'flowing', 'and', 'have', 'nevering'],
#  ['yup',
#   'thk',
#   'cine',
#   'is',
#   'better',
#   'co',
#   'no',
#   'need',
#   'go',
#   'down',
#   'plaza',
#   'mah'],
#  ['ok', 'ur', 'typical', 'reply'],
#  ['per',
#   'your',
#   'request',
#   'melle',
#   'melle',
#   'oru',
#   'minnaminunginte',
#   'nurungu',
#   'vettam',
#   'ha',
#   'been',
#   'set',
#   'your',
#   'callertune',
#   'for',
#   'all',
#   'caller',
#   'press',
#   'to',
#   'copy',
#   'your',
#   'friend',
#   'callertune'],
#  ['you',
#   'are',
#   'everywhere',
#   'dirt',
#   'on',
#   'the',
#   'floor',
#   'the',
#   'window',
#   'even',
#   'on',
#   'my',
#   'shirt',
#   'and',
#   'sometimes',
#   'when',
#   'open',
#   'my',
#   'mouth',
#   'you',
#   'are',
#   'all',
#   'that',
#   'come',
#   'flowing',
#   'out',
#   'dream',
#   'of',
#   'my',
#   'world',
#   'without',
#   'you',
#   'then',
#   'half',
#   'my',
#   'chore',
#   'are',
#   'out',
#   'too',
#   'time',
#   'of',
#   'joy',
#   'for',
#   'me',
#   'lot',
#   'of',
#   'tv',
#   'show',
#   'll',
#   'see',
#   'but',
#   'guess',
#   'like',
#   'all',
#   'thing',
#   'you',
#   'just',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'and',
#   'mist',
#   'and',
#   'when',
#   'my',
#   'time',
#   'here',
#   'is',
#   'done',
#   'you',
#   'and',
#   'become',
#   'one'],
#  ['aaooooright', 'are', 'you', 'at', 'work'],
#  ['leaving', 'my', 'house', 'now'],
#  ['hello',
#   'my',
#   'love',
#   'what',
#   'are',
#   'you',
#   'doing',
#   'did',
#   'you',
#   'get',
#   'to',
#   'that',
#   'interview',
#   'today',
#   'are',
#   'you',
#   'you',
#   'happy',
#   'are',
#   'you',
#   'being',
#   'good',
#   'boy',
#   'do',
#   'you',
#   'think',
#   'of',
#   'me',
#   'are',
#   'you',
#   'missing',
#   'me'],
#  ['customer',
#   'service',
#   'annoncement',
#   'you',
#   'have',
#   'new',
#   'year',
#   'delivery',
#   'waiting',
#   'for',
#   'you',
#   'please',
#   'call',
#   'now',
#   'to',
#   'arrange',
#   'delivery'],
#  ['you',
#   'are',
#   'winner',
#   'have',
#   'been',
#   'specially',
#   'selected',
#   'receive',
#   'cash',
#   'or',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'to',
#   'live',
#   'operator',
#   'claim'],
#  ['keep',
#   'yourself',
#   'safe',
#   'for',
#   'me',
#   'because',
#   'need',
#   'you',
#   'and',
#   'miss',
#   'you',
#   'already',
#   'and',
#   'envy',
#   'everyone',
#   'that',
#   'see',
#   'you',
#   'in',
#   'real',
#   'life'],
#  ['new',
#   'car',
#   'and',
#   'house',
#   'for',
#   'my',
#   'parent',
#   'have',
#   'only',
#   'new',
#   'job',
#   'in',
#   'hand'],
#  ['so',
#   'in',
#   'love',
#   'with',
#   'you',
#   'excited',
#   'each',
#   'day',
#   'spend',
#   'with',
#   'you',
#   'you',
#   'make',
#   'me',
#   'so',
#   'happy'],
#  ['pls',
#   'stop',
#   'bootydelious',
#   'is',
#   'inviting',
#   'you',
#   'to',
#   'be',
#   'her',
#   'friend',
#   'reply',
#   'yes',
#   'or',
#   'no',
#   'see',
#   'her',
#   'www',
#   'sm',
#   'ac',
#   'bootydelious',
#   'stop',
#   'send',
#   'stop',
#   'frnd',
#   'to'],
#  ['bangbabes',
#   'ur',
#   'order',
#   'is',
#   'on',
#   'the',
#   'way',
#   'should',
#   'receive',
#   'service',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'if',
#   'do',
#   'not',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'on',
#   'ur',
#   'mobile',
#   'internet',
#   'service',
#   'menu'],
#  ['place', 'all', 'ur', 'point', 'on', 'culture', 'module', 'already'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'you',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hr',
#   'only'],
#  ['hi',
#   'frnd',
#   'which',
#   'is',
#   'best',
#   'way',
#   'to',
#   'avoid',
#   'missunderstding',
#   'wit',
#   'our',
#   'beloved',
#   'one'],
#  ['great',
#   'escape',
#   'fancy',
#   'the',
#   'bridge',
#   'but',
#   'need',
#   'her',
#   'lager',
#   'see',
#   'you',
#   'tomo'],
#  ['yes',
#   'it',
#   'completely',
#   'in',
#   'out',
#   'of',
#   'form',
#   'clark',
#   'also',
#   'utter',
#   'waste'],
#  ['sir', 'need', 'axis', 'bank', 'account', 'no', 'and', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'to',
#   'hop',
#   'ard',
#   'ya',
#   'can',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'to',
#   'discus',
#   'liao'],
#  ['what', 'time', 'you', 'coming', 'down', 'later'],
#  ['bloody',
#   'hell',
#   'cant',
#   'believe',
#   'you',
#   'forgot',
#   'my',
#   'surname',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'it',
#   'spanish',
#   'and',
#   'begin',
#   'with'],
#  ['well',
#   'gonna',
#   'finish',
#   'my',
#   'bath',
#   'now',
#   'have',
#   'good',
#   'fine',
#   'night'],
#  ['let',
#   'me',
#   'know',
#   'when',
#   'you',
#   've',
#   'got',
#   'the',
#   'money',
#   'so',
#   'carlos',
#   'can',
#   'make',
#   'the',
#   'call'],
#  ['still', 'going', 'to', 'the', 'mall'],
#  ['turn',
#   'out',
#   'my',
#   'friend',
#   'are',
#   'staying',
#   'for',
#   'the',
#   'whole',
#   'show',
#   'and',
#   'won',
#   'be',
#   'back',
#   'til',
#   'lt',
#   'gt',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'go',
#   'ahead',
#   'and',
#   'smoke',
#   'that',
#   'lt',
#   'gt',
#   'worth'],
#  ['text',
#   'her',
#   'if',
#   'she',
#   'doesnt',
#   'reply',
#   'let',
#   'me',
#   'know',
#   'so',
#   'can',
#   'have',
#   'her',
#   'log',
#   'in'],
#  ['hi',
#   'you',
#   'just',
#   'spoke',
#   'to',
#   'maneesha',
#   'we',
#   'like',
#   'to',
#   'know',
#   'if',
#   'you',
#   'were',
#   'satisfied',
#   'with',
#   'the',
#   'experience',
#   'reply',
#   'toll',
#   'free',
#   'with',
#   'yes',
#   'or',
#   'no'],
#  ['you',
#   'lifted',
#   'my',
#   'hope',
#   'with',
#   'the',
#   'offer',
#   'of',
#   'money',
#   'am',
#   'in',
#   'need',
#   'especially',
#   'when',
#   'the',
#   'end',
#   'of',
#   'the',
#   'month',
#   'approach',
#   'and',
#   'it',
#   'hurt',
#   'my',
#   'studying',
#   'anyways',
#   'have',
#   'gr',
#   'weekend'],
#  ['lol', 'no', 'can', 'trust', 'me'],
#  ['ok',
#   'am',
#   'gentleman',
#   'and',
#   'will',
#   'treat',
#   'you',
#   'with',
#   'dignity',
#   'and',
#   'respect'],
#  ['he', 'will', 'you', 'guy', 'close'],
#  ['going', 'on', 'nothing', 'great', 'bye'],
#  ['hello',
#   'handsome',
#   'are',
#   'you',
#   'finding',
#   'that',
#   'job',
#   'not',
#   'being',
#   'lazy',
#   'working',
#   'towards',
#   'getting',
#   'back',
#   'that',
#   'net',
#   'for',
#   'mummy',
#   'where',
#   'my',
#   'boytoy',
#   'now',
#   'doe',
#   'he',
#   'miss',
#   'me'],
#  ['haha', 'awesome', 'be', 'there', 'in', 'minute'],
#  ['please',
#   'call',
#   'our',
#   'customer',
#   'service',
#   'representative',
#   'on',
#   'freephone',
#   'between',
#   'am',
#   'pm',
#   'you',
#   'have',
#   'won',
#   'guaranteed',
#   'cash',
#   'or',
#   'prize'],
#  ['have',
#   'you',
#   'got',
#   'xmas',
#   'radio',
#   'time',
#   'if',
#   'not',
#   'will',
#   'get',
#   'it',
#   'now'],
#  ['jus',
#   'reached',
#   'home',
#   'go',
#   'bathe',
#   'first',
#   'but',
#   'my',
#   'si',
#   'using',
#   'net',
#   'tell',
#   'when',
#   'she',
#   'finish'],
#  ['are',
#   'you',
#   'unique',
#   'enough',
#   'find',
#   'out',
#   'from',
#   'th',
#   'august',
#   'www',
#   'areyouunique',
#   'co',
#   'uk'],
#  ['sorry',
#   've',
#   'joined',
#   'the',
#   'league',
#   'of',
#   'people',
#   'that',
#   'dont',
#   'keep',
#   'in',
#   'touch',
#   'you',
#   'mean',
#   'great',
#   'deal',
#   'to',
#   'me',
#   'you',
#   'have',
#   'been',
#   'friend',
#   'at',
#   'all',
#   'time',
#   'even',
#   'at',
#   'great',
#   'personal',
#   'cost',
#   'do',
#   'have',
#   'great',
#   'week'],
#  ['hi', 'finally', 'completed', 'the', 'course'],
#  ['it',
#   'will',
#   'stop',
#   'on',
#   'itself',
#   'however',
#   'suggest',
#   'she',
#   'stay',
#   'with',
#   'someone',
#   'that',
#   'will',
#   'be',
#   'able',
#   'to',
#   'give',
#   'or',
#   'for',
#   'every',
#   'stool'],
#  ['how',
#   'are',
#   'you',
#   'doing',
#   'hope',
#   'you',
#   've',
#   'settled',
#   'in',
#   'for',
#   'the',
#   'new',
#   'school',
#   'year',
#   'just',
#   'wishin',
#   'you',
#   'gr',
#   'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['did', 'got', 'that', 'person', 'story'],
#  ['is',
#   'your',
#   'hamster',
#   'dead',
#   'hey',
#   'so',
#   'tmr',
#   'meet',
#   'you',
#   'at',
#   'pm',
#   'orchard',
#   'mrt'],
#  ['hi',
#   'it',
#   'kate',
#   'how',
#   'is',
#   'your',
#   'evening',
#   'hope',
#   'can',
#   'see',
#   'you',
#   'tomorrow',
#   'for',
#   'bit',
#   'but',
#   'have',
#   'to',
#   'bloody',
#   'babyjontet',
#   'txt',
#   'back',
#   'if',
#   'can',
#   'xxx'],
#  ['found', 'it', 'enc', 'lt', 'gt', 'where', 'you', 'at'],
#  ['sent', 'you', 'lt', 'gt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finished',
#   'college',
#   'now',
#   'so',
#   'txt',
#   'me',
#   'when',
#   'finish',
#   'if',
#   'can',
#   'love',
#   'kate',
#   'xxx'],
#  ['your',
#   'account',
#   'ha',
#   'been',
#   'refilled',
#   'successfully',
#   'by',
#   'inr',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'keralacircle',
#   'prepaid',
#   'account',
#   'balance',
#   'is',
#   'lt',
#   'decimal',
#   'gt',
#   'your',
#   'transaction',
#   'id',
#   'is',
#   'kr',
#   'lt',
#   'gt'],
#  ['goodmorning', 'sleeping', 'ga'],
#  ['call', 'me', 'alter', 'at', 'ok'],
#  ['say',
#   'until',
#   'like',
#   'dat',
#   'dun',
#   'buy',
#   'ericsson',
#   'oso',
#   'cannot',
#   'oredi',
#   'lar'],
#  ['entered',
#   'my',
#   'cabin',
#   'my',
#   'pa',
#   'said',
#   'happy',
#   'day',
#   'bos',
#   'felt',
#   'special',
#   'she',
#   'askd',
#   'me',
#   'lunch',
#   'after',
#   'lunch',
#   'she',
#   'invited',
#   'me',
#   'to',
#   'her',
#   'apartment',
#   'we',
#   'went',
#   'there'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['you',
#   'please',
#   'give',
#   'connection',
#   'today',
#   'itself',
#   'before',
#   'lt',
#   'decimal',
#   'gt',
#   'or',
#   'refund',
#   'the',
#   'bill'],
#  ['both', 'shoot', 'big', 'load', 'so', 'get', 'ready'],
#  ['what',
#   'up',
#   'bruv',
#   'hope',
#   'you',
#   'had',
#   'great',
#   'break',
#   'do',
#   'have',
#   'rewarding',
#   'semester'],
#  ['home', 'so', 'we', 'can', 'always', 'chat'],
#  ['good', 'study', 'well'],
#  ['yup', 'how', 'noe', 'leh'],
#  ['sound', 'great', 'are', 'you', 'home', 'now'],
#  ['finally',
#   'the',
#   'match',
#   'heading',
#   'towards',
#   'draw',
#   'your',
#   'prediction'],
#  ['tired', 'haven', 'slept', 'well', 'the', 'past', 'few', 'night'],
#  ['easy', 'ah', 'sen', 'got', 'selected', 'mean', 'it', 'good'],
#  ['have', 'to', 'take', 'exam', 'with', 'march'],
#  ['yeah',
#   'you',
#   'should',
#   'think',
#   'you',
#   'can',
#   'use',
#   'your',
#   'gt',
#   'atm',
#   'now',
#   'to',
#   'register',
#   'not',
#   'sure',
#   'but',
#   'if',
#   'there',
#   'anyway',
#   'can',
#   'help',
#   'let',
#   'me',
#   'know',
#   'but',
#   'when',
#   'you',
#   'do',
#   'be',
#   'sure',
#   'you',
#   'are',
#   'ready'],
#  ['ok', 'no', 'prob', 'take', 'ur', 'time'],
#  ['there',
#   'is',
#   'called',
#   'ubandu',
#   'which',
#   'will',
#   'run',
#   'without',
#   'installing',
#   'in',
#   'hard',
#   'disk',
#   'you',
#   'can',
#   'use',
#   'that',
#   'to',
#   'copy',
#   'the',
#   'important',
#   'file',
#   'in',
#   'system',
#   'and',
#   'give',
#   'it',
#   'to',
#   'repair',
#   'shop'],
#  ['sorry', 'll', 'call', 'later'],
#  ['say',
#   'leh',
#   'of',
#   'course',
#   'nothing',
#   'happen',
#   'lar',
#   'not',
#   'say',
#   'romantic',
#   'jus',
#   'bit',
#   'only',
#   'lor',
#   'thk',
#   'nite',
#   'scenery',
#   'not',
#   'so',
#   'nice',
#   'leh'],
#  ['new',
#   'mobile',
#   'from',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'to',
#   'no',
#   'collect',
#   'yours',
#   'today',
#   'from',
#   'only',
#   'www',
#   'tc',
#   'biz',
#   'optout',
#   'gbp',
#   'mtmsg'],
#  ['would',
#   'really',
#   'appreciate',
#   'if',
#   'you',
#   'call',
#   'me',
#   'just',
#   'need',
#   'someone',
#   'to',
#   'talk',
#   'to'],
#  ['will',
#   'meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'is',
#   'ur',
#   'career',
#   'off',
#   'flyng',
#   'start',
#   'find',
#   'out',
#   'free',
#   'txt',
#   'horo',
#   'followed',
#   'by',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'aries'],
#  ['hey', 'company', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'is',
#   'more',
#   'strict',
#   'than',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'then',
#   'conduct',
#   'exam',
#   'but',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'then',
#   'teach',
#   'lesson',
#   'happy',
#   'morning'],
#  ['dear', 'good', 'morning', 'now', 'only', 'am', 'up'],
#  ['get',
#   'down',
#   'in',
#   'gandhipuram',
#   'and',
#   'walk',
#   'to',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'lt',
#   'gt',
#   'street',
#   'road',
#   'and',
#   'turn',
#   'at',
#   'first',
#   'right'],
#  ['dear', 'we', 'are', 'going', 'to', 'our', 'rubber', 'place'],
#  ['sorry', 'battery', 'died', 'yeah', 'here'],
#  ['yes', 'here', 'tv', 'is', 'always', 'available', 'in', 'work', 'place'],
#  ['text',
#   'meet',
#   'someone',
#   'sexy',
#   'today',
#   'can',
#   'find',
#   'date',
#   'or',
#   'even',
#   'flirt',
#   'it',
#   'up',
#   'to',
#   'join',
#   'just',
#   'reply',
#   'with',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recd',
#   'thirtyeight',
#   'penny'],
#  ['have', 'printed', 'it', 'oh', 'so', 'lt', 'gt', 'come', 'upstairs'],
#  ['or',
#   'ill',
#   'be',
#   'little',
#   'closer',
#   'like',
#   'at',
#   'the',
#   'bus',
#   'stop',
#   'on',
#   'the',
#   'same',
#   'street'],
#  ['where', 'are', 'you', 'when', 'wil', 'you', 'reach', 'here'],
#  ['new',
#   'theory',
#   'argument',
#   'win',
#   'situation',
#   'but',
#   'loses',
#   'the',
#   'person',
#   'so',
#   'dont',
#   'argue',
#   'with',
#   'ur',
#   'friend',
#   'just',
#   'kick',
#   'them',
#   'amp',
#   'say',
#   'always',
#   'correct'],
#  ['have',
#   'secret',
#   'admirer',
#   'who',
#   'is',
#   'looking',
#   'make',
#   'contact',
#   'with',
#   'find',
#   'out',
#   'who',
#   'they',
#   'reveal',
#   'who',
#   'think',
#   'ur',
#   'so',
#   'special',
#   'call',
#   'on'],
#  ['tomarrow', 'final', 'hearing', 'on', 'my', 'laptop', 'case', 'so', 'cant'],
#  ['tel', 'me', 'avent', 'done', 'sportsx'],
#  ['okay',
#   'no',
#   'no',
#   'just',
#   'shining',
#   'on',
#   'that',
#   'wa',
#   'meant',
#   'to',
#   'be',
#   'signing',
#   'but',
#   'that',
#   'sound',
#   'better'],
#  ['although',
#   'told',
#   'dat',
#   'into',
#   'baig',
#   'face',
#   'watch',
#   'now',
#   'but',
#   'really',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'it',
#   'fr',
#   'thanx',
#   'everything',
#   'dat',
#   've',
#   'done',
#   'today',
#   'touched'],
#  ['don', 'remember', 'that', 'old', 'commercial'],
#  ['too',
#   'late',
#   'said',
#   'have',
#   'the',
#   'website',
#   'didn',
#   'have',
#   'or',
#   'dont',
#   'have',
#   'the',
#   'slipper'],
#  ['asked', 'you', 'to', 'call', 'him', 'now', 'ok'],
#  ['kallis', 'wont', 'bat', 'in', 'nd', 'inning'],
#  ['it',
#   'didnt',
#   'work',
#   'again',
#   'oh',
#   'ok',
#   'goodnight',
#   'then',
#   'll',
#   'fix',
#   'and',
#   'have',
#   'it',
#   'ready',
#   'by',
#   'the',
#   'time',
#   'you',
#   'wake',
#   'up',
#   'you',
#   'are',
#   'very',
#   'dearly',
#   'missed',
#   'have',
#   'good',
#   'night',
#   'sleep'],
#  ['congratulation',
#   'ur',
#   'awarded',
#   'of',
#   'cd',
#   'voucher',
#   'or',
#   'gift',
#   'guaranteed',
#   'free',
#   'entry',
#   'wkly',
#   'draw',
#   'txt',
#   'music',
#   'to',
#   'tncs',
#   'www',
#   'ldew',
#   'com',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'and', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovable',
#   'bcums',
#   'angry',
#   'wid',
#   'dnt',
#   'take',
#   'it',
#   'seriously',
#   'coz',
#   'being',
#   'angry',
#   'is',
#   'most',
#   'childish',
#   'true',
#   'way',
#   'of',
#   'showing',
#   'deep',
#   'affection',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'have',
#   'nice',
#   'day',
#   'da'],
#  ['what', 'you', 'doing', 'how', 'are', 'you'],
#  ['ups',
#   'which',
#   'is',
#   'day',
#   'also',
#   'and',
#   'the',
#   'shipping',
#   'company',
#   'that',
#   'take',
#   'wks',
#   'the',
#   'other',
#   'way',
#   'is',
#   'usps',
#   'which',
#   'take',
#   'week',
#   'but',
#   'when',
#   'it',
#   'get',
#   'to',
#   'lag',
#   'you',
#   'may',
#   'have',
#   'to',
#   'bribe',
#   'nipost',
#   'to',
#   'get',
#   'your',
#   'stuff'],
#  ['back', 'lemme', 'know', 'when', 'you', 're', 'ready'],
#  ['don',
#   'necessarily',
#   'expect',
#   'it',
#   'to',
#   'be',
#   'done',
#   'before',
#   'you',
#   'get',
#   'back',
#   'though',
#   'because',
#   'just',
#   'now',
#   'headin',
#   'out'],
#  ['mmm', 'so', 'yummy', 'babe', 'nice', 'jolt', 'to', 'the', 'suzy'],
#  ['where', 'are', 'you', 'lover', 'need', 'you'],
#  ['we',
#   'tried',
#   'to',
#   'contact',
#   'you',
#   're',
#   'your',
#   'reply',
#   'to',
#   'our',
#   'offer',
#   'of',
#   'video',
#   'handset',
#   'anytime',
#   'network',
#   'min',
#   'unlimited',
#   'text',
#   'camcorder',
#   'reply',
#   'or',
#   'call',
#   'now'],
#  ['parked',
#   'next',
#   'to',
#   'mini',
#   'when',
#   'are',
#   'you',
#   'coming',
#   'in',
#   'today',
#   'do',
#   'you',
#   'think'],
#  ['yup'],
#  ['anyway',
#   'going',
#   'shopping',
#   'on',
#   'my',
#   'own',
#   'now',
#   'co',
#   'my',
#   'si',
#   'not',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['my', 'no', 'in', 'luton', 'ring', 'me', 'if', 'ur', 'around'],
#  ['hey',
#   'am',
#   'really',
#   'horny',
#   'want',
#   'to',
#   'chat',
#   'or',
#   'see',
#   'me',
#   'naked',
#   'text',
#   'hot',
#   'to',
#   'text',
#   'charged',
#   'at',
#   'pm',
#   'to',
#   'unsubscribe',
#   'text',
#   'stop'],
#  ['why', 'you', 'dint', 'come', 'with'],
#  ['same', 'wana', 'plan', 'trip', 'sometme', 'then'],
#  ['not', 'sure', 'yet', 'still', 'trying', 'to', 'get', 'hold', 'of', 'him'],
#  ['ur',
#   'ringtone',
#   'service',
#   'ha',
#   'changed',
#   'free',
#   'credit',
#   'go',
#   'to',
#   'club',
#   'mobile',
#   'com',
#   'to',
#   'choose',
#   'content',
#   'now',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'to',
#   'wk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['the', 'evo', 'just', 'had', 'to', 'download', 'flash', 'jealous'],
#  ['ringtone',
#   'club',
#   'get',
#   'the',
#   'uk',
#   'single',
#   'chart',
#   'on',
#   'your',
#   'mobile',
#   'each',
#   'week',
#   'and',
#   'choose',
#   'any',
#   'top',
#   'quality',
#   'ringtone',
#   'this',
#   'message',
#   'is',
#   'free',
#   'of',
#   'charge'],
#  ['come',
#   'to',
#   'mu',
#   'we',
#   're',
#   'sorting',
#   'out',
#   'our',
#   'narcotic',
#   'situation'],
#  ['night',
#   'ha',
#   'ended',
#   'for',
#   'another',
#   'day',
#   'morning',
#   'ha',
#   'come',
#   'in',
#   'special',
#   'way',
#   'may',
#   'you',
#   'smile',
#   'like',
#   'the',
#   'sunny',
#   'ray',
#   'and',
#   'leaf',
#   'your',
#   'worry',
#   'at',
#   'the',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'of',
#   'genuine',
#   'hmv',
#   'voucher',
#   'to',
#   'be',
#   'won',
#   'just',
#   'answer',
#   'easy',
#   'question',
#   'play',
#   'now',
#   'send',
#   'hmv',
#   'to',
#   'more',
#   'info',
#   'www',
#   'percent',
#   'real',
#   'com'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['no', 'objection', 'my', 'bf', 'not', 'coming'],
#  ['thanx'],
#  ['tell', 'rob', 'to', 'mack', 'his', 'gf', 'in', 'the', 'theater'],
#  ['awesome', 'll', 'see', 'you', 'in', 'bit'],
#  ['just',
#   'sent',
#   'it',
#   'so',
#   'what',
#   'type',
#   'of',
#   'food',
#   'do',
#   'you',
#   'like'],
#  ['all',
#   'done',
#   'all',
#   'handed',
#   'in',
#   'celebration',
#   'in',
#   'full',
#   'swing',
#   'yet'],
#  ['you', 'got', 'called', 'tool'],
#  ['wen',
#   'miss',
#   'someone',
#   'the',
#   'person',
#   'is',
#   'definitely',
#   'special',
#   'for',
#   'but',
#   'if',
#   'the',
#   'person',
#   'is',
#   'so',
#   'special',
#   'why',
#   'to',
#   'miss',
#   'them',
#   'just',
#   'keep',
#   'in',
#   'touch',
#   'gdeve'],
#  ['ok', 'asked', 'for', 'money', 'how', 'far'],
#  ['okie'],
#  ['yeah',
#   'think',
#   'my',
#   'usual',
#   'guy',
#   'still',
#   'passed',
#   'out',
#   'from',
#   'last',
#   'night',
#   'if',
#   'you',
#   'get',
#   'ahold',
#   'of',
#   'anybody',
#   'let',
#   'me',
#   'know',
#   'and',
#   'll',
#   'throw',
#   'down'],
#  ['might',
#   'come',
#   'by',
#   'tonight',
#   'then',
#   'if',
#   'my',
#   'class',
#   'let',
#   'out',
#   'early'],
#  ['ok'],
#  ['hi',
#   'baby',
#   'im',
#   'cruisin',
#   'with',
#   'my',
#   'girl',
#   'friend',
#   'what',
#   'up',
#   'give',
#   'me',
#   'call',
#   'in',
#   'and',
#   'hour',
#   'at',
#   'home',
#   'if',
#   'thats',
#   'alright',
#   'or',
#   'fone',
#   'me',
#   'on',
#   'this',
#   'fone',
#   'now',
#   'love',
#   'jenny',
#   'xxx'],
#  ['my',
#   'life',
#   'mean',
#   'lot',
#   'to',
#   'me',
#   'not',
#   'because',
#   'love',
#   'my',
#   'life',
#   'but',
#   'because',
#   'love',
#   'the',
#   'people',
#   'in',
#   'my',
#   'life',
#   'the',
#   'world',
#   'call',
#   'them',
#   'friend',
#   'call',
#   'them',
#   'my',
#   'world',
#   'ge'],
#  ['dear',
#   'shall',
#   'mail',
#   'tonite',
#   'busy',
#   'in',
#   'the',
#   'street',
#   'shall',
#   'update',
#   'you',
#   'tonite',
#   'thing',
#   'are',
#   'looking',
#   'ok',
#   'varunnathu',
#   'edukkukayee',
#   'raksha',
#   'ollu',
#   'but',
#   'good',
#   'one',
#   'in',
#   'real',
#   'sense'],
#  ['hey', 'you', 'told', 'your', 'name', 'to', 'gautham', 'ah'],
#  ['haf', 'found', 'him', 'feel', 'so', 'stupid', 'da', 'cam', 'wa', 'working'],
#  ['oops', 'got', 'that', 'bit'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['accidentally', 'deleted', 'the', 'message', 'resend', 'please'],
#  ['mobile',
#   'customer',
#   'you',
#   'may',
#   'now',
#   'claim',
#   'your',
#   'free',
#   'camera',
#   'phone',
#   'upgrade',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'for',
#   'your',
#   'loyalty',
#   'call',
#   'on',
#   'offer',
#   'end',
#   'thfeb',
#   'apply'],
#  ['unless',
#   'it',
#   'situation',
#   'where',
#   'you',
#   'go',
#   'gurl',
#   'would',
#   'be',
#   'more',
#   'appropriate'],
#  ['hurt',
#   'me',
#   'tease',
#   'me',
#   'make',
#   'me',
#   'cry',
#   'but',
#   'in',
#   'the',
#   'end',
#   'of',
#   'my',
#   'life',
#   'when',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'on',
#   'my',
#   'grave',
#   'and',
#   'say',
#   'stupid',
#   'miss',
#   'have',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'the', 'phone', 'right', 'now', 'pls', 'send', 'message'],
#  ['need',
#   'coffee',
#   'run',
#   'tomo',
#   'can',
#   'believe',
#   'it',
#   'that',
#   'time',
#   'of',
#   'week',
#   'already'],
#  ['awesome',
#   'remember',
#   'the',
#   'last',
#   'time',
#   'we',
#   'got',
#   'somebody',
#   'high',
#   'for',
#   'the',
#   'first',
#   'time',
#   'with',
#   'diesel'],
#  ['shit',
#   'that',
#   'is',
#   'really',
#   'shocking',
#   'and',
#   'scary',
#   'cant',
#   'imagine',
#   'for',
#   'second',
#   'def',
#   'up',
#   'for',
#   'night',
#   'out',
#   'do',
#   'think',
#   'there',
#   'is',
#   'somewhere',
#   'could',
#   'crash',
#   'for',
#   'night',
#   'save',
#   'on',
#   'taxi'],
#  ['oh',
#   'and',
#   'by',
#   'the',
#   'way',
#   'you',
#   'do',
#   'have',
#   'more',
#   'food',
#   'in',
#   'your',
#   'fridge',
#   'want',
#   'to',
#   'go',
#   'out',
#   'for',
#   'meal',
#   'tonight'],
#  ['he', 'is', 'womdarfull', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'is',
#   'from',
#   'aberdeen',
#   'united',
#   'kingdom',
#   'check',
#   'him',
#   'out',
#   'http',
#   'img',
#   'sm',
#   'ac',
#   'icmb',
#   'cktz',
#   'no',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'from', 'what', 'remb', 'think', 'should', 'be', 'can', 'book'],
#  ['jos', 'ask', 'if', 'wana', 'meet', 'up'],
#  ['lol',
#   'yes',
#   'our',
#   'friendship',
#   'is',
#   'hanging',
#   'on',
#   'thread',
#   'cause',
#   'won',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'out',
#   'our',
#   'newest',
#   'selection',
#   'of',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'and',
#   'sport',
#   'keep',
#   'your',
#   'mobile',
#   'fit',
#   'and',
#   'funky',
#   'text',
#   'wap',
#   'to'],
#  ['where',
#   'are',
#   'the',
#   'garage',
#   'key',
#   'they',
#   'aren',
#   'on',
#   'the',
#   'bookshelf'],
#  ['today',
#   'is',
#   'accept',
#   'day',
#   'accept',
#   'me',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'no',
#   'rply',
#   'mean',
#   'enemy'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'this',
#   'week',
#   'in',
#   'our',
#   'weekly',
#   'quiz',
#   'text',
#   'play',
#   'to',
#   'now',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['he',
#   'say',
#   'he',
#   'll',
#   'give',
#   'me',
#   'call',
#   'when',
#   'his',
#   'friend',
#   'got',
#   'the',
#   'money',
#   'but',
#   'that',
#   'he',
#   'definitely',
#   'buying',
#   'before',
#   'the',
#   'end',
#   'of',
#   'the',
#   'week'],
#  ['hi',
#   'the',
#   'way',
#   'wa',
#   'with',
#   'day',
#   'is',
#   'the',
#   'normal',
#   'way',
#   'this',
#   'is',
#   'the',
#   'real',
#   'me',
#   'ur',
#   'unique',
#   'hope',
#   'know',
#   'the',
#   'rest',
#   'of',
#   'mylife',
#   'hope',
#   'find',
#   'wot',
#   'wa',
#   'lost'],
#  ['you', 'made', 'my', 'day', 'do', 'have', 'great', 'day', 'too'],
#  ['advance', 'happy', 'pongal'],
#  ['hmmm',
#   'guess',
#   'we',
#   'can',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'we',
#   'can',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['not', 'really', 'dude', 'have', 'no', 'friend', 'afraid'],
#  ['december',
#   'only',
#   'had',
#   'your',
#   'mobile',
#   'mths',
#   'you',
#   'are',
#   'entitled',
#   'to',
#   'update',
#   'to',
#   'the',
#   'latest',
#   'colour',
#   'camera',
#   'mobile',
#   'for',
#   'free',
#   'call',
#   'the',
#   'mobile',
#   'update',
#   'co',
#   'free',
#   'on'],
#  ['coffee', 'cake', 'guess'],
#  ['merry', 'christmas', 'to', 'you', 'too', 'babe', 'love', 'ya', 'kiss'],
#  ['hey',
#   'why',
#   'dont',
#   'we',
#   'just',
#   'go',
#   'watch',
#   'men',
#   'and',
#   'have',
#   'lunch',
#   'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'bus',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'they',
#   'were',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['that',
#   'would',
#   'be',
#   'great',
#   'we',
#   'll',
#   'be',
#   'at',
#   'the',
#   'guild',
#   'could',
#   'meet',
#   'on',
#   'bristol',
#   'road',
#   'or',
#   'somewhere',
#   'will',
#   'get',
#   'in',
#   'touch',
#   'over',
#   'weekend',
#   'our',
#   'plan',
#   'take',
#   'flight',
#   'have',
#   'good',
#   'week'],
#  ['no', 'problem', 'how', 'are', 'you', 'doing'],
#  ['no', 'call', 'message', 'missed', 'call'],
#  ['hi', 'da', 'how', 'is', 'the', 'today', 'class'],
#  ['say',
#   'that',
#   'good',
#   'sign',
#   'but',
#   'well',
#   'you',
#   'know',
#   'my',
#   'track',
#   'record',
#   'at',
#   'reading',
#   'woman'],
#  ['cool', 'text', 'me', 'when', 'you', 're', 'parked'],
#  ['reading',
#   'the',
#   'text',
#   'just',
#   'sent',
#   'you',
#   'it',
#   'meant',
#   'to',
#   'be',
#   'joke',
#   'so',
#   'read',
#   'it',
#   'in',
#   'that',
#   'light'],
#  ['apo', 'good', 'movie'],
#  ['maybe',
#   'could',
#   'get',
#   'book',
#   'out',
#   'tomo',
#   'then',
#   'return',
#   'it',
#   'immediately',
#   'or',
#   'something'],
#  ['call',
#   'germany',
#   'for',
#   'only',
#   'penny',
#   'per',
#   'minute',
#   'call',
#   'from',
#   'fixed',
#   'line',
#   'via',
#   'access',
#   'number',
#   'no',
#   'prepayment',
#   'direct',
#   'access'],
#  ['any',
#   'chance',
#   'you',
#   'might',
#   'have',
#   'had',
#   'with',
#   'me',
#   'evaporated',
#   'soon',
#   'you',
#   'violated',
#   'my',
#   'privacy',
#   'by',
#   'stealing',
#   'my',
#   'phone',
#   'number',
#   'from',
#   'your',
#   'employer',
#   'paperwork',
#   'not',
#   'cool',
#   'at',
#   'all',
#   'please',
#   'do',
#   'not',
#   'contact',
#   'me',
#   'again',
#   'or',
#   'will',
#   'report',
#   'you',
#   'to',
#   'your',
#   'supervisor'],
#  ['valentine',
#   'day',
#   'special',
#   'win',
#   'over',
#   'in',
#   'our',
#   'quiz',
#   'and',
#   'take',
#   'your',
#   'partner',
#   'on',
#   'the',
#   'trip',
#   'of',
#   'lifetime',
#   'send',
#   'go',
#   'to',
#   'now',
#   'msg',
#   'rcvd',
#   'custcare'],
#  ['ta', 'daaaaa', 'am', 'home', 'babe', 'are', 'you', 'still', 'up'],
#  ['cool',
#   'so',
#   'how',
#   'come',
#   'you',
#   'havent',
#   'been',
#   'wined',
#   'and',
# ...
#   'usb',
#   'flash',
#   'drive'],
#  ['gibbs', 'unsold', 'mike', 'hussey'],
#  ['like',
#   'to',
#   'talk',
#   'pa',
#   'but',
#   'am',
#   'not',
#   'able',
#   'to',
#   'dont',
#   'know'],
#  ['dun',
#   'cut',
#   'too',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'she',
#   'failed',
#   'she',
#   'quite',
#   'sad'],
#  ['you', 'unbelievable', 'faglord'],
#  ['wife', 'how', 'she', 'knew', 'the', 'time', 'of', 'murder', 'exactly'],
#  ['why', 'do', 'you', 'ask', 'princess'],
#  ['am', 'great', 'princess', 'what', 'are', 'you', 'thinking', 'about', 'me'],
#  ['nutter',
#   'cutter',
#   'ctter',
#   'cttergg',
#   'cttargg',
#   'ctargg',
#   'ctagg',
#   'ie',
#   'you'],
#  ['it',
#   'ok',
#   'noe',
#   're',
#   'busy',
#   'but',
#   'really',
#   'too',
#   'bored',
#   'so',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'she',
#   'choose',
#   'me',
#   'one'],
#  ['doesn',
#   'have',
#   'class',
#   'early',
#   'tomorrow',
#   'and',
#   'thus',
#   'shouldn',
#   'be',
#   'trying',
#   'to',
#   'smoke',
#   'at',
#   'lt',
#   'gt'],
#  ['superb',
#   'thought',
#   'be',
#   'grateful',
#   'that',
#   'dont',
#   'have',
#   'everything',
#   'want',
#   'that',
#   'mean',
#   'still',
#   'have',
#   'an',
#   'opportunity',
#   'to',
#   'be',
#   'happier',
#   'tomorrow',
#   'than',
#   'are',
#   'today'],
#  ['hope', 'you', 'are', 'having', 'good', 'week', 'just', 'checking', 'in'],
#  ['used',
#   'to',
#   'it',
#   'just',
#   'hope',
#   'my',
#   'agent',
#   'don',
#   'drop',
#   'me',
#   'since',
#   've',
#   'only',
#   'booked',
#   'few',
#   'thing',
#   'this',
#   'year',
#   'this',
#   'whole',
#   'me',
#   'in',
#   'boston',
#   'them',
#   'in',
#   'nyc',
#   'wa',
#   'an',
#   'experiment'],
#  ['thursday',
#   'night',
#   'yeah',
#   'sure',
#   'thing',
#   'we',
#   'll',
#   'work',
#   'it',
#   'out',
#   'then'],
#  ['your',
#   'free',
#   'ringtone',
#   'is',
#   'waiting',
#   'to',
#   'be',
#   'collected',
#   'simply',
#   'text',
#   'the',
#   'password',
#   'mix',
#   'to',
#   'to',
#   'verify',
#   'get',
#   'usher',
#   'and',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probably',
#   'money',
#   'worry',
#   'thing',
#   'are',
#   'coming',
#   'due',
#   'and',
#   'have',
#   'several',
#   'outstanding',
#   'invoice',
#   'for',
#   'work',
#   'did',
#   'two',
#   'and',
#   'three',
#   'month',
#   'ago'],
#  ['how', 'is', 'it', 'possible', 'to', 'teach', 'you', 'and', 'where'],
#  ['wonder',
#   'if',
#   'your',
#   'phone',
#   'battery',
#   'went',
#   'dead',
#   'had',
#   'to',
#   'tell',
#   'you',
#   'love',
#   'you',
#   'babe'],
#  ['lovely', 'smell', 'on', 'this', 'bus', 'and', 'it', 'ain', 'tobacco'],
#  ['we',
#   're',
#   'all',
#   'getting',
#   'worried',
#   'over',
#   'here',
#   'derek',
#   'and',
#   'taylor',
#   'have',
#   'already',
#   'assumed',
#   'the',
#   'worst'],
#  ['hey', 'what', 'up', 'charles', 'sorry', 'about', 'the', 'late', 'reply'],
#  ['all',
#   'the',
#   'lastest',
#   'from',
#   'stereophonics',
#   'marley',
#   'dizzee',
#   'racal',
#   'libertine',
#   'and',
#   'the',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'with',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'or',
#   'text',
#   'wap',
#   'to'],
#  ['ll',
#   'give',
#   'her',
#   'once',
#   'have',
#   'it',
#   'plus',
#   'she',
#   'said',
#   'grinule',
#   'greet',
#   'you',
#   'whenever',
#   'we',
#   'speak'],
#  ['white', 'fudge', 'oreo', 'are', 'in', 'store'],
#  ['january',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'now',
#   'cheaper',
#   'call',
#   'national',
#   'rate',
#   'from',
#   'min',
#   'cheap',
#   'to',
#   'min',
#   'peak',
#   'to',
#   'stop',
#   'text',
#   'call',
#   'min'],
#  ['my',
#   'love',
#   'how',
#   'come',
#   'it',
#   'took',
#   'you',
#   'so',
#   'long',
#   'to',
#   'leave',
#   'for',
#   'zaher',
#   'got',
#   'your',
#   'word',
#   'on',
#   'ym',
#   'and',
#   'wa',
#   'happy',
#   'to',
#   'see',
#   'them',
#   'but',
#   'wa',
#   'sad',
#   'you',
#   'had',
#   'left',
#   'miss',
#   'you'],
#  ['am', 'sorry', 'it', 'hurt', 'you'],
#  ['can',
#   'feel',
#   'nauseous',
#   'so',
#   'pissed',
#   'didn',
#   'eat',
#   'any',
#   'sweet',
#   'all',
#   'week',
#   'cause',
#   'today',
#   'wa',
#   'planning',
#   'to',
#   'pig',
#   'out',
#   'wa',
#   'dieting',
#   'all',
#   'week',
#   'and',
#   'now',
#   'not',
#   'hungry'],
#  ['ok',
#   'lor',
#   'but',
#   'not',
#   'too',
#   'early',
#   'me',
#   'still',
#   'having',
#   'project',
#   'meeting',
#   'now'],
#  ['call', 'me', 'da', 'am', 'waiting', 'for', 'your', 'call'],
#  ['could',
#   'ask',
#   'carlos',
#   'if',
#   'we',
#   'could',
#   'get',
#   'more',
#   'if',
#   'anybody',
#   'else',
#   'can',
#   'chip',
#   'in'],
#  ['wa',
#   'actually',
#   'about',
#   'to',
#   'send',
#   'you',
#   'reminder',
#   'today',
#   'have',
#   'wonderful',
#   'weekend'],
#  ['when',
#   'people',
#   'see',
#   'my',
#   'msg',
#   'they',
#   'think',
#   'iam',
#   'addicted',
#   'to',
#   'msging',
#   'they',
#   'are',
#   'wrong',
#   'bcoz',
#   'they',
#   'don',
#   'know',
#   'that',
#   'iam',
#   'addicted',
#   'to',
#   'my',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'you',
#   'gave',
#   'them',
#   'your',
#   'photo',
#   'when',
#   'you',
#   'registered',
#   'for',
#   'driving',
#   'ah',
#   'tmr',
#   'wanna',
#   'meet',
#   'at',
#   'yck'],
#  ['dont', 'talk', 'to', 'him', 'ever', 'ok', 'it', 'my', 'word'],
#  ['when', 'wana', 'see', 'it', 'then'],
#  ['on',
#   'ma',
#   'way',
#   'to',
#   'school',
#   'can',
#   'you',
#   'pls',
#   'send',
#   'me',
#   'ashley',
#   'number'],
#  ['it', 'shall', 'be', 'fine', 'have', 'avalarr', 'now', 'will', 'hollalater'],
#  ['she',
#   'went',
#   'to',
#   'attend',
#   'another',
#   'two',
#   'round',
#   'today',
#   'but',
#   'still',
#   'did',
#   'reach',
#   'home'],
#  ['actually',
#   'deleted',
#   'my',
#   'old',
#   'website',
#   'now',
#   'blogging',
#   'at',
#   'magicalsongs',
#   'blogspot',
#   'com'],
#  ['wait', 'chikku', 'il', 'send', 'aftr', 'lt', 'gt', 'min'],
#  ['but',
#   'on',
#   'diet',
#   'and',
#   'ate',
#   'too',
#   'many',
#   'slice',
#   'of',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'always',
#   'on',
#   'diet'],
#  ['will', 'give', 'my', 'kvb', 'acc', 'detail'],
#  ['oh', 'all', 'have', 'to', 'come', 'ah'],
#  ['money',
#   'you',
#   'lucky',
#   'winner',
#   'claim',
#   'your',
#   'prize',
#   'text',
#   'money',
#   'over',
#   'million',
#   'to',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'jy'],
#  ['really',
#   'sorry',
#   'won',
#   'able',
#   'do',
#   'this',
#   'friday',
#   'hope',
#   'can',
#   'find',
#   'an',
#   'alternative',
#   'hope',
#   'yr',
#   'term',
#   'going',
#   'ok'],
#  ['congratulation',
#   'ore',
#   'mo',
#   'owo',
#   're',
#   'wa',
#   'enjoy',
#   'it',
#   'and',
#   'wish',
#   'you',
#   'many',
#   'happy',
#   'moment',
#   'to',
#   'and',
#   'fro',
#   'wherever',
#   'you',
#   'go'],
#  ['so', 'do', 'you', 'have', 'samus', 'shoulder', 'yet'],
#  ['what',
#   'time',
#   'you',
#   'think',
#   'you',
#   'll',
#   'have',
#   'it',
#   'need',
#   'to',
#   'know',
#   'when',
#   'should',
#   'be',
#   'near',
#   'campus'],
#  ['dear',
#   'matthew',
#   'please',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'lux',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'ppm',
#   'sae',
#   'box',
#   'sk',
#   'xh'],
#  ['then', 'dun', 'wear', 'jean', 'lor'],
#  ['since', 'when', 'which', 'side', 'any', 'fever', 'any', 'vomitin'],
#  ['are', 'you', 'in', 'college'],
#  ['urgent',
#   'call',
#   'from',
#   'landline',
#   'your',
#   'complimentary',
#   'tenerife',
#   'holiday',
#   'or',
#   'cash',
#   'await',
#   'collection',
#   'sae',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'up',
#   'for',
#   'friday',
#   'and',
#   'stuffed',
#   'myself',
#   'like',
#   'pig',
#   'yesterday',
#   'now',
#   'feel',
#   'bleh',
#   'but',
#   'at',
#   'least',
#   'it',
#   'not',
#   'writhing',
#   'pain',
#   'kind',
#   'of',
#   'bleh'],
#  ['no',
#   'we',
#   'sell',
#   'it',
#   'all',
#   'so',
#   'we',
#   'll',
#   'have',
#   'ton',
#   'if',
#   'coin',
#   'then',
#   'sell',
#   'our',
#   'coin',
#   'to',
#   'someone',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'in',
#   'life',
#   'pocket'],
#  ['theyre',
#   'doing',
#   'it',
#   'to',
#   'lot',
#   'of',
#   'place',
#   'only',
#   'hospital',
#   'and',
#   'medical',
#   'place',
#   'are',
#   'safe'],
#  ['how',
#   'about',
#   'getting',
#   'in',
#   'touch',
#   'with',
#   'folk',
#   'waiting',
#   'for',
#   'company',
#   'just',
#   'txt',
#   'back',
#   'your',
#   'name',
#   'and',
#   'age',
#   'to',
#   'opt',
#   'in',
#   'enjoy',
#   'the',
#   'community',
#   'sm'],
#  ['and',
#   'also',
#   've',
#   'sorta',
#   'blown',
#   'him',
#   'off',
#   'couple',
#   'time',
#   'recently',
#   'so',
#   'id',
#   'rather',
#   'not',
#   'text',
#   'him',
#   'out',
#   'of',
#   'the',
#   'blue',
#   'looking',
#   'for',
#   'weed'],
#  ['sent',
#   'my',
#   'score',
#   'to',
#   'sophas',
#   'and',
#   'had',
#   'to',
#   'do',
#   'secondary',
#   'application',
#   'for',
#   'few',
#   'school',
#   'think',
#   'if',
#   'you',
#   'are',
#   'thinking',
#   'of',
#   'applying',
#   'do',
#   'research',
#   'on',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrinde',
#   'her',
#   'school',
#   'is',
#   'one',
#   'me',
#   'the',
#   'less',
#   'expensive',
#   'one'],
#  ['cant',
#   'wait',
#   'to',
#   'see',
#   'you',
#   'how',
#   'were',
#   'the',
#   'photo',
#   'were',
#   'useful'],
#  ['ur',
#   'cash',
#   'balance',
#   'is',
#   'currently',
#   'pound',
#   'to',
#   'maximize',
#   'ur',
#   'cash',
#   'in',
#   'now',
#   'send',
#   'go',
#   'to',
#   'only',
#   'msg',
#   'cc',
#   'po',
#   'box',
#   'tcr'],
#  ['hey',
#   'booked',
#   'the',
#   'kb',
#   'on',
#   'sat',
#   'already',
#   'what',
#   'other',
#   'lesson',
#   'are',
#   'we',
#   'going',
#   'for',
#   'ah',
#   'keep',
#   'your',
#   'sat',
#   'night',
#   'free',
#   'we',
#   'need',
#   'to',
#   'meet',
#   'and',
#   'confirm',
#   'our',
#   'lodging'],
#  ['chk', 'in', 'ur', 'belovd', 'dict'],
#  ['is', 'that', 'what', 'time', 'you', 'want', 'me', 'to', 'come'],
#  ['awesome', 'lemme', 'know', 'whenever', 'you', 're', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beautiful',
#   'truth',
#   'against',
#   'gravity',
#   'read',
#   'carefully',
#   'our',
#   'heart',
#   'feel',
#   'light',
#   'when',
#   'someone',
#   'is',
#   'in',
#   'it',
#   'but',
#   'it',
#   'feel',
#   'very',
#   'heavy',
#   'when',
#   'someone',
#   'leaf',
#   'it',
#   'good',
#   'night'],
#  ['also', 'remember', 'to', 'get', 'dobby', 'bowl', 'from', 'your', 'car'],
#  ['filthy', 'story', 'and', 'girl', 'waiting', 'for', 'your'],
#  ['sorry',
#   'now',
#   'then',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'so',
#   'poor',
#   'thing',
#   'but',
#   'only',
#   'one',
#   'night',
#   'tmr',
#   'll',
#   'have',
#   'brand',
#   'new',
#   'room',
#   'sleep',
#   'in'],
#  ['love',
#   'isn',
#   'decision',
#   'it',
#   'feeling',
#   'if',
#   'we',
#   'could',
#   'decide',
#   'who',
#   'to',
#   'love',
#   'then',
#   'life',
#   'would',
#   'be',
#   'much',
#   'simpler',
#   'but',
#   'then',
#   'less',
#   'magical'],
#  ['welp', 'apparently', 'he', 'retired'],
#  ['my',
#   'sort',
#   'code',
#   'is',
#   'and',
#   'acc',
#   'no',
#   'is',
#   'the',
#   'bank',
#   'is',
#   'natwest',
#   'can',
#   'you',
#   'reply',
#   'to',
#   'confirm',
#   've',
#   'sent',
#   'this',
#   'to',
#   'the',
#   'right',
#   'person'],
#  ['where'],
#  ['sure', 'can', 'take', 'any', 'sick', 'time'],
#  ['urgent',
#   'we',
#   'are',
#   'trying',
#   'to',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'that',
#   'you',
#   'have',
#   'won',
#   'prize',
#   'guaranteed',
#   'call',
#   'from',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr',
#   'only'],
#  ['watching',
#   'cartoon',
#   'listening',
#   'music',
#   'amp',
#   'at',
#   'eve',
#   'had',
#   'to',
#   'go',
#   'temple',
#   'amp',
#   'church',
#   'what',
#   'about'],
#  ['yo',
#   'chad',
#   'which',
#   'gymnastics',
#   'class',
#   'do',
#   'you',
#   'wanna',
#   'take',
#   'the',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'is',
#   'full'],
#  ['are', 'you', 'this', 'much', 'buzy'],
#  ['or',
#   'better',
#   'still',
#   'can',
#   'you',
#   'catch',
#   'her',
#   'and',
#   'let',
#   'ask',
#   'her',
#   'if',
#   'she',
#   'can',
#   'sell',
#   'lt',
#   'gt',
#   'for',
#   'me'],
#  ['am',
#   'not',
#   'sure',
#   'about',
#   'night',
#   'menu',
#   'know',
#   'only',
#   'about',
#   'noon',
#   'menu'],
#  ['what',
#   'do',
#   'want',
#   'when',
#   'come',
#   'back',
#   'beautiful',
#   'necklace',
#   'token',
#   'of',
#   'my',
#   'heart',
#   'for',
#   'you',
#   'thats',
#   'what',
#   'will',
#   'give',
#   'but',
#   'only',
#   'to',
#   'my',
#   'wife',
#   'of',
#   'my',
#   'liking',
#   'be',
#   'that',
#   'and',
#   'see',
#   'no',
#   'one',
#   'can',
#   'give',
#   'you',
#   'that',
#   'dont',
#   'call',
#   'me',
#   'will',
#   'wait',
#   'till',
#   'come'],
#  ['are', 'you', 'willing', 'to', 'go', 'for', 'aptitude', 'class'],
#  ['it', 'wont', 'until', 'trying', 'sort', 'house', 'out', 'is', 'that', 'ok'],
#  ['yar',
#   'lor',
#   'he',
#   'wan',
#   'go',
#   'horse',
#   'racing',
#   'today',
#   'mah',
#   'so',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesome', 'omw', 'back', 'now', 'then'],
#  ['yup', 'thk', 'so', 'until', 'shop', 'close', 'lor'],
#  ['what', 'is', 'your', 'account', 'number'],
#  ['eh', 'send', 'wrongly', 'lar'],
#  ['hey',
#   'no',
#   'ad',
#   'crap',
#   'nite',
#   'wa',
#   'borin',
#   'without',
#   'ya',
#   'boggy',
#   'with',
#   'me',
#   'boring',
#   'biatch',
#   'thanx',
#   'but',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk', 'to', 'him'],
#  ['dont',
#   'hesitate',
#   'you',
#   'know',
#   'this',
#   'is',
#   'the',
#   'second',
#   'time',
#   'she',
#   'ha',
#   'had',
#   'weakness',
#   'like',
#   'that',
#   'so',
#   'keep',
#   'notebook',
#   'of',
#   'what',
#   'she',
#   'eat',
#   'and',
#   'did',
#   'the',
#   'day',
#   'before',
#   'or',
#   'if',
#   'anything',
#   'changed',
#   'the',
#   'day',
#   'before',
#   'so',
#   'that',
#   'we',
#   'can',
#   'be',
#   'sure',
#   'it',
#   'nothing'],
#  ['hey', 'you', 'can', 'pay', 'with', 'salary', 'de', 'only', 'lt', 'gt'],
#  ['another', 'month', 'need', 'chocolate', 'weed', 'and', 'alcohol'],
#  ['if',
#   'he',
#   'started',
#   'searching',
#   'he',
#   'will',
#   'get',
#   'job',
#   'in',
#   'few',
#   'day',
#   'he',
#   'have',
#   'great',
#   'potential',
#   'and',
#   'talent'],
#  ['reckon',
#   'need',
#   'to',
#   'be',
#   'in',
#   'town',
#   'by',
#   'eightish',
#   'to',
#   'walk',
#   'from',
#   'carpark'],
#  ['congrats',
#   'mobile',
#   'videophones',
#   'yours',
#   'call',
#   'now',
#   'videochat',
#   'wid',
#   'your',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'noline',
#   'rentl'],
#  ['look',
#   'at',
#   'the',
#   'fuckin',
#   'time',
#   'what',
#   'the',
#   'fuck',
#   'you',
#   'think',
#   'is',
#   'up'],
#  ['yo', 'guess', 'what', 'just', 'dropped'],
#  ['carlos', 'say', 'he', 'll', 'be', 'at', 'mu', 'in', 'lt', 'gt', 'minute'],
#  ['in', 'office', 'now', 'will', 'call', 'you', 'lt', 'gt', 'min'],
#  ['geeee',
#   'miss',
#   'you',
#   'already',
#   'you',
#   'know',
#   'your',
#   'all',
#   'can',
#   'think',
#   'about',
#   'fuck',
#   'can',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'when',
#   'we',
#   'will',
#   'be',
#   'together',
#   'loving',
#   'kiss'],
#  ['yun',
#   'ah',
#   'the',
#   'ubi',
#   'one',
#   'say',
#   'if',
#   'wan',
#   'call',
#   'by',
#   'tomorrow',
#   'call',
#   'look',
#   'for',
#   'irene',
#   'ere',
#   'only',
#   'got',
#   'bus',
#   'ubi',
#   'cres',
#   'ubi',
#   'tech',
#   'park',
#   'ph',
#   'for',
#   'st',
#   'wkg',
#   'day'],
#  ['ugh',
#   'gotta',
#   'drive',
#   'back',
#   'to',
#   'sd',
#   'from',
#   'la',
#   'my',
#   'butt',
#   'is',
#   'sore'],
#  ['th', 'of', 'july'],
#  ['hi',
#   'im',
#   'having',
#   'the',
#   'most',
#   'relaxing',
#   'time',
#   'ever',
#   'we',
#   'have',
#   'to',
#   'get',
#   'up',
#   'at',
#   'am',
#   'every',
#   'day',
#   'wa',
#   'the',
#   'party',
#   'good',
#   'the',
#   'other',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'at',
#   'ish'],
#  ['up',
#   'to',
#   'wan',
#   'come',
#   'then',
#   'come',
#   'lor',
#   'but',
#   'din',
#   'any',
#   'stripe',
#   'skirt'],
#  ['the',
#   'xmas',
#   'story',
#   'is',
#   'peace',
#   'the',
#   'xmas',
#   'msg',
#   'is',
#   'love',
#   'the',
#   'xmas',
#   'miracle',
#   'is',
#   'jesus',
#   'hav',
#   'blessed',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merry',
#   'xmas'],
#  ['can', 'don', 'have', 'her', 'number'],
#  ['change', 'again', 'it', 'one', 'next', 'to', 'escalator'],
#  ['yetunde',
#   'in',
#   'class',
#   'can',
#   'you',
#   'not',
#   'run',
#   'water',
#   'on',
#   'it',
#   'to',
#   'make',
#   'it',
#   'ok',
#   'pls',
#   'now'],
#  ['not',
#   'lot',
#   'ha',
#   'happened',
#   'here',
#   'feel',
#   'very',
#   'quiet',
#   'beth',
#   'is',
#   'at',
#   'her',
#   'aunt',
#   'and',
#   'charlie',
#   'is',
#   'working',
#   'lot',
#   'just',
#   'me',
#   'and',
#   'helen',
#   'in',
#   'at',
#   'the',
#   'mo',
#   'how',
#   'have',
#   'you',
#   'been'],
#  ['then',
#   'wait',
#   'me',
#   'at',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'if',
#   'dun',
#   'then',
#   'go',
#   'get',
#   'my',
#   'car',
#   'then',
#   'come',
#   'back',
#   'pick'],
#  ...]

# %%
#lets train Word2Vec from scratch
model=gensim.models.Word2Vec(words)

# %%
# to get all the vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
#  'any',
#  'her',
#  'ha',
#  'co',
#  'did',
#  'been',
#  'msg',
#  'min',
#  'some',
#  'an',
#  'night',
#  'make',
#  'dear',
#  'who',
#  'here',
#  'message',
#  'say',
#  'well',
#  'where',
#  're',
#  'thing',
#  'much',
#  'oh',
#  'great',
#  'claim',
#  'hope',
#  'hey',
#  'him',
#  'number',
#  'give',
#  'more',
#  'too',
#  'happy',
#  'work',
#  'wat',
#  'friend',
#  'had',
#  'yes',
#  'way',
#  'www',
#  've',
#  'let',
#  'should',
#  'prize',
#  'won',
#  'right',
#  'tomorrow',
#  'already',
#  'tone',
#  'after',
#  'ask',
#  'win',
#  'said',
#  'life',
#  'amp',
#  'cash',
#  'doing',
#  'im',
#  'yeah',
#  'really',
#  'meet',
#  'babe',
#  'why',
#  'find',
#  'them',
#  'miss',
#  'morning',
#  'very',
#  'last',
#  'year',
#  'service',
#  'thanks',
#  'uk',
#  'care',
#  'com',
#  'would',
#  'anything',
#  'lol',
#  'nokia',
#  'also',
#  'every',
#  'feel',
#  'keep',
#  'sure',
#  'pick',
#  'urgent',
#  'over',
#  'sent',
#  'contact',
#  'something',
#  'buy',
#  'gud',
#  'again',
#  'cant',
#  'wait',
#  'before',
#  'place',
#  'box',
#  'first',
#  'his',
#  'even',
#  'someone',
#  'guy',
#  'help',
#  'went',
#  'wish',
#  'next',
#  'tonight',
#  'were',
#  'nice',
#  'soon',
#  'show',
#  'which',
#  'off',
#  'around',
#  'word',
#  'could',
#  'customer',
#  'money',
#  'sleep',
#  'chat',
#  'per',
#  'many',
#  'late',
#  'always',
#  'ya',
#  'gonna',
#  'sm',
#  'down',
#  'leave',
#  'wan',
#  'name',
#  'lot',
#  'end',
#  'other',
#  'dun',
#  'pm',
#  'told',
#  'st',
#  'person',
#  'waiting',
#  'hello',
#  'special',
#  'try',
#  'month',
#  'girl',
#  'hour',
#  'may',
#  'fine',
#  'best',
#  'haha',
#  'minute',
#  'heart',
#  'people',
#  'coming',
#  'done',
#  'guaranteed',
#  'yet',
#  'thk',
#  'same',
#  'th',
#  'getting',
#  'smile',
#  'ppm',
#  'use',
#  'thought',
#  'god',
#  'didn',
#  'offer',
#  'stuff',
#  'holiday',
#  'talk',
#  'start',
#  'class',
#  'man',
#  'cost',
#  'live',
#  'mean',
#  'bit',
#  'line',
#  'car',
#  'lunch',
#  'few',
#  'draw',
#  'finish',
#  'job',
#  'being',
#  'problem',
#  'never',
#  'yup',
#  'ill',
#  'better',
#  'plan',
#  'trying',
#  'house',
#  'thats',
#  'cool',
#  'hr',
#  'meeting',
#  'account',
#  'rate',
#  'mind',
#  'pobox',
#  'ready',
#  'having',
#  'dat',
#  'long',
#  'weekend',
#  'game',
#  'chance',
#  'world',
#  'real',
#  'half',
#  'enjoy',
#  'latest',
#  'wk',
#  'po',
#  'room',
#  'yo',
#  'sir',
#  'check',
#  'because',
#  'than',
#  'bt',
#  'guess',
#  'play',
#  'awarded',
#  'wanna',
#  'nothing',
#  'lar',
#  'receive',
#  'boy',
#  'voucher',
#  'eat',
#  'sweet',
#  'luv',
#  'look',
#  'camera',
#  'pic',
#  'another',
#  'liao',
#  'big',
#  'shit',
#  'dinner',
#  'into',
#  'ah',
#  'landline',
#  'birthday',
#  'xxx',
#  'jus',
#  'might',
#  'ever',
#  'quite',
#  'video',
#  'kiss',
#  'age',
#  'watching',
#  'wont',
#  'question',
#  'land',
#  'watch',
#  'dream',
#  'orange',
#  'early',
#  'thanx',
#  'worry',
#  'baby',
#  'called',
#  'speak',
#  'two',
#  'tv',
#  'aight',
#  'once',
#  'hear',
#  'fun',
#  'probably',
#  'nd',
#  'point',
#  'bed',
#  'pa',
#  'pay',
#  'doe',
#  'actually',
#  'network',
#  'princess',
#  'nite',
#  'apply',
#  'maybe',
#  'shall',
#  'bus',
#  'part',
#  'sat',
#  'left',
#  'forgot',
#  'den',
#  'bad',
#  'ringtone',
#  'remember',
#  'office',
#  'hurt',
#  'easy',
#  'reach',
#  'code',
#  'shopping',
#  'between',
#  'dunno',
#  'made',
#  'xx',
#  'dis',
#  'little',
#  'evening',
#  'didnt',
#  'award',
#  'put',
#  'true',
#  'leh',
#  'fuck',
#  'everything',
#  'wife',
#  'anyway',
#  'face',
#  'dad',
#  'looking',
#  'town',
#  'thank',
#  'afternoon',
#  'gift',
#  'school',
#  'enough',
#  'sound',
#  'those',
#  'mail',
#  'working',
#  'mate',
#  'selected',
#  'yr',
#  'movie',
#  'most',
#  'collect',
#  'pound',
#  'detail',
#  'without',
#  'asked',
#  'entry',
#  'while',
#  'missing',
#  'tmr',
#  'hav',
#  'join',
#  'price',
#  'sexy',
#  'okay',
#  'though',
#  'pain',
#  'wif',
#  'important',
#  'must',
#  'xmas',
#  'wanted',
#  'until',
#  'since',
#  'valid',
#  'came',
#  'missed',
#  'mob',
#  'answer',
#  'wot',
#  'lesson',
#  'wake',
#  'book',
#  'abt',
#  'run',
#  'bring',
#  'collection',
#  'able',
#  'til',
#  'wen',
#  'haven',
#  'decimal',
#  'de',
#  'test',
#  'charge',
#  'juz',
#  'plus',
#  'change',
#  'stay',
#  'plz',
#  'date',
#  'colour',
#  'away',
#  'double',
#  'dude',
#  'havent',
#  'yesterday',
#  'saw',
#  'music',
#  'till',
#  'else',
#  'weekly',
#  'shop',
#  'bored',
#  'attempt',
#  'alright',
#  'update',
#  'hair',
#  'food',
#  'lei',
#  'credit',
#  'optout',
#  'friendship',
#  'making',
#  'trip',
#  'drink',
#  'net',
#  'these',
#  'online',
#  'id',
#  'haf',
#  'yours',
#  'top',
#  'oso',
#  'coz',
#  'goin',
#  'tried',
#  'gr',
#  'family',
#  'address',
#  'delivery',
#  'sch',
#  'hot',
#  'player',
#  'club',
#  'either',
#  'smoke',
#  'ard',
#  'driving',
#  'feeling',
#  'national',
#  'yourself',
#  'nt',
#  'sad',
#  'order',
#  'lose',
#  'together',
#  'calling',
#  'full',
#  'wid',
#  'second',
#  'story',
#  'mom',
#  'busy',
#  'ring',
#  'beautiful',
#  'head',
#  'bonus',
#  'walk',
#  'http',
#  'brother',
#  'tot',
#  'both',
#  'si',
#  'sae',
#  'post',
#  'believe',
#  'smiling',
#  'huh',
#  'close',
#  'poly',
#  'old',
#  'eve',
#  'row',
#  'chikku',
#  'happen',
#  'noe',
#  'drive',
#  'await',
#  'set',
#  'info',
#  'hand',
#  'saying',
#  'mum',
#  'sleeping',
#  'leaving',
#  'awesome',
#  'mths',
#  'took',
#  'congrats',
#  'pub',
#  'hl',
#  'email',
#  'drop',
#  'parent',
#  'wil',
#  'rite',
#  'tomo',
#  'match',
#  'thinking',
#  'suite',
#  'started',
#  'news',
#  'simple',
#  'aft',
#  'finished',
#  'private',
#  'cause',
#  'doesn',
#  'okie',
#  'tho',
#  'unsubscribe',
#  'auction',
#  'available',
#  'tc',
#  'forget',
#  'content',
#  'everyone',
#  'company',
#  'anyone',
#  'sister',
#  'touch',
#  'break',
#  'caller',
#  'valentine',
#  'reason',
#  'mine',
#  'final',
#  'card',
#  'angry',
#  'neva',
#  'taking',
#  'gd',
#  'statement',
#  'open',
#  'dating',
#  'loving',
#  'whats',
#  'alone',
#  'found',
#  'treat',
#  'whatever',
#  'lucky',
#  'fancy',
#  'carlos',
#  'gal',
#  'choose',
#  'worth',
#  'opt',
#  'each',
#  'ticket',
#  'search',
#  'sun',
#  'knw',
#  'type',
#  'bank',
#  'expires',
#  'wonderful',
#  'frnd',
#  'hows',
#  'mobileupd',
#  'hit',
#  'winner',
#  'hard',
#  'boytoy',
#  'gone',
#  'saturday',
#  'gbp',
#  'welcome',
#  'fast',
#  'happened',
#  'quiz',
#  'anytime',
#  'kind',
#  'congratulation',
#  'bout',
#  'secret',
#  'far',
#  'identifier',
#  'decided',
#  'sub',
#  'ni',
#  'exam',
#  'uncle',
#  'ltd',
#  'party',
#  'smth',
#  'friday',
#  'college',
#  'visit',
#  'nyt',
#  'prob',
#  'song',
#  'darlin',
#  'mu',
#  'hold',
#  'read',
#  'light',
#  'operator',
#  'oredi',
#  'goodmorning',
#  'finally',
#  'mrng',
#  'tel',
#  'sea',
#  'wit',
#  'project',
#  'pretty',
#  'outside',
#  'nope',
#  'term',
#  'used',
#  'drug',
#  'fucking',
#  'wonder',
#  'camcorder',
#  'lovely',
#  'wrong',
#  'least',
#  'chennai',
#  'fri',
#  'crazy',
#  'ten',
#  'log',
#  'cum',
#  'listen',
#  'frnds',
#  'freemsg',
#  'seeing',
#  'blue',
#  'telling',
#  'fone',
#  'case',
#  'meant',
#  'jay',
#  'whole',
#  'fr',
#  'unlimited',
#  'cd',
#  'their',
#  'wasn',
#  'isn',
#  'support',
#  'course',
#  'frm',
#  'sunday',
#  'hmm',
#  'wq',
#  'savamob',
#  'snow',
#  'hungry',
#  'earlier',
#  'wkly',
#  'stupid',
#  'die',
#  'happiness',
#  'un',
#  'dnt',
#  'move',
#  'etc',
#  'hee',
#  'within',
#  'single',
#  'yar',
#  'hmmm',
#  'cut',
#  'mr',
#  'eh',
#  'moment',
#  'march',
#  'enter',
#  'joy',
#  'luck',
#  'film',
#  'na',
#  'balance',
#  'gn',
#  'john',
#  'gas',
#  'child',
#  'knew',
#  'understand',
#  'pas',
#  'father',
#  'valued',
#  'store',
#  'tired',
#  'bslvyl',
#  'mayb',
#  'sell',
#  'almost',
#  'sex',
#  'paper',
#  'press',
#  'side',
#  'area',
#  'sk',
#  'currently',
#  'couple',
#  'txts',
#  'computer',
#  'rock',
#  'invited',
#  'felt',
#  'as',
#  'ago',
#  'download',
#  'india',
#  'lost',
#  'mah',
#  'christmas',
#  'talking',
#  'reading',
#  'load',
#  'motorola',
#  'park',
#  'shower',
#  'bill',
#  'hospital',
#  'askd',
#  'picking',
#  'charged',
#  'photo',
#  'direct',
#  'heard',
#  'return',
#  'rental',
#  'eye',
#  'via',
#  'darren',
#  'confirm',
#  'semester',
#  'correct',
#  'reveal',
#  'red',
#  'doin',
#  'ac',
#  'laptop',
#  'xy',
#  'supposed',
#  'wow',
#  'sort',
#  'ugh',
#  'extra',
#  'information',
#  'bcoz',
#  'kid',
#  'gym',
#  'swing',
#  'redeemed',
#  'surprise',
#  'seen',
#  'difficult',
#  'through',
#  'ge',
#  'promise',
#  'met',
#  'max',
#  'sending',
#  'lady',
#  'complimentary',
#  'comp',
#  'figure',
#  'ipod',
#  'gotta',
#  'grin',
#  'ish',
#  'abiola',
#  'slowly',
#  'ex',
#  'whenever',
#  'discount',
#  'lovable',
#  'yep',
#  'muz',
#  'request',
#  'std',
#  'bath',
#  'police',
#  'hg',
#  'crave',
#  'usf',
#  'safe',
#  'reward',
#  'nobody',
#  'eg',
#  'orchard',
#  'road',
#  'kate',
#  'wine',
#  'comin',
#  'slow',
#  'weed',
#  'link',
#  'asap',
#  'truth',
#  'wap',
#  'fantasy',
#  'study',
#  'fact',
#  'loved',
#  'loan',
#  'cheer',
#  'small',
#  'somebody',
#  'page',
#  'rest',
#  'laugh',
#  'rply',
#  'hmv',
#  'joke',
#  'leaf',
#  'entered',
#  'txting',
#  'blood',
#  'wana',
#  'idea',
#  'noon',
#  'clean',
#  'dogging',
#  'door',
#  'checking',
#  'asking',
#  'train',
#  'own',
#  'remove',
#  'lover',
#  'monday',
#  'save',
#  'rent',
#  'pete',
#  'member',
#  'energy',
#  'nah',
#  'deal',
#  'near',
#  'del',
#  'forever',
#  'mistake',
#  'cup',
#  'copy',
#  'normal',
#  'somewhere',
#  'men',
#  'england',
#  'la',
#  'opinion',
#  'situation',
#  'em',
#  'cheap',
#  'warm',
#  'hoping',
#  'empty',
#  'across',
#  'hw',
#  'woke',
#  'usual',
#  'rakhesh',
#  'callertune',
#  'spend',
#  'med',
#  'gave',
#  'cover',
#  'write',
#  'short',
#  'bb',
#  'tonite',
#  'ringtones',
#  'bathe',
#  'water',
#  'different',
#  'representative',
#  'sony',
#  'ho',
#  'ntt',
#  'voice',
#  'king',
#  'merry',
#  'gap',
#  'poor',
#  'fantastic',
#  'booked',
#  'oops',
#  'wc',
#  'gettin',
#  'bag',
#  'admirer',
#  'getzed',
#  'ldn',
#  'kick',
#  'less',
#  'immediately',
#  'glad',
#  'summer',
#  'wishing',
#  'street',
#  'teach',
#  'cr',
#  'otherwise',
#  'worried',
#  'doctor',
#  'sale',
#  'il',
#  'convey',
#  'custcare',
#  'indian',
#  ...]

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('well', 0.9986796379089355),
#  ('not', 0.998642086982727),
#  ('all', 0.998635470867157),
#  ('night', 0.9986304044723511),
#  ('where', 0.9985188245773315),
#  ('oh', 0.9984481334686279),
#  ('morning', 0.9984118342399597),
#  ('thing', 0.9984005093574524),
#  ('sleep', 0.9983888268470764),
#  ('great', 0.9983874559402466)]

# %%
model.wv['good']
# Out:
# array([-0.25419736,  0.22395772,  0.14260562,  0.07504299,  0.11048298,
#        -0.63337725,  0.22839658,  0.76539916, -0.3606539 , -0.13290685,
#        -0.36030748, -0.5752586 , -0.20789596,  0.15173389,  0.19227366,
#        -0.27912626,  0.21190625, -0.42661065, -0.06468227, -0.8021971 ,
#         0.35065392,  0.07317435,  0.255866  , -0.1609283 ,  0.00726559,
#         0.03210774, -0.25413352, -0.31399825, -0.3962646 ,  0.12396832,
#         0.47356465, -0.02452728,  0.18387085, -0.34149924, -0.22097678,
#         0.4464152 , -0.04860361, -0.31708753, -0.13511178, -0.7842677 ,
#         0.05787995, -0.32212698, -0.21109769,  0.03704174,  0.2866734 ,
#        -0.03109114, -0.20395826, -0.14975424,  0.2983324 ,  0.25119427,
#         0.27679408, -0.27212572, -0.10025206,  0.01415615, -0.10049552,
#         0.11569574,  0.23803338,  0.11362527, -0.6079166 ,  0.1832422 ,
#         0.07893214,  0.08400907, -0.1137637 , -0.11869439, -0.33513206,
#         0.35929507,  0.17092049,  0.40292007, -0.44073734,  0.49544442,
#        -0.26466388,  0.20853128,  0.5328974 , -0.1449017 ,  0.51355076,
#         0.06213366,  0.02913205, -0.1339185 , -0.2292276 ,  0.13133779,
#        -0.33457294, -0.02693974, -0.40046403,  0.5782438 , -0.29002446,
#        -0.14895377,  0.21716994,  0.27304327,  0.50355893, -0.01481434,
#         0.5632677 ,  0.18924655,  0.08608779,  0.0454882 ,  0.7330471 ,
#         0.29257953,  0.20408608, -0.32363248,  0.15792297, -0.07630319],
#       dtype=float32)

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
def avg_word2vec(doc):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (4.66.5)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(words))):
    X.append(avg_word2vec(words[i]))
# Out:
#   7%|█████▋                                                                       | 410/5569 [00:00<00:03, 1441.09it/s]C:\Users\Acer\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\Acer\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|████████████████████████████████████████████████████████████████████████████| 5569/5569 [00:01<00:00, 3232.95it/s]

# %%
X
# Out:
# [array([-1.6719590e-01,  1.5345976e-01,  1.0049137e-01,  5.1629826e-02,
#          8.3705097e-02, -4.5330656e-01,  1.5574542e-01,  5.1794559e-01,
#         -2.3938438e-01, -1.0528633e-01, -2.5059679e-01, -3.8253564e-01,
#         -1.6879438e-01,  1.0915043e-01,  1.3719153e-01, -1.8270589e-01,
#          1.2598450e-01, -2.9999208e-01, -5.1984556e-02, -5.4010504e-01,
#          2.1681665e-01,  4.5383755e-02,  1.6208726e-01, -1.2577771e-01,
#          1.1353344e-02,  1.1954391e-02, -1.8325165e-01, -2.0886554e-01,
#         -2.7358568e-01,  7.4397407e-02,  3.0353060e-01, -1.9614243e-04,
#          1.1303142e-01, -2.2364560e-01, -1.6147725e-01,  3.0786273e-01,
#         -5.7338816e-03, -2.2923112e-01, -1.2882017e-01, -5.3292525e-01,
#          2.3498142e-02, -2.0528960e-01, -1.6097037e-01,  1.2842445e-02,
#          1.9215253e-01, -3.8142972e-02, -1.2741554e-01, -9.1422111e-02,
#          2.3035754e-01,  1.8201925e-01,  1.6367739e-01, -1.9532838e-01,
#         -6.5740354e-02,  2.1194579e-02, -9.6393332e-02,  7.7289626e-02,
#          1.4941669e-01,  6.7966864e-02, -4.1975880e-01,  1.2839921e-01,
#          6.9120988e-02,  6.8020105e-02, -7.3348016e-02, -8.8612191e-02,
#         -2.3056890e-01,  2.5012740e-01,  1.0411051e-01,  2.6234430e-01,
#         -3.1867701e-01,  3.2732531e-01, -1.7345984e-01,  1.8251607e-01,
#          3.5047576e-01, -1.1514117e-01,  3.6161593e-01,  4.6154361e-02,
#          1.6499313e-03, -8.9238524e-02, -1.6179571e-01,  8.0337636e-02,
#         -2.1568187e-01, -4.8100326e-02, -2.8605333e-01,  4.0419176e-01,
#         -1.8870221e-01, -9.0656564e-02,  1.4038484e-01,  1.9518788e-01,
#          3.5095078e-01,  4.8479089e-03,  3.7379599e-01,  1.4165980e-01,
#          4.5678429e-02,  1.4380498e-02,  4.9284431e-01,  1.8086269e-01,
#          1.0669793e-01, -2.3556976e-01,  1.2729700e-01, -4.2495392e-02],
#        dtype=float32),
#  array([-0.15753588,  0.13437204,  0.08192524,  0.04406684,  0.08292264,
#         -0.39320928,  0.12433251,  0.45259124, -0.2101215 , -0.08666937,
#         -0.22303139, -0.32983315, -0.14075911,  0.10010609,  0.12597369,
#         -0.16792694,  0.10778367, -0.26390818, -0.05470043, -0.47360042,
#          0.19176875,  0.04029855,  0.13437133, -0.10541614,  0.01431791,
#          0.0106719 , -0.15722346, -0.18891424, -0.2309726 ,  0.05944937,
#          0.25956255,  0.00050695,  0.08925155, -0.19126889, -0.14068209,
#          0.26825628, -0.00585097, -0.19981892, -0.1073648 , -0.4676809 ,
#          0.02242412, -0.17187546, -0.13550866,  0.00562917,  0.15514009,
#         -0.03978009, -0.11351934, -0.07905886,  0.19869727,  0.15809785,
#          0.13457726, -0.16591284, -0.04664778,  0.02106041, -0.07983901,
#          0.07103389,  0.12838732,  0.05391279, -0.3595308 ,  0.12460035,
#          0.0673069 ,  0.05859399, -0.05646047, -0.06250998, -0.20723853,
#          0.21339585,  0.08808829,  0.22606258, -0.27121717,  0.29067037,
#         -0.14887086,  0.14817429,  0.29537052, -0.10826129,  0.30523112,
#          0.03524539, -0.00254039, -0.07304463, -0.14870614,  0.05627357,
#         -0.17199478, -0.03704856, -0.2557996 ,  0.33892182, -0.16973215,
#         -0.07118662,  0.11600889,  0.17467275,  0.29404795, -0.00350095,
#          0.33171067,  0.1144412 ,  0.03165492,  0.00405476,  0.41398674,
#          0.14745831,  0.09030534, -0.2172128 ,  0.11957267, -0.04154909],
#        dtype=float32),
#  array([-0.18217239,  0.17584737,  0.10854073,  0.07487064,  0.06534512,
#         -0.5055578 ,  0.15885492,  0.5206328 , -0.26257533, -0.13690017,
#         -0.25881922, -0.39896476, -0.17479387,  0.09482658,  0.1373773 ,
#         -0.20765537,  0.14034969, -0.33307797, -0.0561072 , -0.5666778 ,
#          0.20186047,  0.08938574,  0.16429552, -0.1418564 ,  0.04889023,
#          0.01588103, -0.2071227 , -0.17919008, -0.29317507,  0.05833211,
#          0.30263758,  0.006514  ,  0.11037581, -0.21798502, -0.15624684,
#          0.33593753,  0.04987836, -0.2629653 , -0.15888466, -0.5692434 ,
#          0.01728411, -0.23366413, -0.20827751,  0.0039075 ,  0.17011684,
#         -0.0322157 , -0.12347655, -0.07990009,  0.2347613 ,  0.18375303,
#          0.15127613, -0.23606516, -0.0579355 ,  0.05344884, -0.13545044,
#          0.07228329,  0.1560709 ,  0.05102428, -0.45341223,  0.1592635 ,
#          0.06975914,  0.06100499, -0.05705146, -0.09197161, -0.26678044,
#          0.28488117,  0.09359699,  0.2940858 , -0.35578176,  0.3740864 ,
#         -0.19322796,  0.25337937,  0.37477094, -0.14144224,  0.38093117,
#          0.03959037, -0.02616849, -0.11566184, -0.16815116,  0.06125417,
#         -0.20621857, -0.0574545 , -0.2904944 ,  0.41281635, -0.16787441,
#         -0.07236347,  0.11495917,  0.17852701,  0.36125883,  0.04779955,
#          0.3697916 ,  0.14481209,  0.03140876,  0.00814959,  0.5238333 ,
#          0.17957512,  0.05638593, -0.27580777,  0.15955195, -0.02455979],
#        dtype=float32),
#  array([-2.38308504e-01,  2.07451984e-01,  1.30493030e-01,  7.04511032e-02,
#          1.21103160e-01, -6.19293988e-01,  2.06523985e-01,  7.14252770e-01,
#         -3.32937628e-01, -1.37833938e-01, -3.46564144e-01, -5.17846107e-01,
#         -2.25213677e-01,  1.63182497e-01,  1.98145300e-01, -2.62874335e-01,
#          1.76691324e-01, -4.11725312e-01, -7.63652995e-02, -7.48553932e-01,
#          3.08708459e-01,  5.54332733e-02,  2.10891336e-01, -1.67572632e-01,
#          1.05473381e-02,  2.61837933e-02, -2.50261724e-01, -2.95921177e-01,
#         -3.64720196e-01,  1.02488481e-01,  4.25234765e-01, -9.89024647e-06,
#          1.49942085e-01, -3.03182602e-01, -2.27907181e-01,  4.20577675e-01,
#         -1.74013805e-02, -3.06028575e-01, -1.60602421e-01, -7.35614121e-01,
#          4.19817939e-02, -2.76748031e-01, -2.11016297e-01,  2.44789552e-02,
#          2.64301479e-01, -6.08677380e-02, -1.75635979e-01, -1.36157855e-01,
#          3.19597214e-01,  2.43945137e-01,  2.09151819e-01, -2.58958697e-01,
#         -7.38112777e-02,  2.54330020e-02, -1.22199282e-01,  1.10252358e-01,
#          2.03711405e-01,  9.34284180e-02, -5.64755559e-01,  1.83793589e-01,
#          1.00748539e-01,  9.70256329e-02, -9.64001939e-02, -1.10029742e-01,
#         -3.13624561e-01,  3.43145043e-01,  1.43946499e-01,  3.64300460e-01,
#         -4.24157113e-01,  4.59817082e-01, -2.35730499e-01,  2.22809896e-01,
#          4.74133074e-01, -1.71005011e-01,  4.89353478e-01,  6.18369021e-02,
#          5.01248240e-03, -1.04899816e-01, -2.25597233e-01,  9.66314748e-02,
#         -2.91555971e-01, -6.18898012e-02, -3.93919796e-01,  5.50058424e-01,
#         -2.66162306e-01, -1.24029502e-01,  2.02909142e-01,  2.78093666e-01,
#          4.80602205e-01, -1.84106398e-02,  5.19044876e-01,  1.88872978e-01,
#          5.92478998e-02,  1.90085378e-02,  6.62254393e-01,  2.47393027e-01,
#          1.58285365e-01, -3.31722170e-01,  1.77373022e-01, -6.37443215e-02],
#        dtype=float32),
#  array([-2.05625787e-01,  1.71318471e-01,  1.18682571e-01,  5.68635613e-02,
#          1.08219564e-01, -5.23198009e-01,  1.71629444e-01,  6.08444095e-01,
#         -2.83925951e-01, -1.24633193e-01, -2.93579668e-01, -4.50300932e-01,
#         -1.95249677e-01,  1.30137995e-01,  1.70020595e-01, -2.14159772e-01,
#          1.59713998e-01, -3.54025930e-01, -6.13305829e-02, -6.38836205e-01,
#          2.58006513e-01,  4.32601012e-02,  1.85942173e-01, -1.39909610e-01,
#          1.75010022e-02,  2.39017215e-02, -2.10161075e-01, -2.45350942e-01,
#         -3.15068394e-01,  8.88274312e-02,  3.61882806e-01,  5.37996995e-04,
#          1.34764716e-01, -2.66712219e-01, -1.91901162e-01,  3.60264540e-01,
#         -8.33958574e-03, -2.57977605e-01, -1.34739593e-01, -6.11183703e-01,
#          3.89678366e-02, -2.42815807e-01, -1.82572916e-01,  2.67064199e-02,
#          2.25379273e-01, -4.20353077e-02, -1.49052411e-01, -1.11370355e-01,
#          2.59518534e-01,  2.09421858e-01,  1.77407503e-01, -2.19568014e-01,
#         -6.12096824e-02,  2.84320656e-02, -1.05355732e-01,  9.20937061e-02,
#          1.65044814e-01,  8.24591070e-02, -4.77926105e-01,  1.61011621e-01,
#          8.24621245e-02,  7.78153017e-02, -8.16663057e-02, -8.89777243e-02,
#         -2.67256469e-01,  2.90284932e-01,  1.28384352e-01,  3.11899155e-01,
#         -3.51576537e-01,  3.89744133e-01, -1.98467627e-01,  1.93885818e-01,
#          4.01011139e-01, -1.37957662e-01,  4.14951116e-01,  4.83026020e-02,
#         -6.51818141e-03, -9.41220224e-02, -1.84635520e-01,  8.75661373e-02,
#         -2.39873096e-01, -4.59795296e-02, -3.26010019e-01,  4.68785435e-01,
#         -2.15476409e-01, -9.10855904e-02,  1.81666717e-01,  2.25692049e-01,
#          4.00343388e-01, -1.46312416e-02,  4.41730738e-01,  1.56475380e-01,
#          5.36135025e-02,  1.89383850e-02,  5.64021647e-01,  2.13224053e-01,
#          1.29243627e-01, -2.90124893e-01,  1.45868152e-01, -4.91363518e-02],
#        dtype=float32),
#  array([-2.19031885e-01,  1.90231293e-01,  1.24464601e-01,  6.78316876e-02,
#          1.04911298e-01, -5.70670009e-01,  1.85258642e-01,  6.41451120e-01,
#         -3.04519981e-01, -1.43526331e-01, -3.08609933e-01, -4.76842314e-01,
#         -2.05506399e-01,  1.34786114e-01,  1.73423007e-01, -2.31832594e-01,
#          1.67032540e-01, -3.77090424e-01, -6.46878406e-02, -6.74196184e-01,
#          2.64336258e-01,  5.85146248e-02,  2.01090991e-01, -1.55867308e-01,
#          3.16800550e-02,  2.38670595e-02, -2.30417147e-01, -2.47645944e-01,
#         -3.37911487e-01,  8.71876106e-02,  3.82754952e-01, -1.80920004e-04,
#          1.40447155e-01, -2.76778489e-01, -1.95219606e-01,  3.88186008e-01,
#          7.32510490e-03, -2.86321402e-01, -1.54301643e-01, -6.59177542e-01,
#          3.61440703e-02, -2.66476095e-01, -2.09215775e-01,  2.03169622e-02,
#          2.29680270e-01, -4.23911139e-02, -1.57343492e-01, -1.12463191e-01,
#          2.78652847e-01,  2.20426500e-01,  1.97062910e-01, -2.42944792e-01,
#         -6.72528669e-02,  3.86523753e-02, -1.22040212e-01,  9.51728970e-02,
#          1.83976814e-01,  8.04939419e-02, -5.13707101e-01,  1.72091782e-01,
#          8.61853212e-02,  7.78023079e-02, -8.05250034e-02, -9.70369950e-02,
#         -2.90736765e-01,  3.19881946e-01,  1.30547434e-01,  3.35247815e-01,
#         -3.88749868e-01,  4.22870100e-01, -2.14159355e-01,  2.31048986e-01,
#          4.31863785e-01, -1.46128193e-01,  4.45721239e-01,  5.17764315e-02,
#         -9.84670687e-03, -1.09496444e-01, -1.94456175e-01,  8.89011547e-02,
#         -2.58866757e-01, -5.05665727e-02, -3.46626282e-01,  4.92540479e-01,
#         -2.22794935e-01, -9.75766182e-02,  1.81786269e-01,  2.31624320e-01,
#          4.30586994e-01,  8.45435262e-03,  4.61713403e-01,  1.70540243e-01,
#          5.41831218e-02,  1.57747995e-02,  6.03067398e-01,  2.27365866e-01,
#          1.19080193e-01, -3.06850195e-01,  1.62231430e-01, -4.69667353e-02],
#        dtype=float32),
#  array([-0.22497489,  0.1940691 ,  0.13674563,  0.066924  ,  0.11423536,
#         -0.5913726 ,  0.19163683,  0.6740586 , -0.31860605, -0.14123099,
#         -0.3231389 , -0.4996082 , -0.21000424,  0.15005828,  0.18500523,
#         -0.24101909,  0.17716697, -0.38997033, -0.06718706, -0.715073  ,
#          0.29294398,  0.05032501,  0.21188112, -0.16403687,  0.0235968 ,
#          0.0248623 , -0.23726378, -0.27005398, -0.35420847,  0.09940772,
#          0.40715128,  0.00622148,  0.15669481, -0.29725966, -0.21218462,
#          0.4039154 , -0.0114816 , -0.29638076, -0.15969424, -0.6929755 ,
#          0.03563958, -0.2752241 , -0.2064976 ,  0.02339857,  0.25712165,
#         -0.05126595, -0.16890934, -0.12342011,  0.29699588,  0.23237371,
#          0.20877722, -0.24072924, -0.07496784,  0.0294179 , -0.1172586 ,
#          0.0992832 ,  0.18884535,  0.09259794, -0.5347262 ,  0.16981767,
#          0.08817643,  0.08769768, -0.09503658, -0.10193589, -0.30003786,
#          0.3347184 ,  0.14080523,  0.35421458, -0.3999733 ,  0.43964973,
#         -0.22466874,  0.2198963 ,  0.45254818, -0.14665224,  0.46679297,
#          0.05472854, -0.00094222, -0.11259297, -0.20317061,  0.10717747,
#         -0.28304806, -0.05797626, -0.36991438,  0.52789533, -0.24416848,
#         -0.1133799 ,  0.19849491,  0.24934776,  0.4551385 , -0.00202973,
#          0.4913373 ,  0.18151416,  0.06026587,  0.01978252,  0.63571864,
#          0.24515603,  0.14567678, -0.31339064,  0.16166435, -0.05879382],
#        dtype=float32),
#  array([-1.6505446e-01,  1.6360326e-01,  1.0720724e-01,  6.0823351e-02,
#          6.1033476e-02, -4.5802182e-01,  1.5169275e-01,  4.9910188e-01,
#         -2.4384870e-01, -1.2184066e-01, -2.3905487e-01, -3.8090611e-01,
#         -1.5923972e-01,  9.9998921e-02,  1.3383155e-01, -1.8745379e-01,
#          1.2801303e-01, -3.0789277e-01, -4.4559967e-02, -5.2783060e-01,
#          2.0199485e-01,  6.0916737e-02,  1.5762532e-01, -1.2988307e-01,
#          2.1335855e-02,  1.2473918e-02, -1.8990614e-01, -1.8137164e-01,
#         -2.7250978e-01,  6.4652704e-02,  2.9707947e-01,  1.9394953e-03,
#          1.1861348e-01, -2.0178190e-01, -1.5120098e-01,  3.1107736e-01,
#          1.9555205e-02, -2.3614718e-01, -1.4151455e-01, -5.2692109e-01,
#          1.7208908e-02, -2.1439986e-01, -1.8108426e-01,  1.2688709e-02,
#          1.7413163e-01, -3.0956790e-02, -1.2084281e-01, -7.9716779e-02,
#          2.3185579e-01,  1.8541840e-01,  1.5703051e-01, -2.0338024e-01,
#         -6.4648725e-02,  3.3412684e-02, -1.0186900e-01,  6.8021774e-02,
#          1.4178751e-01,  6.5192312e-02, -4.2031318e-01,  1.3497533e-01,
#          5.3923462e-02,  6.1148476e-02, -6.4068295e-02, -8.9536391e-02,
#         -2.4234144e-01,  2.5120467e-01,  9.4816148e-02,  2.6392707e-01,
#         -3.2554972e-01,  3.4288302e-01, -1.7031039e-01,  2.1208113e-01,
#          3.5369495e-01, -1.2116638e-01,  3.6287284e-01,  4.8810899e-02,
#         -4.5784553e-05, -1.1172590e-01, -1.5574071e-01,  7.0440091e-02,
#         -2.1642102e-01, -5.1792193e-02, -2.7570236e-01,  3.9940959e-01,
#         -1.7614941e-01, -8.2217194e-02,  1.1755834e-01,  1.7404021e-01,
#          3.5127044e-01,  3.6590964e-02,  3.5973591e-01,  1.4341088e-01,
#          4.9483165e-02,  1.5234661e-02,  4.8666373e-01,  1.7894708e-01,
#          8.3759934e-02, -2.4062333e-01,  1.3572037e-01, -3.8169991e-02],
#        dtype=float32),
#  array([-0.19566947,  0.1987919 ,  0.13747004,  0.08546909,  0.07770757,
#         -0.543593  ,  0.17694266,  0.5667918 , -0.2860015 , -0.1507612 ,
#         -0.28302312, -0.44765973, -0.19602913,  0.11295317,  0.15333153,
#         -0.22805955,  0.14693908, -0.3590549 , -0.06336357, -0.61711216,
#          0.22172062,  0.08451504,  0.17902072, -0.161632  ,  0.03589112,
#          0.00550981, -0.23542668, -0.18715169, -0.3068675 ,  0.07929623,
#          0.33997685, -0.00273728,  0.12150463, -0.22196901, -0.16772409,
#          0.3545083 ,  0.05132432, -0.2785778 , -0.17612383, -0.61342514,
#          0.02586973, -0.2578674 , -0.21826167,  0.0137674 ,  0.18458943,
#         -0.03026549, -0.1309872 , -0.09003963,  0.25722942,  0.20054257,
#          0.18197994, -0.26582086, -0.06724916,  0.06117461, -0.13867821,
#          0.09207434,  0.17561324,  0.07310827, -0.4949145 ,  0.1764671 ,
#          0.06564292,  0.05536994, -0.05912154, -0.09247178, -0.2807649 ,
#          0.29140595,  0.12040043,  0.3116223 , -0.38461235,  0.40151572,
#         -0.20480885,  0.26147383,  0.40005717, -0.14904186,  0.4075749 ,
#          0.04220193, -0.02299075, -0.12832558, -0.18297313,  0.06486233,
#         -0.2318893 , -0.0544144 , -0.31034863,  0.44684717, -0.17606103,
#         -0.07080366,  0.12577996,  0.18417019,  0.39197785,  0.04137739,
#          0.41511044,  0.15027066,  0.03396557, -0.00239423,  0.56694615,
#          0.18308544,  0.06151053, -0.30142465,  0.17067921, -0.01887174],
#        dtype=float32),
#  array([-2.18181223e-01,  2.23601133e-01,  1.39189333e-01,  9.69898328e-02,
#          7.52918497e-02, -6.33176863e-01,  1.93286210e-01,  6.43487096e-01,
#         -3.28779250e-01, -1.76775306e-01, -3.28180462e-01, -5.00827610e-01,
#         -2.16675162e-01,  1.18578784e-01,  1.79063469e-01, -2.60004967e-01,
#          1.63607538e-01, -4.17995870e-01, -6.21145219e-02, -6.97945416e-01,
#          2.43396074e-01,  1.15763977e-01,  2.04877511e-01, -1.86907068e-01,
#          6.45959079e-02,  1.09636476e-02, -2.62659401e-01, -2.07130700e-01,
#         -3.66174012e-01,  7.23168924e-02,  3.74629289e-01,  9.96365095e-04,
#          1.35001436e-01, -2.47601718e-01, -1.92963079e-01,  4.18425202e-01,
#          7.10702091e-02, -3.39551955e-01, -2.05960959e-01, -7.03461885e-01,
#          2.00351141e-02, -2.95820534e-01, -2.71154165e-01,  3.01260006e-04,
#          2.09658876e-01, -3.55087966e-02, -1.46838278e-01, -9.75061357e-02,
#          2.96543658e-01,  2.34372064e-01,  1.94248423e-01, -3.07422757e-01,
#         -6.96958080e-02,  6.34562001e-02, -1.73347875e-01,  8.86026695e-02,
#          1.83797181e-01,  5.79862930e-02, -5.64169109e-01,  1.92707688e-01,
#          8.75623524e-02,  7.24914297e-02, -6.56590313e-02, -1.17396027e-01,
#         -3.48820984e-01,  3.45338136e-01,  1.13204986e-01,  3.65695655e-01,
#         -4.54590201e-01,  4.77571219e-01, -2.34193280e-01,  3.30079913e-01,
#          4.67536151e-01, -1.81739420e-01,  4.80631948e-01,  6.44988567e-02,
#         -2.69547962e-02, -1.55695453e-01, -2.03087628e-01,  7.50725567e-02,
#         -2.55630702e-01, -7.92307779e-02, -3.64174873e-01,  5.21329343e-01,
#         -2.06117690e-01, -9.43353772e-02,  1.28490537e-01,  2.10010961e-01,
#          4.52596217e-01,  7.54137561e-02,  4.57844436e-01,  1.84446394e-01,
#          4.22646776e-02,  1.12709859e-02,  6.52169347e-01,  2.22234905e-01,
#          6.53520823e-02, -3.32669497e-01,  1.96425691e-01, -3.55974548e-02],
#        dtype=float32),
#  array([-0.21521647,  0.18311988,  0.11928571,  0.05771624,  0.10633069,
#         -0.5525794 ,  0.17717803,  0.63276196, -0.29540837, -0.13517965,
#         -0.30224872, -0.46789292, -0.1986345 ,  0.1300378 ,  0.17199288,
#         -0.23149863,  0.16471152, -0.36740372, -0.06127263, -0.6643758 ,
#          0.26350713,  0.04765284,  0.19372354, -0.15072605,  0.02221921,
#          0.02205674, -0.22008997, -0.24629968, -0.3272258 ,  0.0903376 ,
#          0.3791554 , -0.00127116,  0.1389922 , -0.2736238 , -0.19022658,
#          0.37316576, -0.00109884, -0.27169377, -0.14011966, -0.63973385,
#          0.04343513, -0.2584535 , -0.19650412,  0.02602612,  0.22852662,
#         -0.04189742, -0.14951104, -0.11463434,  0.26717785,  0.21176174,
#          0.19188887, -0.23090184, -0.06167315,  0.03866715, -0.11326386,
#          0.09725585,  0.17682645,  0.07671972, -0.49333522,  0.16683334,
#          0.08546569,  0.07493592, -0.08028527, -0.09149634, -0.27657893,
#          0.30955568,  0.13528581,  0.3246228 , -0.37312603,  0.40733775,
#         -0.21007274,  0.2073766 ,  0.41869554, -0.13789417,  0.42898926,
#          0.05663177, -0.00675096, -0.09551606, -0.19002269,  0.09287012,
#         -0.2513927 , -0.04556624, -0.33549535,  0.48120296, -0.22031073,
#         -0.09538726,  0.18518737,  0.22934334,  0.41597694, -0.00249279,
#          0.45764402,  0.16350235,  0.05127562,  0.01517239,  0.5866081 ,
#          0.22125188,  0.12378907, -0.29956794,  0.15127988, -0.04248086],
#        dtype=float32),
#  array([-0.21981746,  0.20254241,  0.12811595,  0.08414486,  0.08898144,
#         -0.60093945,  0.18622118,  0.6184862 , -0.31299007, -0.15808469,
#         -0.30881187, -0.47671497, -0.20974664,  0.116263  ,  0.16550833,
#         -0.24615733,  0.17643167, -0.39467683, -0.06916371, -0.67365617,
#          0.24190304,  0.10165821,  0.19718231, -0.16736425,  0.05561784,
#          0.02021158, -0.24920018, -0.21337906, -0.34673488,  0.0781648 ,
#          0.36676633, -0.00167954,  0.13062923, -0.25113416, -0.18454573,
#          0.39298785,  0.04736175, -0.3133211 , -0.17973235, -0.67382437,
#          0.0312263 , -0.2818966 , -0.23875915,  0.0099621 ,  0.20049694,
#         -0.03687808, -0.15010142, -0.09463671,  0.27276948,  0.21562935,
#          0.18428656, -0.28049672, -0.05807719,  0.06393411, -0.15874138,
#          0.09061914,  0.18883006,  0.0646928 , -0.5340932 ,  0.19437954,
#          0.07959418,  0.06867735, -0.06719863, -0.10092153, -0.312162  ,
#          0.33639216,  0.11765844,  0.35154694, -0.41827562,  0.44772202,
#         -0.23286396,  0.2882221 ,  0.44169462, -0.17364378,  0.4513009 ,
#          0.04410546, -0.02981541, -0.13186076, -0.1990878 ,  0.06560721,
#         -0.24907048, -0.05813905, -0.3381423 ,  0.48935905, -0.19810507,
#         -0.07951992,  0.14437486,  0.20932782,  0.42508087,  0.04518301,
#          0.4411362 ,  0.16814317,  0.03420277,  0.01272294,  0.61488825,
#          0.21291755,  0.07296606, -0.33074787,  0.18684939, -0.02831837],
#        dtype=float32),
#  array([-0.22991654,  0.22039777,  0.14798273,  0.09062839,  0.09143239,
#         -0.6262527 ,  0.19921511,  0.6456619 , -0.32779616, -0.16937514,
#         -0.3239248 , -0.50900716, -0.22159135,  0.11832771,  0.17713849,
#         -0.25617588,  0.17632528, -0.41937613, -0.07033458, -0.70832455,
#          0.244566  ,  0.10783499,  0.20523275, -0.18464331,  0.05188981,
#          0.0171394 , -0.2680696 , -0.21819386, -0.35478634,  0.08361279,
#          0.389719  , -0.007417  ,  0.13422823, -0.25612667, -0.19436072,
#          0.41080597,  0.05872371, -0.32238522, -0.1859979 , -0.70826864,
#          0.03937823, -0.3020796 , -0.25251105,  0.01286954,  0.21089858,
#         -0.03512742, -0.14915477, -0.10239027,  0.283742  ,  0.22159874,
#          0.20051289, -0.30659765, -0.06779066,  0.07107474, -0.16746056,
#          0.10149533,  0.19950157,  0.07313674, -0.5691721 ,  0.20256126,
#          0.08044593,  0.06379009, -0.0619626 , -0.10192821, -0.33031663,
#          0.34492797,  0.12725978,  0.36405498, -0.43854398,  0.46476915,
#         -0.2411623 ,  0.3074882 ,  0.46366942, -0.17768225,  0.47146276,
#          0.04807375, -0.03168426, -0.14368844, -0.21015489,  0.07246125,
#         -0.26020044, -0.06017561, -0.3538015 ,  0.5147055 , -0.19880243,
#         -0.08201437,  0.14459996,  0.21786685,  0.44913673,  0.04946955,
#          0.46703905,  0.1753413 ,  0.03906543,  0.00357777,  0.6522673 ,
#          0.21948199,  0.07147886, -0.3443625 ,  0.19734217, -0.02567401],
#        dtype=float32),
#  array([-0.21950932,  0.18853915,  0.12625803,  0.06371289,  0.10666298,
#         -0.5624111 ,  0.18215436,  0.6365279 , -0.30068132, -0.1402145 ,
#         -0.30669633, -0.4765177 , -0.19974223,  0.13389689,  0.1752572 ,
#         -0.23393585,  0.1702313 , -0.37673447, -0.05821602, -0.6698048 ,
#          0.2636258 ,  0.05644669,  0.20120262, -0.15399235,  0.02559272,
#          0.02204792, -0.23202753, -0.24584009, -0.3328677 ,  0.09161439,
#          0.3887839 , -0.00344175,  0.13785122, -0.26508352, -0.19267368,
#          0.3820526 ,  0.00097566, -0.276454  , -0.14024407, -0.64849925,
#          0.04557293, -0.26838768, -0.20843412,  0.02572341,  0.22783864,
#         -0.03300868, -0.15531793, -0.10931455,  0.2704817 ,  0.2204064 ,
#          0.20232922, -0.23914386, -0.0612063 ,  0.0438638 , -0.11939715,
#          0.09697191,  0.18157868,  0.0812716 , -0.5057609 ,  0.1711566 ,
#          0.0799147 ,  0.07193418, -0.07515658, -0.09477773, -0.28642026,
#          0.31217864,  0.1367732 ,  0.3282191 , -0.3827861 ,  0.41957775,
#         -0.21168168,  0.22216967,  0.4307223 , -0.14130297,  0.4390918 ,
#          0.05694024, -0.00451585, -0.10832263, -0.19024424,  0.09226634,
#         -0.2606405 , -0.04460613, -0.33459243,  0.491326  , -0.22048892,
#         -0.09688855,  0.18246713,  0.22787814,  0.42357695,  0.00569137,
#          0.4620663 ,  0.1651466 ,  0.05629996,  0.01537121,  0.59671223,
#          0.22887881,  0.1252523 , -0.30170816,  0.15953794, -0.04216495],
#        dtype=float32),
#  array([-2.04069778e-01,  1.91699103e-01,  1.29671380e-01,  6.74052909e-02,
#          9.16808918e-02, -5.56200802e-01,  1.80631027e-01,  6.17230356e-01,
#         -2.91067034e-01, -1.39838383e-01, -2.97674417e-01, -4.70481008e-01,
#         -1.99404433e-01,  1.30187705e-01,  1.66664451e-01, -2.25705877e-01,
#          1.65316001e-01, -3.72462779e-01, -5.41688800e-02, -6.55383408e-01,
#          2.63372064e-01,  6.75928369e-02,  1.93357304e-01, -1.57161489e-01,
#          2.33767312e-02,  1.42912678e-02, -2.29236960e-01, -2.34412253e-01,
#         -3.25279862e-01,  8.65618810e-02,  3.69524449e-01, -5.98934770e-04,
#          1.42319068e-01, -2.63668627e-01, -1.93572924e-01,  3.79208922e-01,
#          1.35965953e-02, -2.83198684e-01, -1.61779448e-01, -6.45355344e-01,
#          3.56982201e-02, -2.63494343e-01, -2.00587690e-01,  2.02292055e-02,
#          2.30632469e-01, -3.20205204e-02, -1.55551136e-01, -1.08507484e-01,
#          2.76928753e-01,  2.17840970e-01,  2.01015398e-01, -2.40528718e-01,
#         -7.11508915e-02,  3.64263691e-02, -1.22983597e-01,  9.09811482e-02,
#          1.79363444e-01,  7.89997205e-02, -5.08180201e-01,  1.66244775e-01,
#          7.71388337e-02,  7.28775784e-02, -7.85985291e-02, -1.00618921e-01,
#         -2.84398466e-01,  3.11330259e-01,  1.25704527e-01,  3.29838246e-01,
#         -3.87833565e-01,  4.18073744e-01, -2.12723389e-01,  2.28753150e-01,
#          4.31926280e-01, -1.39093623e-01,  4.42486763e-01,  5.14657088e-02,
#         -4.36937949e-03, -1.19906537e-01, -1.87632427e-01,  9.46636423e-02,
#         -2.64297336e-01, -5.83382137e-02, -3.44340831e-01,  4.89480376e-01,
#         -2.15948939e-01, -9.98550281e-02,  1.62976757e-01,  2.19924077e-01,
#          4.29637790e-01,  2.15117037e-02,  4.53100353e-01,  1.70771539e-01,
#          5.50755858e-02,  1.25996815e-02,  5.93090355e-01,  2.16001704e-01,
#          1.10391021e-01, -2.89144248e-01,  1.61622316e-01, -4.00327891e-02],
#        dtype=float32),
#  array([-0.18438284,  0.17340498,  0.1089827 ,  0.06438537,  0.07731993,
#         -0.50459343,  0.15905006,  0.5348975 , -0.2689291 , -0.12941569,
#         -0.2670048 , -0.41233304, -0.17854793,  0.10227285,  0.14921647,
#         -0.20292546,  0.14261667, -0.3317198 , -0.05620345, -0.576009  ,
#          0.21124318,  0.07475041,  0.17038517, -0.14374124,  0.03476032,
#          0.01704364, -0.20622928, -0.19396317, -0.2964909 ,  0.0649875 ,
#          0.3182167 , -0.00184754,  0.1140845 , -0.22296655, -0.16063742,
#          0.3403696 ,  0.03107922, -0.2584332 , -0.14890213, -0.576009  ,
#          0.02500102, -0.23550658, -0.1976068 ,  0.01225465,  0.18423112,
#         -0.03212263, -0.12678187, -0.08490257,  0.23571213,  0.19152555,
#          0.16354437, -0.23037478, -0.06104364,  0.04272563, -0.12572959,
#          0.0767262 ,  0.15929909,  0.05805559, -0.45860702,  0.15150203,
#          0.06844812,  0.06419346, -0.0613492 , -0.09158811, -0.2667585 ,
#          0.2842597 ,  0.10188873,  0.29661277, -0.35173914,  0.37458092,
#         -0.18852928,  0.23879634,  0.3826593 , -0.13658111,  0.38735375,
#          0.05200549, -0.01091445, -0.11251107, -0.1717128 ,  0.07238072,
#         -0.22043918, -0.05499999, -0.29669946,  0.42594945, -0.18305269,
#         -0.08213384,  0.12868471,  0.18945447,  0.37204194,  0.03707242,
#          0.38399258,  0.15226139,  0.04125417,  0.01290159,  0.5293403 ,
#          0.19089112,  0.08168036, -0.2684211 ,  0.15310426, -0.03611915],
#        dtype=float32),
#  array([-0.19532056,  0.17296265,  0.11672918,  0.05546856,  0.09851829,
#         -0.5218938 ,  0.17543507,  0.6059215 , -0.2785076 , -0.11801711,
#         -0.2929542 , -0.4533546 , -0.19085021,  0.1303079 ,  0.16119944,
#         -0.21179835,  0.15132123, -0.35105297, -0.05928909, -0.6287064 ,
#          0.26589897,  0.04542832,  0.17757905, -0.14282827,  0.00757475,
#          0.01934233, -0.20976315, -0.25083312, -0.31694758,  0.08510513,
#          0.3588493 , -0.00112291,  0.13027662, -0.25897607, -0.18971188,
#          0.36073956, -0.01490964, -0.26041067, -0.13554187, -0.6132229 ,
#          0.03744528, -0.2349503 , -0.18316306,  0.01562878,  0.22561955,
#         -0.04711198, -0.14811046, -0.10357191,  0.2698785 ,  0.21251722,
#          0.18961556, -0.2197666 , -0.07356713,  0.02224855, -0.10447544,
#          0.09665406,  0.17094539,  0.08531495, -0.47961256,  0.14810915,
#          0.07223132,  0.0832542 , -0.08920759, -0.09653103, -0.2685092 ,
#          0.29151714,  0.1283623 ,  0.30502447, -0.35507348,  0.38349915,
#         -0.19653921,  0.19427335,  0.40342808, -0.13804406,  0.4123671 ,
#          0.05285573,  0.00574969, -0.10158435, -0.190094  ,  0.09761703,
#         -0.24963783, -0.05319668, -0.33257264,  0.4698697 , -0.22314094,
#         -0.10330776,  0.16782206,  0.23222663,  0.4078437 , -0.00583407,
#          0.43539056,  0.17125767,  0.05796661,  0.02405545,  0.5640442 ,
#          0.2162803 ,  0.13334656, -0.2722471 ,  0.15033314, -0.05315204],
#        dtype=float32),
#  array([-1.75314963e-01,  1.42923042e-01,  9.98099521e-02,  4.52002399e-02,
#          9.13771018e-02, -4.41143155e-01,  1.42086938e-01,  5.04252613e-01,
#         -2.33887061e-01, -1.03459559e-01, -2.50541896e-01, -3.76949549e-01,
#         -1.60959601e-01,  1.08720332e-01,  1.39366552e-01, -1.85888037e-01,
#          1.33039966e-01, -2.96184450e-01, -4.69170809e-02, -5.33301890e-01,
#          2.19012573e-01,  3.45699191e-02,  1.55781686e-01, -1.15874343e-01,
#          1.48244156e-02,  1.73021536e-02, -1.80118188e-01, -2.09808588e-01,
#         -2.60510474e-01,  7.28798136e-02,  3.04986149e-01, -1.82463627e-04,
#          1.09129965e-01, -2.15060726e-01, -1.56106740e-01,  3.00846756e-01,
#         -1.76206995e-02, -2.21229553e-01, -1.07603364e-01, -5.18623352e-01,
#          3.54981460e-02, -2.09109828e-01, -1.51575491e-01,  2.11882964e-02,
#          1.81756303e-01, -3.38083915e-02, -1.27582252e-01, -9.33887362e-02,
#          2.16108546e-01,  1.73946917e-01,  1.54754862e-01, -1.87062725e-01,
#         -4.35874201e-02,  2.72022858e-02, -9.21671167e-02,  8.13601390e-02,
#          1.44308552e-01,  7.21205696e-02, -4.03386384e-01,  1.32067531e-01,
#          6.54912218e-02,  6.38140067e-02, -6.47244379e-02, -7.52542540e-02,
#         -2.27108181e-01,  2.39730895e-01,  1.13076217e-01,  2.61359602e-01,
#         -2.95650512e-01,  3.33134443e-01, -1.68131292e-01,  1.61491543e-01,
#          3.37413222e-01, -1.16493069e-01,  3.46051574e-01,  4.39761579e-02,
#          4.70240787e-03, -7.89082497e-02, -1.55461386e-01,  7.49045312e-02,
#         -2.07634494e-01, -3.88937145e-02, -2.65622765e-01,  3.96793872e-01,
#         -1.83075622e-01, -8.01899359e-02,  1.49342492e-01,  1.91938922e-01,
#          3.35661680e-01, -1.03593720e-02,  3.70779425e-01,  1.28314003e-01,
#          4.17462736e-02,  1.44811822e-02,  4.71158743e-01,  1.86036602e-01,
#          1.09010905e-01, -2.38334641e-01,  1.21870607e-01, -3.84210199e-02],
#        dtype=float32),
#  array([-2.49499083e-01,  1.94529250e-01,  1.34466469e-01,  5.48939817e-02,
#          1.32631451e-01, -6.03151739e-01,  1.92808554e-01,  7.03268111e-01,
#         -3.29271883e-01, -1.41866416e-01, -3.41364831e-01, -5.16256034e-01,
#         -2.20007822e-01,  1.51796147e-01,  2.05700830e-01, -2.53231615e-01,
#          1.92806751e-01, -4.03816044e-01, -7.61849359e-02, -7.36047208e-01,
#          2.98997760e-01,  4.19597700e-02,  2.23364860e-01, -1.55569434e-01,
#          1.88133195e-02,  2.97196601e-02, -2.40314484e-01, -2.90879190e-01,
#         -3.58778954e-01,  1.07349649e-01,  4.35363710e-01, -5.05973701e-04,
#          1.52477533e-01, -3.07937205e-01, -2.17606306e-01,  4.12929475e-01,
#         -1.90586410e-02, -2.93276697e-01, -1.39479384e-01, -7.05147862e-01,
#          4.77333292e-02, -2.90989578e-01, -2.05374435e-01,  3.80578227e-02,
#          2.66470373e-01, -4.38120738e-02, -1.71462014e-01, -1.27226278e-01,
#          2.94867516e-01,  2.39368960e-01,  2.21604735e-01, -2.48510271e-01,
#         -7.68148229e-02,  2.37229578e-02, -1.21497884e-01,  1.05464317e-01,
#          2.00032204e-01,  9.79245231e-02, -5.43915451e-01,  1.75972462e-01,
#          9.73430723e-02,  9.23061967e-02, -8.50230232e-02, -1.01537347e-01,
#         -2.95523345e-01,  3.38844061e-01,  1.58411190e-01,  3.60804141e-01,
#         -4.05652374e-01,  4.51280922e-01, -2.23131493e-01,  2.17333227e-01,
#          4.61209357e-01, -1.46543279e-01,  4.83146489e-01,  6.93891197e-02,
#          5.17475326e-03, -1.04241215e-01, -2.08538339e-01,  1.13354087e-01,
#         -2.89902627e-01, -5.43876700e-02, -3.70042950e-01,  5.46941638e-01,
#         -2.55697042e-01, -1.17423676e-01,  2.19225004e-01,  2.63985157e-01,
#          4.67425048e-01, -2.06124242e-02,  5.17490745e-01,  1.87267572e-01,
#          7.20089078e-02,  1.82707347e-02,  6.52874291e-01,  2.62830585e-01,
#          1.68790549e-01, -3.18758249e-01,  1.56636119e-01, -5.03915772e-02],
#        dtype=float32),
#  array([-0.16693297,  0.15329456,  0.09379766,  0.06342587,  0.07086119,
#         -0.45545632,  0.1417616 ,  0.4719587 , -0.2398173 , -0.11549066,
#         -0.23462084, -0.3654889 , -0.1608007 ,  0.08915137,  0.12751456,
#         -0.18427072,  0.13341877, -0.2995149 , -0.05279061, -0.5139917 ,
#          0.18238619,  0.07637271,  0.14543086, -0.12547062,  0.0403551 ,
#          0.01954008, -0.18509793, -0.16591397, -0.2629256 ,  0.05575926,
#          0.28304017,  0.00117291,  0.09804953, -0.19694181, -0.14115429,
#          0.29955256,  0.0338714 , -0.23393273, -0.13106374, -0.51730084,
#          0.02341591, -0.2110743 , -0.182578  ,  0.00797089,  0.1585793 ,
#         -0.02947149, -0.11792541, -0.07407498,  0.2046415 ,  0.16377975,
#          0.1355073 , -0.21111803, -0.04601319,  0.04428964, -0.11677215,
#          0.06946295,  0.1429767 ,  0.04891124, -0.40599373,  0.14363244,
#          0.0612254 ,  0.05476823, -0.05162043, -0.07573181, -0.23721446,
#          0.25599706,  0.08968969,  0.26827064, -0.3113333 ,  0.3350246 ,
#         -0.17788287,  0.21523245,  0.33516252, -0.1300235 ,  0.34271863,
#          0.03231603, -0.0193439 , -0.09896138, -0.1490712 ,  0.05153062,
#         -0.18650652, -0.04633861, -0.25887692,  0.37487763, -0.15238331,
#         -0.06506883,  0.11435372,  0.16807228,  0.3280644 ,  0.0348487 ,
#          0.33507285,  0.13136838,  0.03008292,  0.01014162,  0.46969938,
#          0.16700442,  0.06315984, -0.24815327,  0.1416812 , -0.02638609],
#        dtype=float32),
#  array([-2.36753926e-01,  1.80897847e-01,  1.32896110e-01,  5.23765944e-02,
#          1.24106035e-01, -5.63616157e-01,  1.81270018e-01,  6.59522176e-01,
#         -3.03381860e-01, -1.35600477e-01, -3.17684501e-01, -4.95390028e-01,
#         -2.07003281e-01,  1.54099390e-01,  1.86510310e-01, -2.30965182e-01,
#          1.82110474e-01, -3.72549266e-01, -5.64257726e-02, -6.96592331e-01,
#          2.87943870e-01,  2.91612502e-02,  2.13695422e-01, -1.50243446e-01,
#          1.97205711e-02,  3.25128064e-02, -2.28692606e-01, -2.75150627e-01,
#         -3.31876725e-01,  1.07672319e-01,  4.16194290e-01,  4.10719949e-04,
#          1.44419804e-01, -2.83006102e-01, -2.00657621e-01,  3.89539510e-01,
#         -3.23716030e-02, -2.69994766e-01, -1.19649522e-01, -6.64380610e-01,
#          6.38043284e-02, -2.75684625e-01, -1.85960934e-01,  3.29770967e-02,
#          2.42589787e-01, -3.76724191e-02, -1.65508747e-01, -1.28200918e-01,
#          2.71456033e-01,  2.21974805e-01,  2.17600152e-01, -2.33645529e-01,
#         -5.85413910e-02,  3.60396840e-02, -1.10273726e-01,  1.08202301e-01,
#          1.90522641e-01,  9.71964374e-02, -5.12593925e-01,  1.71707138e-01,
#          8.15848559e-02,  7.75828138e-02, -7.93209001e-02, -8.57559964e-02,
#         -2.75043041e-01,  3.10089409e-01,  1.57718137e-01,  3.32353652e-01,
#         -3.70819628e-01,  4.29503173e-01, -2.14546889e-01,  1.87954336e-01,
#          4.34368193e-01, -1.31461799e-01,  4.43929851e-01,  6.02338314e-02,
#          1.67125987e-03, -9.43416879e-02, -1.92039624e-01,  1.05997317e-01,
#         -2.75383264e-01, -4.04086001e-02, -3.30971986e-01,  5.03461540e-01,
#         -2.34112844e-01, -1.01176083e-01,  2.16996059e-01,  2.44113177e-01,
#          4.34384555e-01, -2.84014493e-02,  4.90107983e-01,  1.60895184e-01,
#          5.84101006e-02,  1.07989702e-02,  6.02517664e-01,  2.44902819e-01,
#          1.55742392e-01, -3.10746998e-01,  1.45015955e-01, -3.68655957e-02],
#        dtype=float32),
#  array([-0.21304595,  0.21125261,  0.1343147 ,  0.08129869,  0.07810204,
#         -0.5972753 ,  0.20165373,  0.6577569 , -0.31299058, -0.15249276,
#         -0.31311542, -0.49087816, -0.21122259,  0.13356961,  0.17257802,
#         -0.2448848 ,  0.15910722, -0.3973101 , -0.06153573, -0.69225895,
#          0.27651125,  0.08248135,  0.20025766, -0.1675976 ,  0.02491888,
#          0.01297791, -0.24236648, -0.240221  , -0.36047465,  0.08417366,
#          0.383103  ,  0.00827031,  0.1621018 , -0.28609955, -0.20366952,
#          0.4036082 ,  0.02028289, -0.31034386, -0.19103318, -0.69477654,
#          0.01640441, -0.27415025, -0.230251  ,  0.00549924,  0.24571708,
#         -0.04062879, -0.16550978, -0.10404209,  0.3113039 ,  0.2428919 ,
#          0.20815963, -0.2487415 , -0.09576338,  0.02799667, -0.12648526,
#          0.08282635,  0.19132254,  0.08733795, -0.554217  ,  0.16598943,
#          0.07618859,  0.08784003, -0.0932678 , -0.12535891, -0.31828558,
#          0.33404636,  0.12577908,  0.34693253, -0.43179077,  0.4360435 ,
#         -0.22023585,  0.26722753,  0.45863235, -0.15620834,  0.48339877,
#          0.05657728,  0.00519861, -0.14425254, -0.20676966,  0.0951732 ,
#         -0.2881819 , -0.07479089, -0.37623253,  0.52527195, -0.2353564 ,
#         -0.12243468,  0.1548194 ,  0.22733705,  0.46234676,  0.04040888,
#          0.4640492 ,  0.19002113,  0.06812071,  0.025922  ,  0.6455911 ,
#          0.23496954,  0.11321332, -0.3028149 ,  0.17420861, -0.05337632],
#        dtype=float32),
#  array([-0.19042674,  0.16814901,  0.11139794,  0.05383522,  0.09772731,
#         -0.4993338 ,  0.16626912,  0.5760868 , -0.26517943, -0.11265717,
#         -0.28220895, -0.42190042, -0.18223462,  0.12926288,  0.15994355,
#         -0.21036966,  0.1443679 , -0.33384833, -0.05822042, -0.6017107 ,
#          0.24950781,  0.04413014,  0.1757327 , -0.13542484,  0.01375595,
#          0.01881901, -0.20309322, -0.23732388, -0.3006451 ,  0.08374836,
#          0.34436908,  0.0027595 ,  0.12436292, -0.24973452, -0.18221048,
#          0.33794734, -0.0152571 , -0.24822895, -0.13222857, -0.59050053,
#          0.02873895, -0.22286518, -0.16714337,  0.0170998 ,  0.21001263,
#         -0.04492151, -0.14412466, -0.10591952,  0.2554612 ,  0.20128126,
#          0.17535368, -0.20970829, -0.06340945,  0.02201291, -0.09651481,
#          0.08773806,  0.16099831,  0.07666218, -0.45662808,  0.14542972,
#          0.07806075,  0.07754701, -0.07759817, -0.08872926, -0.2531038 ,
#          0.28024322,  0.11567815,  0.28978795, -0.33882225,  0.36501274,
#         -0.19041178,  0.1863517 ,  0.38231707, -0.12964314,  0.39597628,
#          0.05001495,  0.00480296, -0.08694558, -0.17979917,  0.08508921,
#         -0.23574355, -0.05089645, -0.3186382 ,  0.4418748 , -0.21246357,
#         -0.09832562,  0.16427232,  0.21828417,  0.38816693, -0.00754538,
#          0.422395  ,  0.15619141,  0.0479539 ,  0.01236856,  0.53838384,
#          0.20000382,  0.12349574, -0.2654176 ,  0.13947248, -0.04662757],
#        dtype=float32),
#  array([-2.05223143e-01,  1.76533893e-01,  1.09219119e-01,  5.69209196e-02,
#          1.10090785e-01, -5.16241789e-01,  1.63921833e-01,  5.87314367e-01,
#         -2.80488610e-01, -1.09923497e-01, -2.97807604e-01, -4.33524042e-01,
#         -1.90834090e-01,  1.28025323e-01,  1.66729778e-01, -2.20132053e-01,
#          1.44688353e-01, -3.51752073e-01, -6.48344681e-02, -6.14065230e-01,
#          2.45569214e-01,  6.05256520e-02,  1.76423252e-01, -1.36231869e-01,
#          2.08167974e-02,  1.91996042e-02, -2.18003169e-01, -2.41564050e-01,
#         -3.04204792e-01,  8.11024830e-02,  3.47252965e-01,  1.49691341e-05,
#          1.08550780e-01, -2.38231555e-01, -1.85633838e-01,  3.45050126e-01,
#         -7.63192587e-03, -2.58978784e-01, -1.24891534e-01, -6.11995697e-01,
#          3.87739688e-02, -2.30701789e-01, -1.81935728e-01,  1.49444006e-02,
#          2.04462051e-01, -4.90532629e-02, -1.47684023e-01, -1.07343912e-01,
#          2.56795228e-01,  1.98388800e-01,  1.69409961e-01, -2.27064997e-01,
#         -5.06442823e-02,  3.27568240e-02, -1.14640921e-01,  9.50777382e-02,
#          1.69097379e-01,  7.04396963e-02, -4.66148853e-01,  1.57063350e-01,
#          8.17498267e-02,  7.53512233e-02, -7.70932361e-02, -8.61017704e-02,
#         -2.69175351e-01,  2.82100677e-01,  1.20359734e-01,  3.02209795e-01,
#         -3.50148201e-01,  3.82276386e-01, -2.01847315e-01,  1.98946059e-01,
#          3.86644065e-01, -1.52999610e-01,  3.99047524e-01,  4.50470932e-02,
#         -7.36961793e-03, -9.15712863e-02, -1.90886497e-01,  7.19078034e-02,
#         -2.24587753e-01, -5.33789545e-02, -3.17879558e-01,  4.51667041e-01,
#         -2.15697944e-01, -9.01416093e-02,  1.58016801e-01,  2.26831153e-01,
#          3.84553194e-01, -1.21742859e-02,  4.26688612e-01,  1.57502145e-01,
#          3.93657535e-02,  9.26575903e-03,  5.48730612e-01,  2.03799635e-01,
#          1.20950647e-01, -2.84248888e-01,  1.53662577e-01, -4.50380631e-02],
#        dtype=float32),
#  array([-0.23720175,  0.19349775,  0.13248391,  0.06247194,  0.12502784,
#         -0.6041156 ,  0.19253716,  0.69383776, -0.32420063, -0.14895327,
#         -0.3342327 , -0.51423365, -0.22200084,  0.15175931,  0.19543232,
#         -0.2505016 ,  0.1843661 , -0.40214428, -0.06188539, -0.7230273 ,
#          0.28853256,  0.04856068,  0.22118871, -0.16881034,  0.02954224,
#          0.02803599, -0.24612223, -0.2744685 , -0.34931773,  0.10294262,
#          0.42277437, -0.00138399,  0.14578068, -0.2948013 , -0.20850728,
#          0.41064975, -0.01006569, -0.29331213, -0.14164275, -0.6974096 ,
#          0.05500569, -0.28887746, -0.21371569,  0.03368331,  0.24825954,
#         -0.04040715, -0.16715926, -0.12819774,  0.29109496,  0.23069634,
#          0.21728598, -0.25310916, -0.06145243,  0.04272814, -0.12028687,
#          0.11305183,  0.19271241,  0.09139919, -0.53676736,  0.1843591 ,
#          0.09278403,  0.08381338, -0.08384216, -0.09495734, -0.29982936,
#          0.33628753,  0.15457195,  0.35042718, -0.40036684,  0.45366028,
#         -0.22663951,  0.21942747,  0.4553356 , -0.15124501,  0.47063825,
#          0.06101624, -0.01210959, -0.10200399, -0.20786366,  0.10386462,
#         -0.27767494, -0.04453357, -0.36673632,  0.52414227, -0.23804803,
#         -0.10133551,  0.20918864,  0.25284025,  0.45788395, -0.00578371,
#          0.50683504,  0.17619023,  0.05291851,  0.01073559,  0.6336262 ,
#          0.24331883,  0.14261201, -0.32522753,  0.16537093, -0.04843152],
#        dtype=float32),
#  array([-1.65300041e-01,  1.39619768e-01,  9.66195613e-02,  4.72568907e-02,
#          8.09416473e-02, -4.27692503e-01,  1.35970056e-01,  4.85115826e-01,
#         -2.26015717e-01, -1.02138333e-01, -2.35957801e-01, -3.59050870e-01,
#         -1.54128358e-01,  1.06431812e-01,  1.33109987e-01, -1.76823601e-01,
#          1.26169428e-01, -2.84062922e-01, -4.80695516e-02, -5.10232031e-01,
#          2.04696327e-01,  3.80009562e-02,  1.48916259e-01, -1.15239315e-01,
#          1.73569303e-02,  1.75892804e-02, -1.73862800e-01, -1.94050893e-01,
#         -2.52803355e-01,  6.92640990e-02,  2.91723460e-01,  4.05609433e-04,
#          1.07383393e-01, -2.09148690e-01, -1.51619151e-01,  2.88876355e-01,
#         -4.01270296e-03, -2.13243961e-01, -1.09896094e-01, -4.99394298e-01,
#          2.96939723e-02, -1.98909134e-01, -1.51676089e-01,  1.54459914e-02,
#          1.77259803e-01, -3.30539346e-02, -1.19915552e-01, -8.79889056e-02,
#          2.05037102e-01,  1.67241320e-01,  1.48746595e-01, -1.78661942e-01,
#         -5.21785654e-02,  2.61131413e-02, -8.85566175e-02,  7.33331367e-02,
#          1.35308266e-01,  6.31689206e-02, -3.86823654e-01,  1.22856855e-01,
#          6.32348880e-02,  5.92469722e-02, -6.50201589e-02, -6.89727962e-02,
#         -2.16153800e-01,  2.38843501e-01,  1.00729562e-01,  2.53075331e-01,
#         -2.86213219e-01,  3.16718698e-01, -1.62006587e-01,  1.64047897e-01,
#          3.25952172e-01, -1.09632753e-01,  3.36284041e-01,  3.99569348e-02,
#         -2.15549744e-03, -7.97021836e-02, -1.47806287e-01,  7.19863623e-02,
#         -1.98374614e-01, -3.93600240e-02, -2.59180099e-01,  3.77858251e-01,
#         -1.71586171e-01, -7.63169304e-02,  1.41508937e-01,  1.79108873e-01,
#          3.22280765e-01, -2.99586286e-03,  3.54139954e-01,  1.24427006e-01,
#          4.36822623e-02,  1.18321395e-02,  4.53151405e-01,  1.75292015e-01,
#          9.67024267e-02, -2.32859597e-01,  1.19550556e-01, -3.57827581e-02],
#        dtype=float32),
#  array([-0.23556949,  0.21322267,  0.14581798,  0.07031266,  0.10516417,
#         -0.62001085,  0.20114884,  0.70161974, -0.3277543 , -0.15979257,
#         -0.3394135 , -0.5245098 , -0.21553731,  0.1463289 ,  0.19549285,
#         -0.2581423 ,  0.18084307, -0.42041615, -0.06484251, -0.741125  ,
#          0.28608477,  0.06515992,  0.21744575, -0.17289105,  0.0236522 ,
#          0.0195591 , -0.2591874 , -0.27608085, -0.3613394 ,  0.10513064,
#          0.42144638, -0.00326283,  0.15625331, -0.27803904, -0.21922241,
#          0.4274565 ,  0.00169808, -0.31644028, -0.16968772, -0.7252995 ,
#          0.04159955, -0.2922154 , -0.23100594,  0.02530805,  0.2485349 ,
#         -0.04835965, -0.17022754, -0.12478282,  0.2984107 ,  0.24742025,
#          0.21566278, -0.26938066, -0.07264329,  0.04667412, -0.13340998,
#          0.10809095,  0.20029068,  0.08877704, -0.56014395,  0.18394567,
#          0.08333295,  0.07856373, -0.08765581, -0.10861385, -0.3241781 ,
#          0.34757498,  0.14425087,  0.3613165 , -0.42926508,  0.46070147,
#         -0.23673585,  0.25626346,  0.47691113, -0.16221674,  0.48319024,
#          0.0676585 ,  0.00233321, -0.1259248 , -0.2177757 ,  0.09770696,
#         -0.28501663, -0.06113758, -0.3716431 ,  0.54863864, -0.24813649,
#         -0.10846337,  0.18834412,  0.24678111,  0.46987653,  0.00798895,
#          0.51069266,  0.18731725,  0.05445426,  0.01803293,  0.66108257,
#          0.24653389,  0.1356635 , -0.33573753,  0.17911103, -0.05142612],
#        dtype=float32),
#  array([-0.22004494,  0.16421081,  0.12832986,  0.0449019 ,  0.12518537,
#         -0.5170747 ,  0.15818794,  0.606598  , -0.2806174 , -0.12707974,
#         -0.29203025, -0.45528495, -0.18600433,  0.13780437,  0.17463532,
#         -0.21433519,  0.17507532, -0.34638608, -0.05105333, -0.6427217 ,
#          0.25330532,  0.02962363,  0.19463564, -0.14353837,  0.02222661,
#          0.03001254, -0.21148205, -0.2496213 , -0.29551888,  0.10554893,
#          0.3860336 , -0.00549685,  0.11706708, -0.2445619 , -0.17733337,
#          0.35953823, -0.02749563, -0.24023806, -0.09295395, -0.59567744,
#          0.07814051, -0.25856778, -0.18061064,  0.04180215,  0.21503845,
#         -0.02897073, -0.15001673, -0.11684619,  0.22777754,  0.19128504,
#          0.19978915, -0.21421495, -0.03431576,  0.04623549, -0.09978721,
#          0.10876627,  0.16942753,  0.08714859, -0.45688766,  0.16714154,
#          0.07441402,  0.05936722, -0.06423027, -0.06734315, -0.24724077,
#          0.27876893,  0.15125951,  0.30066755, -0.3225494 ,  0.39533657,
#         -0.20096967,  0.1626557 ,  0.3925325 , -0.12135463,  0.38995263,
#          0.05245703, -0.00780613, -0.07819176, -0.17068459,  0.09351129,
#         -0.23684986, -0.01774905, -0.2918828 ,  0.45081827, -0.20602605,
#         -0.07296159,  0.20892042,  0.21912362,  0.38778347, -0.03115634,
#          0.45921338,  0.13914987,  0.04442662,  0.00316494,  0.53839475,
#          0.22534081,  0.13970686, -0.29317   ,  0.13692093, -0.0294899 ],
#        dtype=float32),
#  array([-0.23819304,  0.19958155,  0.13911453,  0.06139779,  0.13234723,
#         -0.61275184,  0.19506119,  0.72093725, -0.33244333, -0.14781664,
#         -0.34719267, -0.5235797 , -0.22527592,  0.16101624,  0.20213611,
#         -0.25110218,  0.18781866, -0.40897974, -0.07292801, -0.7469949 ,
#          0.2977658 ,  0.03660583,  0.22417259, -0.17725906,  0.0222638 ,
#          0.02530818, -0.2493833 , -0.28732634, -0.35959402,  0.10920092,
#          0.43010917,  0.00151997,  0.15159495, -0.3101886 , -0.21931961,
#          0.41667587, -0.00921652, -0.29793233, -0.1510117 , -0.71178263,
#          0.05173387, -0.28691262, -0.21374485,  0.03616257,  0.26417437,
#         -0.04607731, -0.17614962, -0.132463  ,  0.29954547,  0.24278732,
#          0.22194068, -0.2554827 , -0.06905424,  0.04447206, -0.11952542,
#          0.11548416,  0.19172092,  0.09192795, -0.55022186,  0.1889091 ,
#          0.10162196,  0.08408897, -0.08602481, -0.09696419, -0.30171186,
#          0.34426823,  0.15783106,  0.35781983, -0.40453297,  0.45927143,
#         -0.23295988,  0.22190681,  0.46210533, -0.15046346,  0.47283703,
#          0.05875298, -0.00567836, -0.10323785, -0.20947245,  0.10924654,
#         -0.28063366, -0.04970624, -0.37926373,  0.53791916, -0.2499077 ,
#         -0.10588206,  0.22210169,  0.26544473,  0.46637616, -0.01338309,
# ...
#         -0.10462804,  0.15071239,  0.22344844,  0.43141907,  0.02656895,
#          0.45182985,  0.17395067,  0.05028034,  0.013122  ,  0.6076042 ,
#          0.21496299,  0.10643234, -0.30123216,  0.16350034, -0.04331381],
#        dtype=float32),
#  array([-0.1824363 ,  0.16723166,  0.11164432,  0.06436386,  0.086897  ,
#         -0.48498678,  0.16188034,  0.5332759 , -0.25928319, -0.11673922,
#         -0.26439   , -0.4034366 , -0.17184794,  0.11435   ,  0.1453332 ,
#         -0.19876583,  0.14125954, -0.32330993, -0.05375464, -0.56785834,
#          0.22314437,  0.06045857,  0.17195255, -0.13081712,  0.03193237,
#          0.01419076, -0.20100814, -0.20505542, -0.28692663,  0.07539994,
#          0.3209451 ,  0.00347227,  0.11764436, -0.21915087, -0.16611955,
#          0.33241615,  0.01484254, -0.24792504, -0.13953322, -0.56591356,
#          0.02580213, -0.22459835, -0.17846149,  0.01513664,  0.19029535,
#         -0.03223652, -0.13646328, -0.09025925,  0.23271261,  0.18884796,
#          0.16596778, -0.21886557, -0.06198129,  0.03379864, -0.1090949 ,
#          0.07484122,  0.15345222,  0.06294382, -0.44181648,  0.14329255,
#          0.0668164 ,  0.0617886 , -0.06318568, -0.08652391, -0.2555183 ,
#          0.27308825,  0.10731741,  0.28644153, -0.34229904,  0.36395773,
#         -0.18639442,  0.21192677,  0.36474863, -0.13080736,  0.37835723,
#          0.04131432, -0.00839741, -0.10257193, -0.16784053,  0.07368913,
#         -0.22077703, -0.05325272, -0.29445204,  0.4193307 , -0.1845653 ,
#         -0.08194578,  0.14256923,  0.18762174,  0.36133134,  0.01654328,
#          0.38498643,  0.14811975,  0.04008533,  0.00770115,  0.5152859 ,
#          0.18806867,  0.09464902, -0.26093876,  0.14417686, -0.03770436],
#        dtype=float32),
#  array([-0.22646603,  0.21610758,  0.14744237,  0.05400554,  0.10558569,
#         -0.61410636,  0.21249104,  0.71474195, -0.32033062, -0.15318863,
#         -0.3450597 , -0.5372262 , -0.23603505,  0.14126034,  0.18410589,
#         -0.25567675,  0.17684928, -0.4116165 , -0.06360702, -0.73792315,
#          0.31781477,  0.061631  ,  0.21321698, -0.1587225 ,  0.01323088,
#          0.01888596, -0.25317115, -0.28071752, -0.3910355 ,  0.09555412,
#          0.42127222,  0.00810244,  0.17182706, -0.31714496, -0.21993178,
#          0.41276658, -0.01918647, -0.31991518, -0.18534592, -0.7467102 ,
#          0.02535419, -0.28730595, -0.22226283,  0.00275018,  0.27718186,
#         -0.06081101, -0.17166562, -0.12652326,  0.32819495,  0.27375734,
#          0.24473122, -0.2661307 , -0.10524585,  0.00991111, -0.11428606,
#          0.09223565,  0.20884691,  0.11349651, -0.5790126 ,  0.16227984,
#          0.07580919,  0.1042567 , -0.11021031, -0.14955156, -0.32265067,
#          0.35431153,  0.14987266,  0.37554964, -0.45113897,  0.45380664,
#         -0.23318729,  0.25161636,  0.5064935 , -0.15222842,  0.51028633,
#          0.06948491,  0.01476604, -0.14268185, -0.22553657,  0.12667865,
#         -0.3326711 , -0.07529633, -0.40064722,  0.57684547, -0.27052015,
#         -0.15183315,  0.19159187,  0.25724685,  0.5019318 ,  0.02246812,
#          0.50586236,  0.20573516,  0.08742075,  0.0240612 ,  0.6909874 ,
#          0.26801845,  0.16520245, -0.2977821 ,  0.1681228 , -0.06486008],
#        dtype=float32),
#  array([-0.22072531,  0.20082274,  0.12886895,  0.06256112,  0.10676263,
#         -0.5881748 ,  0.19956729,  0.6761364 , -0.31463423, -0.13709047,
#         -0.3217433 , -0.50093734, -0.21457992,  0.13895188,  0.18362014,
#         -0.24157028,  0.17886885, -0.39000773, -0.06545142, -0.7101926 ,
#          0.28949395,  0.05766597,  0.21208514, -0.16187398,  0.01793131,
#          0.01981701, -0.23377232, -0.27038676, -0.3533151 ,  0.09384976,
#          0.4067152 , -0.00138117,  0.15009592, -0.2917787 , -0.20827974,
#          0.40382248, -0.00561548, -0.29618385, -0.15605359, -0.6966796 ,
#          0.04193713, -0.2810684 , -0.207765  ,  0.02135692,  0.24961002,
#         -0.04103884, -0.16761541, -0.11966811,  0.2964635 ,  0.23375566,
#          0.21635185, -0.24991538, -0.07972673,  0.03053764, -0.12132937,
#          0.10192542,  0.19458096,  0.09083357, -0.5452542 ,  0.16469204,
#          0.08822839,  0.08558372, -0.09140559, -0.11028661, -0.29690275,
#          0.33662644,  0.14259411,  0.3499091 , -0.4114378 ,  0.44050932,
#         -0.22388329,  0.23261361,  0.46213946, -0.14733753,  0.4712699 ,
#          0.06387398,  0.00740425, -0.11792691, -0.20638041,  0.1072304 ,
#         -0.28710777, -0.05586134, -0.36943215,  0.5293824 , -0.24504414,
#         -0.11691972,  0.18765543,  0.24785022,  0.46035093,  0.00564019,
#          0.49182883,  0.18217269,  0.06771113,  0.02039789,  0.641158  ,
#          0.2466345 ,  0.14478396, -0.30602726,  0.160556  , -0.05669765],
#        dtype=float32),
#  array([-0.23950985,  0.2012156 ,  0.12424785,  0.07040972,  0.12086761,
#         -0.6181497 ,  0.20066991,  0.7146551 , -0.34002787, -0.13968144,
#         -0.34774032, -0.51453465, -0.22530408,  0.16047604,  0.1932266 ,
#         -0.26370406,  0.17834938, -0.41562134, -0.07971628, -0.73773754,
#          0.3017594 ,  0.0566784 ,  0.21480827, -0.16191895,  0.020077  ,
#          0.01963689, -0.2516634 , -0.29250336, -0.36406678,  0.09723245,
#          0.4188787 ,  0.00463189,  0.14998154, -0.30541986, -0.21942976,
#          0.41728258, -0.00943616, -0.30137667, -0.15883139, -0.7260219 ,
#          0.04294524, -0.27630216, -0.2178323 ,  0.02582556,  0.25044042,
#         -0.05792676, -0.17445016, -0.1283258 ,  0.3121025 ,  0.23965268,
#          0.20346732, -0.25918582, -0.06470861,  0.03127756, -0.12439789,
#          0.11181116,  0.19966625,  0.08736937, -0.55495846,  0.18898778,
#          0.10548744,  0.0891827 , -0.09561497, -0.10886814, -0.31561235,
#          0.34255213,  0.14464505,  0.35827523, -0.42114687,  0.45730114,
#         -0.23195942,  0.22828515,  0.46482262, -0.16624084,  0.4838616 ,
#          0.05589071, -0.00343385, -0.10513224, -0.22146077,  0.09487239,
#         -0.27155834, -0.05601649, -0.3914273 ,  0.5338732 , -0.26385194,
#         -0.11424281,  0.20586216,  0.26794866,  0.46387586, -0.00719156,
#          0.51350296,  0.18768653,  0.05500566,  0.0175649 ,  0.6578326 ,
#          0.24176726,  0.14348233, -0.3360736 ,  0.17983563, -0.06063872],
#        dtype=float32),
#  array([-0.16733259,  0.1541701 ,  0.10328031,  0.05069022,  0.0814984 ,
#         -0.45096642,  0.14948472,  0.50980234, -0.2389278 , -0.10654651,
#         -0.2421356 , -0.38659695, -0.15587893,  0.10669545,  0.13946024,
#         -0.18376295,  0.13785544, -0.29672882, -0.05106516, -0.5377693 ,
#          0.22076675,  0.05237799,  0.15761083, -0.12316541,  0.01447555,
#          0.01478235, -0.17887914, -0.19919541, -0.27532154,  0.07066137,
#          0.31294745,  0.00194045,  0.11794361, -0.21324553, -0.1636374 ,
#          0.30825457, -0.00344444, -0.23259547, -0.12685281, -0.53605473,
#          0.02612261, -0.21605428, -0.15752248,  0.0105286 ,  0.19870599,
#         -0.03139118, -0.12767622, -0.0911896 ,  0.22395894,  0.1814369 ,
#          0.16590272, -0.19632058, -0.07297987,  0.02044094, -0.10295014,
#          0.06870063,  0.14679183,  0.06617457, -0.4210464 ,  0.12379731,
#          0.06339228,  0.06624429, -0.06837298, -0.09071926, -0.23466262,
#          0.26069877,  0.10716207,  0.26962087, -0.32298312,  0.33402616,
#         -0.17147194,  0.18700117,  0.3558542 , -0.1128177 ,  0.36719745,
#          0.04952819,  0.00420436, -0.09720902, -0.15523495,  0.08216599,
#         -0.21893518, -0.05039933, -0.28433594,  0.4084308 , -0.18073237,
#         -0.09421047,  0.13682902,  0.18275006,  0.35697967,  0.00882569,
#          0.36879748,  0.14730749,  0.05463954,  0.01765372,  0.49579176,
#          0.19446625,  0.11025681, -0.23052813,  0.12774883, -0.03949725],
#        dtype=float32),
#  array([-0.24611092,  0.21650478,  0.14988866,  0.06997256,  0.13170135,
#         -0.64824396,  0.213075  ,  0.7570545 , -0.34490865, -0.16809732,
#         -0.3593883 , -0.5654016 , -0.23410189,  0.16190982,  0.20680125,
#         -0.265573  ,  0.19925629, -0.44079208, -0.06722225, -0.78377783,
#          0.31058452,  0.05363737,  0.22767937, -0.18664491,  0.0190428 ,
#          0.03191607, -0.2667375 , -0.292305  , -0.37923318,  0.11527026,
#          0.4537639 , -0.00550232,  0.17126453, -0.3192315 , -0.23669371,
#          0.44144988,  0.00347125, -0.3150886 , -0.16805036, -0.76275384,
#          0.04484976, -0.31121427, -0.22595255,  0.03458468,  0.2796309 ,
#         -0.04428103, -0.18289848, -0.13712952,  0.32341963,  0.25004336,
#          0.23251426, -0.2671894 , -0.07855414,  0.04184215, -0.13145205,
#          0.11368772,  0.21320851,  0.10155176, -0.5854347 ,  0.20272696,
#          0.08962077,  0.09130643, -0.08927062, -0.10119875, -0.32873422,
#          0.3737517 ,  0.16364303,  0.3814085 , -0.44005424,  0.48557988,
#         -0.24198988,  0.23757163,  0.49648553, -0.15886508,  0.50878257,
#          0.05285621, -0.00796685, -0.11639186, -0.22955124,  0.10792289,
#         -0.30438137, -0.05190421, -0.39556068,  0.57509804, -0.25053862,
#         -0.10770681,  0.22544439,  0.27115405,  0.48968896, -0.0140512 ,
#          0.54997355,  0.18921487,  0.07007878,  0.01898902,  0.69318765,
#          0.25610548,  0.15108472, -0.35286576,  0.17885038, -0.05186981],
#        dtype=float32),
#  array([-0.229145  ,  0.1895045 ,  0.13000773,  0.06864637,  0.10558053,
#         -0.57120967,  0.18832944,  0.65410864, -0.30415687, -0.14331444,
#         -0.3102412 , -0.47843972, -0.20154063,  0.1356816 ,  0.17350571,
#         -0.23150021,  0.17465778, -0.38212356, -0.06604395, -0.681489  ,
#          0.26743582,  0.05211875,  0.20367889, -0.14980884,  0.02591811,
#          0.024086  , -0.23058836, -0.2511571 , -0.34892893,  0.08717111,
#          0.38410082,  0.00596154,  0.14787345, -0.28520396, -0.19933839,
#          0.39027703,  0.00324313, -0.29526916, -0.16287325, -0.66843534,
#          0.02798483, -0.26534048, -0.20604265,  0.01939816,  0.23765409,
#         -0.0497759 , -0.16225715, -0.11078825,  0.2826247 ,  0.23026676,
#          0.19452764, -0.2395404 , -0.08072364,  0.03354831, -0.1203867 ,
#          0.0978943 ,  0.19417787,  0.08327758, -0.51706517,  0.17011666,
#          0.08718144,  0.08494314, -0.08219172, -0.10279862, -0.29791558,
#          0.3224037 ,  0.13192798,  0.3404088 , -0.39409348,  0.42620155,
#         -0.21272469,  0.23061453,  0.4388461 , -0.14787006,  0.45608738,
#          0.05751947, -0.00628006, -0.11123341, -0.20021261,  0.09223671,
#         -0.26508084, -0.04895956, -0.34728262,  0.5041582 , -0.23340106,
#         -0.10702307,  0.1876875 ,  0.24385393,  0.4350963 ,  0.00755332,
#          0.46718955,  0.17700176,  0.05462908,  0.02012573,  0.619509  ,
#          0.23521382,  0.12767941, -0.30854777,  0.161341  , -0.05006841],
#        dtype=float32),
#  array([-2.39097819e-01,  1.99064180e-01,  1.38061106e-01,  6.78965598e-02,
#          1.21237732e-01, -6.08253062e-01,  1.99132845e-01,  7.02741802e-01,
#         -3.25692326e-01, -1.48732603e-01, -3.36583436e-01, -5.14276505e-01,
#         -2.20325768e-01,  1.55853018e-01,  1.89110488e-01, -2.48439789e-01,
#          1.80349872e-01, -4.05052662e-01, -7.35339969e-02, -7.28823721e-01,
#          2.90779620e-01,  4.80857864e-02,  2.17040434e-01, -1.66833922e-01,
#          2.76227556e-02,  2.42467187e-02, -2.47484744e-01, -2.74461061e-01,
#         -3.61884981e-01,  1.01212159e-01,  4.21444267e-01,  8.06032505e-04,
#          1.54673189e-01, -3.02020460e-01, -2.15562373e-01,  4.16016251e-01,
#          2.26409727e-04, -3.07883680e-01, -1.60744816e-01, -7.08452165e-01,
#          3.81829776e-02, -2.84136087e-01, -2.16308758e-01,  2.32816562e-02,
#          2.57661790e-01, -4.83910479e-02, -1.74604714e-01, -1.27500117e-01,
#          3.03848952e-01,  2.41287485e-01,  2.13340774e-01, -2.55652398e-01,
#         -7.29629323e-02,  3.81766558e-02, -1.25309810e-01,  1.08632773e-01,
#          1.98084489e-01,  9.11088735e-02, -5.46732664e-01,  1.81966648e-01,
#          9.53909904e-02,  8.84258375e-02, -8.66739526e-02, -1.04596667e-01,
#         -3.07244360e-01,  3.40644062e-01,  1.47654787e-01,  3.59072894e-01,
#         -4.10138190e-01,  4.53750342e-01, -2.26360366e-01,  2.30159521e-01,
#          4.60293949e-01, -1.52525827e-01,  4.78476733e-01,  5.51010892e-02,
#         -5.38688432e-03, -1.12845287e-01, -2.12058768e-01,  9.89322588e-02,
#         -2.79809445e-01, -5.51144704e-02, -3.72622848e-01,  5.34551382e-01,
#         -2.52709270e-01, -1.11844584e-01,  2.04086140e-01,  2.56509691e-01,
#          4.59992498e-01, -4.69282735e-03,  5.09170234e-01,  1.81258738e-01,
#          5.88490367e-02,  1.16091045e-02,  6.50057733e-01,  2.48137906e-01,
#          1.40231848e-01, -3.29879820e-01,  1.68085709e-01, -5.18910438e-02],
#        dtype=float32),
#  array([-0.23650223,  0.20389126,  0.13640958,  0.06476611,  0.11791392,
#         -0.60231215,  0.20104696,  0.6986571 , -0.324763  , -0.14256613,
#         -0.3345735 , -0.5167435 , -0.22005032,  0.1532259 ,  0.19033413,
#         -0.25020412,  0.1850635 , -0.4018478 , -0.06682312, -0.73284906,
#          0.2988071 ,  0.04784919,  0.21869057, -0.16238576,  0.01395152,
#          0.02545728, -0.24329436, -0.28183195, -0.3624871 ,  0.10742003,
#          0.4260472 , -0.0022532 ,  0.1566259 , -0.30130494, -0.21690762,
#          0.41625515, -0.01624217, -0.2947051 , -0.15300581, -0.7088849 ,
#          0.04826291, -0.29023176, -0.21062273,  0.02583547,  0.2610786 ,
#         -0.04416918, -0.17120238, -0.1279874 ,  0.30233118,  0.23999444,
#          0.22585957, -0.25131863, -0.07769608,  0.02877785, -0.12219071,
#          0.10382323,  0.1960991 ,  0.09523259, -0.5570911 ,  0.17260791,
#          0.08812267,  0.0838918 , -0.09180923, -0.10627756, -0.30239838,
#          0.33777073,  0.15348324,  0.3574956 , -0.41301364,  0.45146084,
#         -0.2280872 ,  0.2245747 ,  0.4688388 , -0.14852928,  0.48055017,
#          0.06114281,  0.00515576, -0.11147482, -0.20802765,  0.1100616 ,
#         -0.2931432 , -0.05736088, -0.37271804,  0.5403996 , -0.25153592,
#         -0.11862656,  0.2090363 ,  0.25833482,  0.4675869 , -0.00833883,
#          0.51118016,  0.18346862,  0.06742747,  0.01914634,  0.6509047 ,
#          0.25366396,  0.15609144, -0.32002997,  0.16361788, -0.05169033],
#        dtype=float32),
#  array([-2.22021371e-01,  1.93000540e-01,  1.20501176e-01,  6.70507774e-02,
#          1.18185267e-01, -5.85839152e-01,  1.92370757e-01,  6.65424049e-01,
#         -3.18093300e-01, -1.35284603e-01, -3.27564389e-01, -4.84991163e-01,
#         -2.11310029e-01,  1.42976448e-01,  1.80186734e-01, -2.44674519e-01,
#          1.68802410e-01, -3.91214013e-01, -7.27857202e-02, -6.97605789e-01,
#          2.76572704e-01,  6.01399280e-02,  2.02044785e-01, -1.60167381e-01,
#          2.79350281e-02,  2.19909661e-02, -2.40948319e-01, -2.69260943e-01,
#         -3.48012239e-01,  9.48179588e-02,  3.87466371e-01,  5.72140422e-03,
#          1.39276609e-01, -2.84936696e-01, -2.05876052e-01,  3.95336241e-01,
#         -3.72314244e-03, -2.89673895e-01, -1.52900353e-01, -6.86185300e-01,
#          3.87597866e-02, -2.65132189e-01, -2.07106426e-01,  2.14039460e-02,
#          2.34957427e-01, -5.70185632e-02, -1.64412618e-01, -1.18737325e-01,
#          2.93185055e-01,  2.23756835e-01,  1.92666799e-01, -2.51679838e-01,
#         -5.87054305e-02,  3.29958946e-02, -1.22595392e-01,  1.00157678e-01,
#          1.84930906e-01,  7.79182389e-02, -5.24094641e-01,  1.79443449e-01,
#          9.85390097e-02,  8.18311423e-02, -8.51713046e-02, -9.92615819e-02,
#         -3.03012669e-01,  3.29013139e-01,  1.35244876e-01,  3.41716617e-01,
#         -4.04048115e-01,  4.32016194e-01, -2.25243136e-01,  2.27570459e-01,
#          4.41774011e-01, -1.63741082e-01,  4.53915328e-01,  5.12966029e-02,
#         -9.54899844e-03, -1.06645323e-01, -2.09843129e-01,  8.76423195e-02,
#         -2.57967502e-01, -5.16500548e-02, -3.68652195e-01,  5.04258156e-01,
#         -2.40873024e-01, -1.06159389e-01,  1.86851397e-01,  2.53219187e-01,
#          4.39821005e-01, -1.31576002e-04,  4.79351819e-01,  1.75566167e-01,
#          4.66325469e-02,  1.43502783e-02,  6.19149268e-01,  2.29818255e-01,
#          1.27207115e-01, -3.17010581e-01,  1.71605662e-01, -5.52255251e-02],
#        dtype=float32),
#  ...]

# %%
len(X)
# Out:
# 5569

# %%
##independent Features
X_new=np.array(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 ##independent Features
# ----> 2 X_new=np.array(X)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5569,) + inhomogeneous part.

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X[1]
# Out:
# array([-0.15753588,  0.13437204,  0.08192524,  0.04406684,  0.08292264,
#        -0.39320928,  0.12433251,  0.45259124, -0.2101215 , -0.08666937,
#        -0.22303139, -0.32983315, -0.14075911,  0.10010609,  0.12597369,
#        -0.16792694,  0.10778367, -0.26390818, -0.05470043, -0.47360042,
#         0.19176875,  0.04029855,  0.13437133, -0.10541614,  0.01431791,
#         0.0106719 , -0.15722346, -0.18891424, -0.2309726 ,  0.05944937,
#         0.25956255,  0.00050695,  0.08925155, -0.19126889, -0.14068209,
#         0.26825628, -0.00585097, -0.19981892, -0.1073648 , -0.4676809 ,
#         0.02242412, -0.17187546, -0.13550866,  0.00562917,  0.15514009,
#        -0.03978009, -0.11351934, -0.07905886,  0.19869727,  0.15809785,
#         0.13457726, -0.16591284, -0.04664778,  0.02106041, -0.07983901,
#         0.07103389,  0.12838732,  0.05391279, -0.3595308 ,  0.12460035,
#         0.0673069 ,  0.05859399, -0.05646047, -0.06250998, -0.20723853,
#         0.21339585,  0.08808829,  0.22606258, -0.27121717,  0.29067037,
#        -0.14887086,  0.14817429,  0.29537052, -0.10826129,  0.30523112,
#         0.03524539, -0.00254039, -0.07304463, -0.14870614,  0.05627357,
#        -0.17199478, -0.03704856, -0.2557996 ,  0.33892182, -0.16973215,
#        -0.07118662,  0.11600889,  0.17467275,  0.29404795, -0.00350095,
#         0.33171067,  0.1144412 ,  0.03165492,  0.00405476,  0.41398674,
#         0.14745831,  0.09030534, -0.2172128 ,  0.11957267, -0.04154909],
#       dtype=float32)

# %%
X_new.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 X_new.shape
#
# NameError: name 'X_new' is not defined

# %%
X_new[0].shape

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))]
y=pd.get_dummies(y['label'])
y=y.iloc[:,0].values

# %%
y.shape
# Out:
# (5569,)

# %%
X[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df=pd.DataFrame()
for i in range(0,len(X)):
    df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9488\4049946657.py in ?()
#       1 ## this is the final independent features
#       2 df=pd.DataFrame()
#       3 for i in range(0,len(X)):
# ----> 4     df=df.append(pd.DataFrame(X[i].reshape(1,-1)),ignore_index=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Output']=y

# %%
df.head()
# Out:
#    Output
# 0    True
# 1    True
# 2   False
# 3    True
# 4    True

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Output    0
# dtype: int64

# %%
X=df

# %%
df.isnull().sum()
# Out:
# Output    0
# dtype: int64

# %%
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
X_train.head()
# Out:
#       Output
# 4093    True
# 4626   False
# 648    False
# 3604    True
# 954     True

# %%
y_train
# Out:
# 4093     True
# 4626    False
# 648     False
# 3604     True
# 954      True
#         ...
# 4523     True
# 4266     True
# 4020     True
# 4396     True
# 1628     True
# Name: Output, Length: 4455, dtype: bool

# %%
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier()

# %%
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00       149
#         True       1.00      1.00      1.00       965
#
#     accuracy                           1.00      1114
#    macro avg       1.00      1.00      1.00      1114
# weighted avg       1.00      1.00      1.00      1114
